# %%
# sphinx_gallery_thumbnail_number = 2

# Authors: Robert Luke <mail@robertluke.net>
#
# License: BSD (3-clause)

# Import common libraries
from collections import defaultdict
from copy import deepcopy
from itertools import compress
from pprint import pprint

# Import Plotting Library
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import os
import pywt
import mne_nirs
import mne



# Import StatsModels
import statsmodels.formula.api as smf
from mne import Epochs, events_from_annotations, set_log_level
from mne.preprocessing.nirs import (
    beer_lambert_law,
    optical_density,
    scalp_coupling_index,
    temporal_derivative_distribution_repair,
    
)

# Import MNE processing
from mne.viz import plot_compare_evokeds

# Import MNE-BIDS processing
from mne_bids import BIDSPath, read_raw_bids


# Import MNE-NIRS processing
from mne_nirs.channels import get_long_channels, picks_pair_to_idx
from mne_nirs.datasets import fnirs_motor_group
from mne_nirs.signal_enhancement import (enhance_negative_correlation, short_channel_regression)
from mne_nirs.channels import (get_long_channels,
                               get_short_channels,
                               picks_pair_to_idx)

from collections import defaultdict
import numpy as np
from itertools import compress
from sklearn.decomposition import PCA

from mne_nirs.experimental_design import make_first_level_design_matrix
from mne_nirs.statistics import run_glm, statsmodels_to_results
from nilearn.plotting import plot_design_matrix
from mne.annotations import Annotations
from statsmodels.formula.api import mixedlm


from scipy.stats import ttest_ind


# Set general parameters
set_log_level("WARNING")  # Don't show info, as it is repetitive for many subjects

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)


# import summary_df from csv file
summary_df = pd.read_csv("global_mean_stddev_zscore.csv")
#stats_df = pd.read_csv("individual_mean_stddev_zscore.csv")
#stats_df = pd.read_csv("individual_mean_stddev_zscore_nocrop.csv")
stats_df = pd.read_csv("individual_mean_stddev_zscore_negcorr.csv")

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Epoch rejection

# %%
def reject_epochs(data, subject, session, condition_name, stats_df, z_thresh=3.0, max_reject_ratio=1.0):
    """
    Rejects epochs based on z-score threshold using subject/session/condition-specific stats from stats_df.

    Parameters:
        data (ndarray): (n_epochs,) or (n_epochs, n_times) – mean amplitude per epoch
        subject (str): e.g., "01"
        session (str): e.g., "01"
        condition_name (str): "Control", "Noise", or "Speech"
        stats_df (pd.DataFrame): DataFrame with per-participant mean and std
        z_thresh (float): Z-score threshold
        max_reject_ratio (float): Max proportion of epochs to reject

    Returns:
        cleaned_data (ndarray), {
            "CONDITION_GOOD_IDX": [...],
            "CONDITION_BAD_IDX": [...]
        }
    """

    # Extract stats
    row = stats_df[
        (stats_df["Subject"] == f"sub-{subject}") &
        (stats_df["Session"] == f"ses-{session}") &
        (stats_df["Condition"] == condition_name)
    ]

    if row.empty:
        raise ValueError(f"No stats found for sub-{subject}, ses-{session}, {condition_name}")

    mean_val = row["Mean_Amplitude"].values[0]
    std_val = row["SD_Amplitude"].values[0]

    # Ensure data is 1D
    if data.ndim > 1:
        data = data.mean(axis=1)

    # Compute z-scores and rejection mask
    z_scores = (data - mean_val) / std_val
    reject_mask = np.abs(z_scores) > z_thresh
    rejected_indices = np.where(reject_mask)[0].tolist()

    # Enforce max rejection ratio
    max_allowed = int(max_reject_ratio * data.shape[0])
    if len(rejected_indices) > max_allowed:
        rejected_indices = rejected_indices[:max_allowed]

    # Determine kept indices
    all_indices = set(range(data.shape[0]))
    good_indices = sorted(list(all_indices - set(rejected_indices)))
    bad_indices = sorted(rejected_indices)

    # Clean the data
    cleaned_data = np.delete(data, rejected_indices, axis=0)

    # Construct keys
    condition_upper = condition_name.upper()
    good_key = f"{condition_upper}_GOOD_IDX"
    bad_key = f"{condition_upper}_BAD_IDX"

    return cleaned_data, {
        good_key: good_indices,
        bad_key: bad_indices
    }

# %% [markdown]
# ## Full preprocessing + GLM

# %%
# cropping the signal before sci calculation
def preprocessing_glm_ROI(bids_path, subject_id, session_id, id, apply_epoch_rejection=True):
    print(f"Processing subject {subject_id} session {session_id}...")
    # Read data with annotations in BIDS format
    raw_intensity = read_raw_bids(bids_path=bids_path, verbose=False)
    raw_intensity.annotations.set_durations({'Control' : 5, 'Noise' : 5, 'Speech' : 5.25})
    
    # Get the events locations
    Breaks, _ = mne.events_from_annotations(raw_intensity, {'Xstart': 4, 'Xend': 5})
    AllEvents, _ = mne.events_from_annotations(raw_intensity)
    ControlEvents, _ = mne.events_from_annotations(raw_intensity, {'Control': 1})
    NoiseEvents, _ = mne.events_from_annotations(raw_intensity, {'Noise': 2})
    SpeechEvents, _ = mne.events_from_annotations(raw_intensity, {'Speech': 3})
    Breaks = Breaks[:, 0] / raw_intensity.info['sfreq']
    LastEvent = AllEvents[-1, 0] / raw_intensity.info['sfreq']

    if len(Breaks) % 2 == 0:
        raise ValueError("Breaks array should have an odd number of elements.")

    original_duration = raw_intensity.times[-1] - raw_intensity.times[0]

    # Cropping dataset
    cropped_intensity = raw_intensity.copy().crop(Breaks[0], Breaks[1])
    for j in range(2, len(Breaks) - 1, 2):
        block = raw_intensity.copy().crop(Breaks[j], Breaks[j + 1])
        cropped_intensity.append(block)
    cropped_intensity.append(raw_intensity.copy().crop(Breaks[-1], LastEvent + 15.25))

    cropped_duration = cropped_intensity.times[-1] - cropped_intensity.times[0]
    if cropped_duration >= original_duration:
        print(f"WARNING: Cropping did not reduce duration!")

    raw_intensity_cropped = cropped_intensity.copy()

    # Remove break annotations
    raw_intensity.annotations.delete(np.where(
        (raw_intensity.annotations.description == 'Xstart') | 
        (raw_intensity.annotations.description == 'Xend') | 
        (raw_intensity.annotations.description == 'BAD boundary') | 
        (raw_intensity.annotations.description == 'EDGE boundary')
    )[0])

    raw_intensity_cropped.annotations.delete(np.where(
        (raw_intensity_cropped.annotations.description == 'Xstart') | 
        (raw_intensity_cropped.annotations.description == 'Xend') | 
        (raw_intensity_cropped.annotations.description == 'BAD boundary') | 
        (raw_intensity_cropped.annotations.description == 'EDGE boundary')
    )[0]) 

    # Convert signal to optical density and determine bad channels
    raw_od = optical_density(raw_intensity)
    raw_od_cropped = optical_density(raw_intensity_cropped)

    # get the total number of short channels
    short_chs = get_short_channels(raw_od)
    tot_number_of_short_channels = len(short_chs.ch_names)

    # sci calculated
    sci = scalp_coupling_index(raw_od_cropped, l_freq=0.7, h_freq=1.45)
    bad_channels= list(compress(raw_od.ch_names, sci < 0.8))

    if len(bad_channels) > 55:
        print(f"❌ Too many bad channels ({len(bad_channels)}). Excluding subject from analysis.")
        return None

    raw_od.info["bads"] = bad_channels
    raw_intensity_cropped.info["bads"] = bad_channels

    raw_od = temporal_derivative_distribution_repair(raw_od)
    raw_od_cropped = temporal_derivative_distribution_repair(raw_od_cropped)

    # Get long channels
    long_chs = get_long_channels(raw_od)
    bad_long_chs = long_chs.info["bads"]

    len_bad_short_chs = len(bad_channels) - len(bad_long_chs)
    num_good_short_channels = tot_number_of_short_channels - len_bad_short_chs

    if num_good_short_channels < 4:
        print("❌ No short channels found. Skipping the subject.")
        return None, None, None, None, None
    else:
        # lets not include the short channels in the raw_od
        raw_od_corrected = short_channel_regression(raw_od)
        
        # raw_od_corrected = raw_od.copy()


    # Convert to haemoglobin and filter
    raw_haemo_bef = beer_lambert_law(raw_od_corrected, ppf=0.1)
    raw_haemo_bef = get_long_channels(raw_haemo_bef, min_dist=0.02)
    
    # negative correlation enhancement
    raw_haemo_bef = enhance_negative_correlation(raw_haemo_bef)

    
     
    raw_haemo_bef = raw_haemo_bef.filter(l_freq=None, h_freq=0.2, method="iir", iir_params=dict(order=5, ftype='butter'))
    raw_haemo_bef = raw_haemo_bef.filter(l_freq=0.05, h_freq=None, method="iir", iir_params=dict(order=5, ftype='butter'))
    
    
    # EPOCH REJECTION
    if apply_epoch_rejection:
        all_events, all_event_dict = mne.events_from_annotations(raw_haemo_bef)
        epochs = mne.Epochs(
            raw_haemo_bef,
            all_events,
            event_id=all_event_dict,
            tmin=-3,
            tmax=14,
            reject=dict(hbo=100e-6),
            reject_by_annotation=True,
            proj=True,
            baseline=(None, 0),
            detrend=1,
            preload=True,
            verbose=None,
        )
        
        """ evoked_dict = {
            "Noise/HbO": epochs["Noise"].average(picks="hbo"),
            "Noise/HbR": epochs["Noise"].average(picks="hbr"),
            "Speech/HbO": epochs["Speech"].average(picks="hbo"),
            "Speech/HbR": epochs["Speech"].average(picks="hbr"),
            "Control/HbO": epochs["Control"].average(picks="hbo"),
            "Control/HbR": epochs["Control"].average(picks="hbr"),
        }

        # Rename channels until the encoding of frequency in ch_name is fixed
        for condition in evoked_dict:
            evoked_dict[condition].rename_channels(lambda x: x[:-4])

        color_dict = dict(HbO="#AA3377", HbR="b")
        styles_dict = dict(Control=dict(linestyle="dashed"), 
                           Noise=dict(linestyle="solid"),
                           Speech=dict(linestyle="dotted"))

        mne.viz.plot_compare_evokeds(
            evoked_dict, combine="mean", ci=0.95, colors=color_dict, styles=styles_dict
        ) """

        bad_ch = epochs.info['bads']
        epochs.drop_channels(bad_ch)
        hbo_data = epochs.copy().pick("hbo")
        #data = hbo_data.get_data(tmin=0, tmax=10).mean(axis=1)
        data = hbo_data.get_data().mean(axis=1)
        
        ev = epochs.events[:, 2]
        index_column = np.arange(0, len(ev)).reshape(-1, 1)
        updated_matrix = np.hstack((index_column, ev.reshape(-1, 1)))

        #time_slice = data[:, :, 26:105]
        mean_values = np.mean(data, axis=1)
        

        control_idx = updated_matrix[updated_matrix[:, 1] == 1][:, 0]
        noise_idx = updated_matrix[updated_matrix[:, 1] == 2][:, 0]
        speech_idx = updated_matrix[updated_matrix[:, 1] == 3][:, 0]

        control_mean = mean_values[control_idx]
        noise_mean = mean_values[noise_idx]
        speech_mean = mean_values[speech_idx]

        
        #  reject_epochs(data, subject, session, condition_name, stats_df, z_thresh=3.0, max_reject_ratio=1.0)
        
        cleaned_data, idx_dict = reject_epochs(
            data=control_mean,
            subject=subject_id,
            session=session_id,
            condition_name="Control",
            stats_df=stats_df,
            z_thresh=2,
            max_reject_ratio=1
        )
       
        CONTROL_GOOD_IDX = idx_dict["CONTROL_GOOD_IDX"]
        CONTROL_BAD_IDX = idx_dict["CONTROL_BAD_IDX"]
        
        cleaned_data, idx_dict = reject_epochs(
            data=noise_mean,
            subject=subject_id,
            session=session_id,
            condition_name="Noise",
            stats_df=stats_df,
            z_thresh=2,
            max_reject_ratio=1
        )
        NOISE_GOOD_IDX = idx_dict["NOISE_GOOD_IDX"]
        NOISE_BAD_IDX = idx_dict["NOISE_BAD_IDX"]
        
        cleaned_data, idx_dict = reject_epochs(
            data=speech_mean,
            subject=subject_id,
            session=session_id,
            condition_name="Speech",
            stats_df=stats_df,
            z_thresh=2,
            max_reject_ratio=1
        )
        
        SPEECH_GOOD_IDX = idx_dict["SPEECH_GOOD_IDX"]
        SPEECH_BAD_IDX = idx_dict["SPEECH_BAD_IDX"]
        
        print(f"Number of rejected Control epochs: {len(CONTROL_BAD_IDX)}")
        print(f"Number of rejected Noise epochs: {len(NOISE_BAD_IDX)}")
        print(f"Number of rejected Speech epochs: {len(SPEECH_BAD_IDX)}")

        raw_haemo = raw_haemo_bef.copy()

        ControlEvents_good = ControlEvents[CONTROL_GOOD_IDX]
        onsets_control = raw_haemo.times[ControlEvents_good[:, 0]]
        durations_control = [0] * len(onsets_control)
        descriptions_control = ['Control'] * len(onsets_control)
        good_annotations_control = Annotations(onset=onsets_control, duration=durations_control, description=descriptions_control)

        NoiseEvents_good = NoiseEvents[NOISE_GOOD_IDX]
        onsets_noise = raw_haemo.times[NoiseEvents_good[:, 0]]
        durations_noise = [0] * len(onsets_noise)
        descriptions_noise = ['Noise'] * len(onsets_noise)
        good_annotations_noise = Annotations(onset=onsets_noise, duration=durations_noise, description=descriptions_noise)

        SpeechEvents_good = SpeechEvents[SPEECH_GOOD_IDX]
        onsets_speech = raw_haemo.times[SpeechEvents_good[:, 0]]
        durations_speech = [0] * len(onsets_speech)
        descriptions_speech = ['Speech'] * len(onsets_speech)
        good_annotations_speech = Annotations(onset=onsets_speech, duration=durations_speech, description=descriptions_speech)

        combined_annotations = good_annotations_control + good_annotations_noise + good_annotations_speech
        raw_haemo.set_annotations(combined_annotations)
    else:
        
        raw_haemo = raw_haemo_bef.copy()

    # make that raw_heamo only have hbo channels
    raw_haemo= raw_haemo.pick("hbo")
    events, event_dict = mne.events_from_annotations(raw_haemo)
    isis, names = mne_nirs.experimental_design.longest_inter_annotation_interval(raw_haemo)
    design_matrix = make_first_level_design_matrix(
        raw_haemo,
        drift_model='cosine',
        high_pass=1/(2*max(isis)),
        hrf_model='spm',
        stim_dur=5.125
    )
    
    
    
    
    glm_est = run_glm(raw_haemo, design_matrix)

      
    # Define ROI channel pairs
    left = [[4, 2], [4, 3], [5, 2], [5, 3], [5, 4], [5, 5]]
    right = [[10, 9], [10, 10], [10, 11], [10, 12], [11, 11], [11, 12]]
    back = [[6, 6], [6, 8], [7, 6], [7, 7], [7, 8], [8, 7], [8, 8], [9, 8]] 
    front = [[1, 1], [2, 1], [3, 1], [3, 2], [12, 1]]
    
    speech_glm_fdr= [[4, 2], [4, 3], [5, 3], [6, 8] ,  [7, 7], [8, 7]]
    noise_glm_fdr=[[10, 11],[11, 12]] 
    speech_glm= [[4, 2], [4, 3], [5, 3],  [7, 7], [9, 8], [11, 11], [11, 12]]
    noise_glm= [[11, 11],[11, 12]]
    
    noise_waa_fdr= [[4, 2], [5, 2], [5, 3], [10, 9], [10, 10], [10, 11],[10, 12]]
    speech_waa_fdr= [[5, 2], [5, 4], [10, 9],[10, 10], [10, 11], [10, 12],  [11, 11]]
    noise_waa = [[11, 11]]
    speech_waa = [[5, 4], [10, 9],[10, 10], [10, 11],  [11, 11], [11, 12]]
    
    '''rois = {
    "Noise_WAA": [ "S10_D11 hbo", "S11_D11 hbo","S10_D9 hbo" ],
    "Speech_WAA": ["S10_D10 hbo", "S10_D11 hbo",  "S10_D12 hbo", "S10_D9 hbo", "S11_D11 hbo", "S11_D12 hbo", "S5_D4 hbo"],
    "Noise_GLM": ["S11_D11 hbo"],
    "Speech_GLM": ["S11_D11 hbo", "S11_D12 hbo", "S4_D2 hbo", "S4_D3 hbo", "S7_D7 hbo"],
    
    "Left_Auditory": ["S4_D2 hbo", "S4_D3 hbo", "S5_D2 hbo", "S5_D3 hbo", "S5_D4 hbo", "S5_D5 hbo"],
    "Right_Auditory": ["S10_D9 hbo", "S10_D10 hbo", "S10_D11 hbo", "S10_D12 hbo", "S11_D11 hbo", "S11_D12 hbo"],
    "Visual": ["S6_D6 hbo", "S6_D8 hbo", "S7_D6 hbo", "S7_D7 hbo","S8_D7 hbo", "S8_D8 hbo", "S9_D8 hbo", "S7_D8 hbo"],
    "Front": ["S1_D1 hbo", "S2_D1 hbo", "S3_D1 hbo", "S3_D2 hbo","S12_D1 hbo"] 
    }'''
   
    

    # Generate index picks for each ROI
    roi_picks = dict(
        Left= picks_pair_to_idx(raw_haemo, left, on_missing="ignore"),
        Right= picks_pair_to_idx(raw_haemo, right, on_missing="ignore"),
        Back= picks_pair_to_idx(raw_haemo, back, on_missing="ignore"),
        Front= picks_pair_to_idx(raw_haemo, front, on_missing="ignore"),
        
        Speech_glm= picks_pair_to_idx(raw_haemo, speech_glm, on_missing="ignore"),
        Noise_glm= picks_pair_to_idx(raw_haemo, noise_glm, on_missing="ignore"),
        Noise_waa= picks_pair_to_idx(raw_haemo, noise_waa, on_missing="ignore"),
        Speech_waa= picks_pair_to_idx(raw_haemo, speech_waa, on_missing="ignore"),  
        
        Speech_glm_fdr= picks_pair_to_idx(raw_haemo, speech_glm_fdr, on_missing="ignore"),
        Noise_glm_fdr= picks_pair_to_idx(raw_haemo, noise_glm_fdr, on_missing="ignore"),
        Speech_waa_fdr= picks_pair_to_idx(raw_haemo, speech_waa_fdr, on_missing="ignore"),
        Noise_waa_fdr= picks_pair_to_idx(raw_haemo, noise_waa_fdr, on_missing="ignore")
          
    )
   
    
    cha= glm_est.to_dataframe()
    
    roi= glm_est.to_dataframe_region_of_interest(
        roi_picks, design_matrix.columns, demographic_info=True
    )
    
    # Define left vs right tapping contrast
    contrast_matrix = np.eye(design_matrix.shape[1])
    basic_conts = dict(
        [(column, contrast_matrix[i]) for i, column in enumerate(design_matrix.columns)]
    )
    contrast_LvR_n = basic_conts["Noise"] - basic_conts["Control"]
    contrast_LvR_s = basic_conts["Speech"] - basic_conts["Control"]

    # Compute defined contrast
    contrast_n = glm_est.compute_contrast(contrast_LvR_n)
    contrast_s = glm_est.compute_contrast(contrast_LvR_s)
    con_n = contrast_n.to_dataframe()
    con_s = contrast_s.to_dataframe()

    # Add the participant sub to the dataframes
    roi["ID"] = cha["ID"] = con_n["ID"] = con_s["ID"] = id
    
    roi["Subject"] = cha["Subject"] = con_n["Subject"] = con_s["Subject"] = subject_id
    
    # Add the session to the dataframes
    roi["session"] = cha["session"] = con_n["session"] = con_s["session"] = session_id

    # Convert to uM for nicer plotting below.
    cha["theta"] = [t * 1.0e6 for t in cha["theta"]]
    roi["theta"] = [t * 1.0e6 for t in roi["theta"]]
    con_n["effect"] = [t * 1.0e6 for t in con_n["effect"]]
    con_s["effect"] = [t * 1.0e6 for t in con_s["effect"]]
    
    
    
    return raw_haemo, roi, cha, con_n, con_s

# %%
bids_root = r"C:\Datasets\Test-retest study\bids_dataset"
subject_list = sorted([d for d in os.listdir(bids_root) if d.startswith("sub-")])
subject_list = [s.replace("sub-", "") for s in subject_list]
#subject_list = subject_list[:1]  # Limit to first 3 subjects for testing

print("Detected subjects:", subject_list)
subjects_df = pd.DataFrame(columns=["subject", "session"])




#optode_subject_sessions = {optode: pd.DataFrame(columns=["subject", "session"]) for optode in optodes}

df_roi = pd.DataFrame()  # To store region of interest results
df_cha = pd.DataFrame()  # To store channel level results
df_con_noise = pd.DataFrame()  # To store channel level contrast results
df_con_speech = pd.DataFrame()  # To store channel level contrast results
id = 0
# Loop through subjects and sessions
for sub in subject_list:
    for ses in range(1, 3):
        
        bids_path = BIDSPath(
                subject=f"{sub}",
                session=f"{ses:02d}",
                task="auditory",
                datatype="nirs",
                root=bids_root,
                suffix="nirs",
                extension=".snirf",
            )
            
        raw_haemo, roi, cha, con_n, con_s = preprocessing_glm_ROI(bids_path, sub, f"{ses:02d}", id, apply_epoch_rejection=True)
        if raw_haemo is None:
            print(f"⚠️ No data for Subject {sub}, Session {ses:02d}. Skipping...")
            continue
        else:
            
            # Append individual results to all participants
            df_roi = pd.concat([df_roi, roi], ignore_index=True)
            df_cha = pd.concat([df_cha, cha], ignore_index=True)
            df_con_noise = pd.concat([df_con_noise, con_n], ignore_index=True)
            df_con_speech = pd.concat([df_con_speech, con_s], ignore_index=True)
            id= id + 1
                
# add a column to df_cha with the channel names without the "hbo" or "hbr" suffix
df_cha["Optode"] = df_cha["ch_name"].str.replace(" hbo", "").str.replace(" hbr", "")
# Out:
# Detected subjects: ['01', '02', '03', '04', '05', '07', '08', '10', '11', '12', '13', '16', '17', '19', '21', '24']
# Processing subject 01 session 01...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 1
# Processing subject 01 session 02...
# Number of rejected Control epochs: 2
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 1
# Processing subject 02 session 01...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 0
# Processing subject 02 session 02...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 0
# Processing subject 03 session 01...
# Number of rejected Control epochs: 0
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 0
# Processing subject 03 session 02...
# Number of rejected Control epochs: 0
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 0
# Processing subject 04 session 01...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 2
# Number of rejected Speech epochs: 1
# Processing subject 04 session 02...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 1
# Processing subject 05 session 01...
# Number of rejected Control epochs: 0
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 0
# Processing subject 05 session 02...
# Number of rejected Control epochs: 0
# Number of rejected Noise epochs: 0
# Number of rejected Speech epochs: 1
# Processing subject 07 session 01...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 2
# Processing subject 07 session 02...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 1
# Processing subject 08 session 01...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 2
# Processing subject 08 session 02...
# Number of rejected Control epochs: 2
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 1
# Processing subject 10 session 01...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 1
# Processing subject 10 session 02...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 0
# Number of rejected Speech epochs: 1
# Processing subject 11 session 01...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 0
# Number of rejected Speech epochs: 1
# Processing subject 11 session 02...
# Number of rejected Control epochs: 0
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 1
# Processing subject 12 session 01...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 0
# Number of rejected Speech epochs: 1
# Processing subject 12 session 02...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 1
# Processing subject 13 session 01...
# Number of rejected Control epochs: 0
# Number of rejected Noise epochs: 0
# Number of rejected Speech epochs: 0
# Processing subject 13 session 02...
# Number of rejected Control epochs: 0
# Number of rejected Noise epochs: 0
# Number of rejected Speech epochs: 0
# Processing subject 16 session 01...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 1
# Processing subject 16 session 02...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 0
# Number of rejected Speech epochs: 1
# Processing subject 17 session 01...
# Number of rejected Control epochs: 0
# Number of rejected Noise epochs: 0
# Number of rejected Speech epochs: 0
# Processing subject 17 session 02...
# Number of rejected Control epochs: 0
# Number of rejected Noise epochs: 0
# Number of rejected Speech epochs: 0
# Processing subject 19 session 01...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 0
# Processing subject 19 session 02...
# Number of rejected Control epochs: 0
# Number of rejected Noise epochs: 0
# Number of rejected Speech epochs: 0
# Processing subject 21 session 01...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 0
# Number of rejected Speech epochs: 0
# Processing subject 21 session 02...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 1
# Processing subject 24 session 01...
# Number of rejected Control epochs: 0
# Number of rejected Noise epochs: 0
# Number of rejected Speech epochs: 0
# Processing subject 24 session 02...
# Number of rejected Control epochs: 1
# Number of rejected Noise epochs: 1
# Number of rejected Speech epochs: 0

# %% [markdown]
# # GLM Data-driven ROIs Construction
# Single Optode Significance Analysis

# %%
def run_lme_per_session(df_cha, session_label):
    df_cha_q = df_cha.query("Condition in ['Control', 'Noise', 'Speech']")
    subset_session = df_cha_q[(df_cha_q["Chroma"] == "hbo") & (df_cha_q["session"] == session_label)]
    optodes = subset_session["Optode"].unique()
    #print(optodes)
    results_summary = []

    for opt in optodes:
        subset = subset_session[subset_session["Optode"] == opt]
        if subset["Condition"].nunique() < 2 or subset["Subject"].nunique() < 2:
            print(f"Skipping {opt} (Session {session_label}) due to insufficient data.")
            continue

        try:
            model = smf.mixedlm("theta ~ Condition", data=subset, groups=subset["Subject"])
            result = model.fit(method="nm")
            #print(result.summary())

            coef_s = result.params.get("Condition[T.Speech]", float('nan'))
            pval_s = result.pvalues.get("Condition[T.Speech]", float('nan'))

            coef_n = result.params.get("Condition[T.Noise]", float('nan'))
            pval_n = result.pvalues.get("Condition[T.Noise]", float('nan'))

            results_summary.append({
                "Optode": opt,
                "Coef_Condition[T.Noise]": coef_n,
                "PValue_Condition[T.Noise]": pval_n,
                "Coef_Condition[T.Speech]": coef_s,
                "PValue_Condition[T.Speech]": pval_s,
                "N_Subjects": subset["Subject"].nunique(),
                "N_Trials": len(subset),
                "Convergence": result.converged
            })

        except Exception as e:
            print(f"⚠️ Failed to fit model for {opt} (Session {session_label}): {e}")

    return pd.DataFrame(results_summary)

def run_lme_both_ses(df_cha):
    df_cha_q = df_cha.query("Condition in ['Control', 'Noise', 'Speech']")
    subset_session = df_cha_q[(df_cha_q["Chroma"] == "hbo")]
    optodes = subset_session["Optode"].unique()
    #print(optodes)
    results_summary = []

    for opt in optodes:
        subset = subset_session[subset_session["Optode"] == opt]
        if subset["Condition"].nunique() < 2 or subset["ID"].nunique() < 2:
            print(f"Skipping {opt}  due to insufficient data.")
            continue

        try:
            model = smf.mixedlm("theta ~ Condition", data=subset, groups=subset["ID"])
            result = model.fit(method="nm")
            #print(result.summary())

            coef_s = result.params.get("Condition[T.Speech]", float('nan'))
            pval_s = result.pvalues.get("Condition[T.Speech]", float('nan'))

            coef_n = result.params.get("Condition[T.Noise]", float('nan'))
            pval_n = result.pvalues.get("Condition[T.Noise]", float('nan'))

            results_summary.append({
                "Optode": opt,
                "Coef_Condition[T.Noise]": coef_n,
                "PValue_Condition[T.Noise]": pval_n,
                "Coef_Condition[T.Speech]": coef_s,
                "PValue_Condition[T.Speech]": pval_s,
                "N_Subjects": subset["ID"].nunique(),
                "N_Trials": len(subset),
                "Convergence": result.converged
            })

        except Exception as e:
            print(f"⚠️ Failed to fit model for {opt}: {e}")

    return pd.DataFrame(results_summary)

def get_significant_optodes_by_condition(results_df):
    speech_sig = results_df[results_df["PValue_Condition[T.Speech]"] < 0.05].copy()
    noise_sig = results_df[results_df["PValue_Condition[T.Noise]"] < 0.05].copy()

    if speech_sig.empty:
        print("No significant SPEECH optodes.")
    if noise_sig.empty:
        print("No significant NOISE optodes.")

    return speech_sig, noise_sig

# %%
# Run LME per session
results_ses01_df = run_lme_per_session(df_cha, session_label='01')
results_ses02_df = run_lme_per_session(df_cha, session_label='02')
results_both_ses_df = run_lme_both_ses(df_cha)

# Get significant optodes for each condition and session
speech_sig_ses01, noise_sig_ses01 = get_significant_optodes_by_condition(results_ses01_df)
speech_sig_ses02, noise_sig_ses02 = get_significant_optodes_by_condition(results_ses02_df)
speech_sig_both, noise_sig_both = get_significant_optodes_by_condition(results_both_ses_df)
# Out:
# c:\Users\sarab\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\sarab\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\sarab\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\sarab\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\sarab\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\sarab\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\sarab\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\sarab\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\sarab\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\sarab\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\sarab\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\sarab\anaconda3\envs\mne\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
m= 50
q=0.05
# get the p-values for noise both sessions
p_values = noise_sig_both["PValue_Condition[T.Noise]"].values
# sort the p-values
sorted_p_values = np.sort(p_values)
for i in range(0, len(sorted_p_values)):  
    p_val = sorted_p_values[i]     
    threshold= ((i+1)/m)*q
    
    # pass if p-value <= threshold
    if p_val <= threshold:
        print(f"Optode {noise_sig_both.iloc[i]['Optode']} is significant with p-value {p_val} and threshold {threshold}")
    else:
        print(f"Optode {noise_sig_both.iloc[i]['Optode']} is not significant with p-value {p_val} and threshold {threshold}")
# Out:
# Optode S10_D11 is significant with p-value 0.0007505965812488266 and threshold 0.001
# Optode S11_D11 is significant with p-value 0.0008984123204090398 and threshold 0.002
# Optode S11_D12 is not significant with p-value 0.01187734533335958 and threshold 0.003

# %%
m= 50
q=0.05
# get the p-values for noise both sessions
p_values = speech_sig_ses02["PValue_Condition[T.Speech]"].values
# sort the p-values
sorted_p_values = np.sort(p_values)
for i in range(0, len(sorted_p_values)):  
    p_val = sorted_p_values[i]     
    threshold= ((i+1)/m)*q
    
    # pass if p-value <= threshold
    if p_val <= threshold:
        print(f"Optode {speech_sig_ses02.iloc[i]['Optode']} is significant with p-value {p_val} and threshold {threshold}")
    else:
        print(f"Optode {speech_sig_ses02.iloc[i]['Optode']} is not significant with p-value {p_val} and threshold {threshold}")
# Out:
# Optode S3_D2 is significant with p-value 3.701055285945935e-05 and threshold 0.001
# Optode S4_D2 is significant with p-value 4.1622104150179673e-05 and threshold 0.002
# Optode S4_D3 is significant with p-value 0.00035938923700589104 and threshold 0.003
# Optode S7_D6 is significant with p-value 0.0023324583297107096 and threshold 0.004
# Optode S7_D7 is significant with p-value 0.003584715948396095 and threshold 0.005000000000000001
# Optode S7_D8 is not significant with p-value 0.012937050074732327 and threshold 0.006
# Optode S8_D7 is not significant with p-value 0.015219295906650629 and threshold 0.007000000000000001
# Optode S9_D8 is not significant with p-value 0.029973030507520752 and threshold 0.008
# Optode S10_D11 is not significant with p-value 0.03663743989883856 and threshold 0.009
# Optode S11_D11 is not significant with p-value 0.0434994992224901 and threshold 0.010000000000000002
# Optode S11_D12 is not significant with p-value 0.047547168152778825 and threshold 0.011000000000000001

# %%
# Find optodes significant in both sessions
common_speech_optodes = set(speech_sig_ses01["Optode"]) & set(speech_sig_ses02["Optode"])
common_noise_optodes = set(noise_sig_ses01["Optode"]) & set(noise_sig_ses02["Optode"])

# Print results
print("\nCommon significant optodes for SPEECH (p < 0.05 in both sessions):")
if common_speech_optodes:
    for opt in sorted(common_speech_optodes):
        print(f" - {opt}")
else:
    print("None found.")

print("\nCommon significant optodes for NOISE (p < 0.05 in both sessions):")
if common_noise_optodes:
    for opt in sorted(common_noise_optodes):
        print(f" - {opt}")
else:
    print("None found.")
# Out:
# Common significant optodes for SPEECH (p < 0.05 in both sessions):
#  - S11_D11
#  - S11_D12
#  - S4_D2
#  - S4_D3
#  - S7_D7
#  - S9_D8
#
# Common significant optodes for NOISE (p < 0.05 in both sessions):
#  - S11_D11
#  - S11_D12

# %% [markdown]
# # GLM Individual Level Analysis (pre-defined vs data-driven ROIs)

# %%
# For the Individual Analysis of the GLM we are just going to go over df_roi and compare the thetha values for each condition on each ROI for each subject-session. 
# If the theta value in noise or speech is higher than the control, we will consider it significant.
def get_individual_significant_rois(df_roi):
    df_hbo = df_roi[df_roi["Chroma"] == "hbo"].copy()
    
    results = []

    grouped = df_hbo.groupby(["Subject", "session", "ROI"])

    for (subj, sess, roi), group in grouped:
        try:
            theta_control = group[group["Condition"] == "Control"]["theta"].values[0]
        except IndexError:
            continue  # Skip if Control condition is missing

        theta_noise = group[group["Condition"] == "Noise"]["theta"]
        theta_speech = group[group["Condition"] == "Speech"]["theta"]

        is_noise_significant = False
        is_speech_significant = False

        if not theta_noise.empty:
            is_noise_significant = theta_noise.values[0] > theta_control

        if not theta_speech.empty:
            is_speech_significant = theta_speech.values[0] > theta_control

        results.append({
            "Subject": subj,
            "Session": sess,
            "ROI": roi,
            "Theta_Control": theta_control,
            "Theta_Noise": theta_noise.values[0] if not theta_noise.empty else None,
            "Theta_Speech": theta_speech.values[0] if not theta_speech.empty else None,
            "Significant_Noise": is_noise_significant,
            "Significant_Speech": is_speech_significant
        })

    return pd.DataFrame(results)


individual_roi_results = get_individual_significant_rois(df_roi)

# %%
def summarize_activation_by_roi(individual_roi_results, condition="Noise"):
    assert condition in ["Noise", "Speech"], "Condition must be 'Noise' or 'Speech'"

    col = f"Significant_{condition}"
    filtered = individual_roi_results[individual_roi_results[col]]

    summary = (
        filtered.groupby("ROI")
        .apply(lambda df: {
            "N_Activated_SubSess": df[["Subject", "Session"]].drop_duplicates().shape[0],
            "Activated_SubSess": sorted([f"{sub}-{sess}" for sub, sess in df[["Subject", "Session"]].drop_duplicates().values])
        })
        .apply(pd.Series)
        .reset_index()
    )

    return summary

# Run summarization for each condition
summary_noise = summarize_activation_by_roi(individual_roi_results, condition="Noise")
summary_speech = summarize_activation_by_roi(individual_roi_results, condition="Speech")

print("=== Noise ===")
print(summary_noise[["ROI", "N_Activated_SubSess"]])

print("\n=== Speech ===")
print(summary_speech[["ROI", "N_Activated_SubSess"]])
# Out:
# === Noise ===
#           ROI  N_Activated_SubSess
# 0        Back                    7
# 1       Front                   14
# 2        Left                   15
# 3   Noise_glm                   26
# 4   Noise_waa                   26
# 5       Right                   27
# 6  Speech_glm                   23
# 7  Speech_waa                   26
#
# === Speech ===
#           ROI  N_Activated_SubSess
# 0        Back                    7
# 1       Front                   15
# 2        Left                   21
# 3   Noise_glm                   26
# 4   Noise_waa                   22
# 5       Right                   24
# 6  Speech_glm                   27
# 7  Speech_waa                   24

# %% [markdown]
# ## Rquantity and Roverlap

# %% [markdown]
# New approach --> look at contrasts!!

# %% [markdown]
# ### Control vs Noise

# %%
# Filter for significant optodes
df_sig = df_con_noise[df_con_noise["Significant"] == True]

# Group by subject and session, and collect the channel names
summary = (
    df_sig.groupby(["Subject", "session"])["ch_name"]
    .apply(list)
    .reset_index()
)

# Display the summary
for _, row in summary.iterrows():
    subject = row["Subject"]
    session = row["session"]
    channels = row["ch_name"]
    print(f"Subject {subject}, Session {session} — Significant channels:")
    for ch in channels:
        print(f"  - {ch}")
    print()  # Add a blank line between subjects
# Out:
# Subject 01, Session 01 — Significant channels:
#   - S1_D1 hbo
#   - S10_D12 hbo
#
# Subject 01, Session 02 — Significant channels:
#   - S2_D1 hbo
#   - S10_D11 hbo
#   - S11_D11 hbo
#
# Subject 02, Session 02 — Significant channels:
#   - S1_D1 hbo
#   - S2_D1 hbo
#   - S3_D1 hbo
#   - S5_D2 hbo
#   - S5_D4 hbo
#   - S8_D8 hbo
#   - S9_D8 hbo
#   - S10_D10 hbo
#   - S10_D11 hbo
#   - S12_D1 hbo
#
# Subject 03, Session 01 — Significant channels:
#   - S11_D11 hbo
#
# Subject 04, Session 01 — Significant channels:
#   - S6_D6 hbo
#   - S10_D12 hbo
#   - S11_D12 hbo
#
# Subject 05, Session 01 — Significant channels:
#   - S3_D2 hbo
#   - S4_D2 hbo
#   - S5_D3 hbo
#   - S8_D8 hbo
#   - S10_D9 hbo
#   - S10_D11 hbo
#   - S10_D12 hbo
#   - S11_D11 hbo
#   - S12_D1 hbo
#
# Subject 05, Session 02 — Significant channels:
#   - S1_D1 hbo
#   - S4_D2 hbo
#   - S5_D2 hbo
#   - S5_D3 hbo
#   - S5_D4 hbo
#   - S7_D6 hbo
#   - S7_D7 hbo
#   - S7_D8 hbo
#   - S8_D7 hbo
#   - S8_D8 hbo
#   - S10_D9 hbo
#   - S10_D10 hbo
#   - S10_D11 hbo
#   - S11_D11 hbo
#   - S11_D12 hbo
#   - S12_D1 hbo
#
# Subject 07, Session 01 — Significant channels:
#   - S6_D6 hbo
#   - S10_D9 hbo
#   - S10_D11 hbo
#   - S11_D11 hbo
#
# Subject 07, Session 02 — Significant channels:
#   - S1_D1 hbo
#   - S4_D3 hbo
#   - S8_D7 hbo
#   - S8_D8 hbo
#   - S10_D10 hbo
#   - S10_D11 hbo
#   - S11_D11 hbo
#   - S12_D1 hbo
#
# Subject 08, Session 01 — Significant channels:
#   - S10_D9 hbo
#   - S10_D10 hbo
#   - S10_D11 hbo
#   - S10_D12 hbo
#   - S11_D11 hbo
#   - S11_D12 hbo
#
# Subject 08, Session 02 — Significant channels:
#   - S3_D2 hbo
#   - S4_D2 hbo
#   - S5_D4 hbo
#   - S6_D6 hbo
#   - S10_D10 hbo
#   - S10_D12 hbo
#   - S11_D11 hbo
#
# Subject 10, Session 01 — Significant channels:
#   - S1_D1 hbo
#   - S3_D2 hbo
#   - S4_D2 hbo
#   - S4_D3 hbo
#   - S5_D2 hbo
#   - S5_D3 hbo
#   - S5_D4 hbo
#   - S5_D5 hbo
#   - S7_D6 hbo
#   - S7_D7 hbo
#   - S7_D8 hbo
#   - S8_D7 hbo
#   - S8_D8 hbo
#   - S10_D9 hbo
#   - S10_D10 hbo
#   - S10_D11 hbo
#   - S10_D12 hbo
#   - S11_D11 hbo
#   - S11_D12 hbo
#   - S12_D1 hbo
#
# Subject 10, Session 02 — Significant channels:
#   - S2_D1 hbo
#   - S6_D8 hbo
#   - S7_D7 hbo
#   - S10_D11 hbo
#   - S10_D12 hbo
#   - S11_D12 hbo
#
# Subject 11, Session 01 — Significant channels:
#   - S1_D1 hbo
#   - S4_D2 hbo
#   - S7_D6 hbo
#   - S7_D8 hbo
#   - S11_D11 hbo
#   - S11_D12 hbo
#
# Subject 11, Session 02 — Significant channels:
#   - S1_D1 hbo
#   - S2_D1 hbo
#   - S3_D1 hbo
#   - S3_D2 hbo
#   - S4_D3 hbo
#   - S5_D4 hbo
#   - S5_D5 hbo
#   - S6_D6 hbo
#   - S8_D7 hbo
#   - S9_D8 hbo
#   - S11_D11 hbo
#   - S11_D12 hbo
#   - S12_D1 hbo
#
# Subject 12, Session 01 — Significant channels:
#   - S10_D12 hbo
#   - S11_D11 hbo
#   - S11_D12 hbo
#
# Subject 12, Session 02 — Significant channels:
#   - S7_D8 hbo
#   - S10_D11 hbo
#   - S11_D11 hbo
#   - S11_D12 hbo
#
# Subject 13, Session 01 — Significant channels:
#   - S6_D6 hbo
#   - S6_D8 hbo
#   - S10_D9 hbo
#   - S10_D11 hbo
#   - S12_D1 hbo
#
# Subject 13, Session 02 — Significant channels:
#   - S11_D11 hbo
#
# Subject 16, Session 01 — Significant channels:
#   - S2_D1 hbo
#   - S5_D3 hbo
#   - S5_D4 hbo
#   - S5_D5 hbo
#   - S6_D8 hbo
#   - S10_D9 hbo
#   - S10_D10 hbo
#   - S10_D12 hbo
#   - S12_D1 hbo
#
# Subject 16, Session 02 — Significant channels:
#   - S12_D1 hbo
#
# Subject 17, Session 01 — Significant channels:
#   - S1_D1 hbo
#   - S2_D1 hbo
#   - S4_D2 hbo
#   - S7_D8 hbo
#   - S8_D7 hbo
#   - S10_D12 hbo
#   - S11_D11 hbo
#   - S12_D1 hbo
#
# Subject 17, Session 02 — Significant channels:
#   - S1_D1 hbo
#   - S7_D6 hbo
#   - S10_D9 hbo
#   - S10_D10 hbo
#   - S11_D11 hbo
#
# Subject 19, Session 01 — Significant channels:
#   - S11_D11 hbo
#   - S11_D12 hbo
#
# Subject 19, Session 02 — Significant channels:
#   - S1_D1 hbo
#   - S2_D1 hbo
#   - S5_D3 hbo
#   - S5_D4 hbo
#   - S5_D5 hbo
#   - S7_D8 hbo
#   - S8_D7 hbo
#   - S10_D9 hbo
#   - S10_D12 hbo
#   - S11_D11 hbo
#   - S11_D12 hbo
#   - S12_D1 hbo
#
# Subject 21, Session 01 — Significant channels:
#   - S2_D1 hbo
#   - S3_D2 hbo
#   - S5_D3 hbo
#   - S11_D12 hbo
#
# Subject 21, Session 02 — Significant channels:
#   - S5_D3 hbo
#   - S5_D5 hbo
#   - S6_D6 hbo
#   - S9_D8 hbo
#   - S10_D11 hbo
#
# Subject 24, Session 01 — Significant channels:
#   - S6_D8 hbo
#   - S7_D6 hbo
#   - S11_D12 hbo
#
# Subject 24, Session 02 — Significant channels:
#   - S4_D2 hbo
#   - S6_D6 hbo
#   - S8_D8 hbo
#   - S10_D11 hbo
#   - S11_D11 hbo

# %%
# Filter for significant optodes only
df_sig = df_con_noise[df_con_noise["Significant"] == True]

# Get unique subjects
subjects = df_sig["Subject"].unique()

# For each subject, calculate R_overlap
for subj in sorted(subjects):
    # Filter data for the subject
    subj_data = df_sig[df_sig["Subject"] == subj]
    
    # FDR
    q = 0.05
    m = 25 # Total number of unique channels
    # run on each session separately

    for session in ["01", "02"]:
        df_ses = subj_data[(subj_data["session"] == session)]
        p_values = df_ses["p_value"].values
        sorted_p_values = np.sort(p_values)
        
        for i in range(len(sorted_p_values)):
            p_val = sorted_p_values[i]
            threshold = (q * (i + 1)) / m
            
            if p_val <= threshold:
                print(f"Subject {subj}  Session {session} - Channel {df_ses.iloc[i]['ch_name']} is significant with p-value {p_val:.4f} and threshold {threshold:.4f}")
            else:
                print(f"Subject {subj} Session {session} - Channel {df_ses.iloc[i]['ch_name']} is not significant with p-value {p_val:.4f} and threshold {threshold:.4f}")
        
        

    # Get channels for each session
    ses1_channels = set(subj_data[subj_data["session"] == "01"]["ch_name"])
    ses2_channels = set(subj_data[subj_data["session"] == "02"]["ch_name"])

    # Calculate activation quantities
    A1 = len(ses1_channels)
    A2 = len(ses2_channels)
    A_overlap = len(ses1_channels.intersection(ses2_channels))

    # Compute R_overlap safely (avoid division by zero)
    if (A1 + A2) > 0:
        R_quantity= 1- ((abs(A1 - A2) )/ (A1 + A2))
        R_overlap = (2 * A_overlap) / (A1 + A2)
    else:
        R_quantity = float('nan') 
        R_overlap = float('nan')

    print(f"Subject {subj}")
    print(f"  Session 01 significant channels ({A1}): {sorted(ses1_channels)}")
    print(f"  Session 02 significant channels ({A2}): {sorted(ses2_channels)}")
    print(f"  Overlapping channels ({A_overlap}): {sorted(ses1_channels.intersection(ses2_channels))}")
    print(f"  R_overlap: {R_overlap:.3f}")
    print(f"  R_quantity: {R_quantity:.3f}")
    print()
# Out:
# Subject 01  Session 01 - Channel S1_D1 hbo is significant with p-value 0.0003 and threshold 0.0020
# Subject 01 Session 01 - Channel S10_D12 hbo is not significant with p-value 0.0345 and threshold 0.0040
# Subject 01  Session 02 - Channel S2_D1 hbo is significant with p-value 0.0001 and threshold 0.0020
# Subject 01  Session 02 - Channel S10_D11 hbo is significant with p-value 0.0002 and threshold 0.0040
# Subject 01 Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0313 and threshold 0.0060
# Subject 01
#   Session 01 significant channels (2): ['S10_D12 hbo', 'S1_D1 hbo']
#   Session 02 significant channels (3): ['S10_D11 hbo', 'S11_D11 hbo', 'S2_D1 hbo']
#   Overlapping channels (0): []
#   R_overlap: 0.000
#   R_quantity: 0.800
#
# Subject 02  Session 02 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 02  Session 02 - Channel S2_D1 hbo is significant with p-value 0.0001 and threshold 0.0040
# Subject 02  Session 02 - Channel S3_D1 hbo is significant with p-value 0.0002 and threshold 0.0060
# Subject 02  Session 02 - Channel S5_D2 hbo is significant with p-value 0.0018 and threshold 0.0080
# Subject 02  Session 02 - Channel S5_D4 hbo is significant with p-value 0.0060 and threshold 0.0100
# Subject 02  Session 02 - Channel S8_D8 hbo is significant with p-value 0.0095 and threshold 0.0120
# Subject 02  Session 02 - Channel S9_D8 hbo is significant with p-value 0.0114 and threshold 0.0140
# Subject 02 Session 02 - Channel S10_D10 hbo is not significant with p-value 0.0174 and threshold 0.0160
# Subject 02  Session 02 - Channel S10_D11 hbo is significant with p-value 0.0176 and threshold 0.0180
# Subject 02 Session 02 - Channel S12_D1 hbo is not significant with p-value 0.0276 and threshold 0.0200
# Subject 02
#   Session 01 significant channels (0): []
#   Session 02 significant channels (10): ['S10_D10 hbo', 'S10_D11 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S2_D1 hbo', 'S3_D1 hbo', 'S5_D2 hbo', 'S5_D4 hbo', 'S8_D8 hbo', 'S9_D8 hbo']
#   Overlapping channels (0): []
#   R_overlap: 0.000
#   R_quantity: 0.000
#
# Subject 03  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0016 and threshold 0.0020
# Subject 03
#   Session 01 significant channels (1): ['S11_D11 hbo']
#   Session 02 significant channels (0): []
#   Overlapping channels (0): []
#   R_overlap: 0.000
#   R_quantity: 0.000
#
# Subject 04  Session 01 - Channel S6_D6 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 04  Session 01 - Channel S10_D12 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 04  Session 01 - Channel S11_D12 hbo is significant with p-value 0.0010 and threshold 0.0060
# Subject 04
#   Session 01 significant channels (3): ['S10_D12 hbo', 'S11_D12 hbo', 'S6_D6 hbo']
#   Session 02 significant channels (0): []
#   Overlapping channels (0): []
#   R_overlap: 0.000
#   R_quantity: 0.000
#
# Subject 05  Session 01 - Channel S3_D2 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 05  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 05  Session 01 - Channel S5_D3 hbo is significant with p-value 0.0001 and threshold 0.0060
# Subject 05  Session 01 - Channel S8_D8 hbo is significant with p-value 0.0002 and threshold 0.0080
# Subject 05  Session 01 - Channel S10_D9 hbo is significant with p-value 0.0002 and threshold 0.0100
# Subject 05  Session 01 - Channel S10_D11 hbo is significant with p-value 0.0003 and threshold 0.0120
# Subject 05  Session 01 - Channel S10_D12 hbo is significant with p-value 0.0022 and threshold 0.0140
# Subject 05  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0076 and threshold 0.0160
# Subject 05  Session 01 - Channel S12_D1 hbo is significant with p-value 0.0126 and threshold 0.0180
# Subject 05  Session 02 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 05  Session 02 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 05  Session 02 - Channel S5_D2 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 05  Session 02 - Channel S5_D3 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 05  Session 02 - Channel S5_D4 hbo is significant with p-value 0.0000 and threshold 0.0100
# Subject 05  Session 02 - Channel S7_D6 hbo is significant with p-value 0.0000 and threshold 0.0120
# Subject 05  Session 02 - Channel S7_D7 hbo is significant with p-value 0.0000 and threshold 0.0140
# Subject 05  Session 02 - Channel S7_D8 hbo is significant with p-value 0.0000 and threshold 0.0160
# Subject 05  Session 02 - Channel S8_D7 hbo is significant with p-value 0.0001 and threshold 0.0180
# Subject 05  Session 02 - Channel S8_D8 hbo is significant with p-value 0.0004 and threshold 0.0200
# Subject 05  Session 02 - Channel S10_D9 hbo is significant with p-value 0.0005 and threshold 0.0220
# Subject 05  Session 02 - Channel S10_D10 hbo is significant with p-value 0.0012 and threshold 0.0240
# Subject 05  Session 02 - Channel S10_D11 hbo is significant with p-value 0.0014 and threshold 0.0260
# Subject 05  Session 02 - Channel S11_D11 hbo is significant with p-value 0.0026 and threshold 0.0280
# Subject 05  Session 02 - Channel S11_D12 hbo is significant with p-value 0.0062 and threshold 0.0300
# Subject 05  Session 02 - Channel S12_D1 hbo is significant with p-value 0.0196 and threshold 0.0320
# Subject 05
#   Session 01 significant channels (9): ['S10_D11 hbo', 'S10_D12 hbo', 'S10_D9 hbo', 'S11_D11 hbo', 'S12_D1 hbo', 'S3_D2 hbo', 'S4_D2 hbo', 'S5_D3 hbo', 'S8_D8 hbo']
#   Session 02 significant channels (16): ['S10_D10 hbo', 'S10_D11 hbo', 'S10_D9 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S4_D2 hbo', 'S5_D2 hbo', 'S5_D3 hbo', 'S5_D4 hbo', 'S7_D6 hbo', 'S7_D7 hbo', 'S7_D8 hbo', 'S8_D7 hbo', 'S8_D8 hbo']
#   Overlapping channels (7): ['S10_D11 hbo', 'S10_D9 hbo', 'S11_D11 hbo', 'S12_D1 hbo', 'S4_D2 hbo', 'S5_D3 hbo', 'S8_D8 hbo']
#   R_overlap: 0.560
#   R_quantity: 0.720
#
# Subject 07  Session 01 - Channel S6_D6 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 07  Session 01 - Channel S10_D9 hbo is significant with p-value 0.0001 and threshold 0.0040
# Subject 07  Session 01 - Channel S10_D11 hbo is significant with p-value 0.0005 and threshold 0.0060
# Subject 07 Session 01 - Channel S11_D11 hbo is not significant with p-value 0.0087 and threshold 0.0080
# Subject 07  Session 02 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 07  Session 02 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 07  Session 02 - Channel S8_D7 hbo is significant with p-value 0.0001 and threshold 0.0060
# Subject 07  Session 02 - Channel S8_D8 hbo is significant with p-value 0.0002 and threshold 0.0080
# Subject 07  Session 02 - Channel S10_D10 hbo is significant with p-value 0.0009 and threshold 0.0100
# Subject 07  Session 02 - Channel S10_D11 hbo is significant with p-value 0.0120 and threshold 0.0120
# Subject 07 Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0313 and threshold 0.0140
# Subject 07 Session 02 - Channel S12_D1 hbo is not significant with p-value 0.0395 and threshold 0.0160
# Subject 07
#   Session 01 significant channels (4): ['S10_D11 hbo', 'S10_D9 hbo', 'S11_D11 hbo', 'S6_D6 hbo']
#   Session 02 significant channels (8): ['S10_D10 hbo', 'S10_D11 hbo', 'S11_D11 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S4_D3 hbo', 'S8_D7 hbo', 'S8_D8 hbo']
#   Overlapping channels (2): ['S10_D11 hbo', 'S11_D11 hbo']
#   R_overlap: 0.333
#   R_quantity: 0.667
#
# Subject 08  Session 01 - Channel S10_D9 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 08  Session 01 - Channel S10_D10 hbo is significant with p-value 0.0004 and threshold 0.0040
# Subject 08  Session 01 - Channel S10_D11 hbo is significant with p-value 0.0005 and threshold 0.0060
# Subject 08  Session 01 - Channel S10_D12 hbo is significant with p-value 0.0011 and threshold 0.0080
# Subject 08  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0067 and threshold 0.0100
# Subject 08  Session 01 - Channel S11_D12 hbo is significant with p-value 0.0092 and threshold 0.0120
# Subject 08  Session 02 - Channel S3_D2 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 08  Session 02 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 08  Session 02 - Channel S5_D4 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 08  Session 02 - Channel S6_D6 hbo is significant with p-value 0.0001 and threshold 0.0080
# Subject 08  Session 02 - Channel S10_D10 hbo is significant with p-value 0.0001 and threshold 0.0100
# Subject 08 Session 02 - Channel S10_D12 hbo is not significant with p-value 0.0384 and threshold 0.0120
# Subject 08 Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0388 and threshold 0.0140
# Subject 08
#   Session 01 significant channels (6): ['S10_D10 hbo', 'S10_D11 hbo', 'S10_D12 hbo', 'S10_D9 hbo', 'S11_D11 hbo', 'S11_D12 hbo']
#   Session 02 significant channels (7): ['S10_D10 hbo', 'S10_D12 hbo', 'S11_D11 hbo', 'S3_D2 hbo', 'S4_D2 hbo', 'S5_D4 hbo', 'S6_D6 hbo']
#   Overlapping channels (3): ['S10_D10 hbo', 'S10_D12 hbo', 'S11_D11 hbo']
#   R_overlap: 0.462
#   R_quantity: 0.923
#
# Subject 10  Session 01 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 10  Session 01 - Channel S3_D2 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 10  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 10  Session 01 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 10  Session 01 - Channel S5_D2 hbo is significant with p-value 0.0000 and threshold 0.0100
# Subject 10  Session 01 - Channel S5_D3 hbo is significant with p-value 0.0000 and threshold 0.0120
# Subject 10  Session 01 - Channel S5_D4 hbo is significant with p-value 0.0000 and threshold 0.0140
# Subject 10  Session 01 - Channel S5_D5 hbo is significant with p-value 0.0000 and threshold 0.0160
# Subject 10  Session 01 - Channel S7_D6 hbo is significant with p-value 0.0000 and threshold 0.0180
# Subject 10  Session 01 - Channel S7_D7 hbo is significant with p-value 0.0000 and threshold 0.0200
# Subject 10  Session 01 - Channel S7_D8 hbo is significant with p-value 0.0000 and threshold 0.0220
# Subject 10  Session 01 - Channel S8_D7 hbo is significant with p-value 0.0000 and threshold 0.0240
# Subject 10  Session 01 - Channel S8_D8 hbo is significant with p-value 0.0000 and threshold 0.0260
# Subject 10  Session 01 - Channel S10_D9 hbo is significant with p-value 0.0001 and threshold 0.0280
# Subject 10  Session 01 - Channel S10_D10 hbo is significant with p-value 0.0012 and threshold 0.0300
# Subject 10  Session 01 - Channel S10_D11 hbo is significant with p-value 0.0030 and threshold 0.0320
# Subject 10  Session 01 - Channel S10_D12 hbo is significant with p-value 0.0032 and threshold 0.0340
# Subject 10  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0244 and threshold 0.0360
# Subject 10  Session 01 - Channel S11_D12 hbo is significant with p-value 0.0342 and threshold 0.0380
# Subject 10 Session 01 - Channel S12_D1 hbo is not significant with p-value 0.0464 and threshold 0.0400
# Subject 10  Session 02 - Channel S2_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 10  Session 02 - Channel S6_D8 hbo is significant with p-value 0.0012 and threshold 0.0040
# Subject 10  Session 02 - Channel S7_D7 hbo is significant with p-value 0.0016 and threshold 0.0060
# Subject 10 Session 02 - Channel S10_D11 hbo is not significant with p-value 0.0236 and threshold 0.0080
# Subject 10 Session 02 - Channel S10_D12 hbo is not significant with p-value 0.0255 and threshold 0.0100
# Subject 10 Session 02 - Channel S11_D12 hbo is not significant with p-value 0.0284 and threshold 0.0120
# Subject 10
#   Session 01 significant channels (20): ['S10_D10 hbo', 'S10_D11 hbo', 'S10_D12 hbo', 'S10_D9 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S3_D2 hbo', 'S4_D2 hbo', 'S4_D3 hbo', 'S5_D2 hbo', 'S5_D3 hbo', 'S5_D4 hbo', 'S5_D5 hbo', 'S7_D6 hbo', 'S7_D7 hbo', 'S7_D8 hbo', 'S8_D7 hbo', 'S8_D8 hbo']
#   Session 02 significant channels (6): ['S10_D11 hbo', 'S10_D12 hbo', 'S11_D12 hbo', 'S2_D1 hbo', 'S6_D8 hbo', 'S7_D7 hbo']
#   Overlapping channels (4): ['S10_D11 hbo', 'S10_D12 hbo', 'S11_D12 hbo', 'S7_D7 hbo']
#   R_overlap: 0.308
#   R_quantity: 0.462
#
# Subject 11  Session 01 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 11  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 11  Session 01 - Channel S7_D6 hbo is significant with p-value 0.0002 and threshold 0.0060
# Subject 11 Session 01 - Channel S7_D8 hbo is not significant with p-value 0.0134 and threshold 0.0080
# Subject 11 Session 01 - Channel S11_D11 hbo is not significant with p-value 0.0342 and threshold 0.0100
# Subject 11 Session 01 - Channel S11_D12 hbo is not significant with p-value 0.0371 and threshold 0.0120
# Subject 11  Session 02 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 11  Session 02 - Channel S2_D1 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 11  Session 02 - Channel S3_D1 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 11  Session 02 - Channel S3_D2 hbo is significant with p-value 0.0001 and threshold 0.0080
# Subject 11  Session 02 - Channel S4_D3 hbo is significant with p-value 0.0003 and threshold 0.0100
# Subject 11  Session 02 - Channel S5_D4 hbo is significant with p-value 0.0003 and threshold 0.0120
# Subject 11  Session 02 - Channel S5_D5 hbo is significant with p-value 0.0005 and threshold 0.0140
# Subject 11  Session 02 - Channel S6_D6 hbo is significant with p-value 0.0007 and threshold 0.0160
# Subject 11  Session 02 - Channel S8_D7 hbo is significant with p-value 0.0038 and threshold 0.0180
# Subject 11  Session 02 - Channel S9_D8 hbo is significant with p-value 0.0085 and threshold 0.0200
# Subject 11  Session 02 - Channel S11_D11 hbo is significant with p-value 0.0128 and threshold 0.0220
# Subject 11  Session 02 - Channel S11_D12 hbo is significant with p-value 0.0133 and threshold 0.0240
# Subject 11 Session 02 - Channel S12_D1 hbo is not significant with p-value 0.0269 and threshold 0.0260
# Subject 11
#   Session 01 significant channels (6): ['S11_D11 hbo', 'S11_D12 hbo', 'S1_D1 hbo', 'S4_D2 hbo', 'S7_D6 hbo', 'S7_D8 hbo']
#   Session 02 significant channels (13): ['S11_D11 hbo', 'S11_D12 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S2_D1 hbo', 'S3_D1 hbo', 'S3_D2 hbo', 'S4_D3 hbo', 'S5_D4 hbo', 'S5_D5 hbo', 'S6_D6 hbo', 'S8_D7 hbo', 'S9_D8 hbo']
#   Overlapping channels (3): ['S11_D11 hbo', 'S11_D12 hbo', 'S1_D1 hbo']
#   R_overlap: 0.316
#   R_quantity: 0.632
#
# Subject 12  Session 01 - Channel S10_D12 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 12  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 12 Session 01 - Channel S11_D12 hbo is not significant with p-value 0.0095 and threshold 0.0060
# Subject 12 Session 02 - Channel S7_D8 hbo is not significant with p-value 0.0051 and threshold 0.0020
# Subject 12 Session 02 - Channel S10_D11 hbo is not significant with p-value 0.0180 and threshold 0.0040
# Subject 12 Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0390 and threshold 0.0060
# Subject 12 Session 02 - Channel S11_D12 hbo is not significant with p-value 0.0406 and threshold 0.0080
# Subject 12
#   Session 01 significant channels (3): ['S10_D12 hbo', 'S11_D11 hbo', 'S11_D12 hbo']
#   Session 02 significant channels (4): ['S10_D11 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S7_D8 hbo']
#   Overlapping channels (2): ['S11_D11 hbo', 'S11_D12 hbo']
#   R_overlap: 0.571
#   R_quantity: 0.857
#
# Subject 13  Session 01 - Channel S6_D6 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 13  Session 01 - Channel S6_D8 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 13  Session 01 - Channel S10_D9 hbo is significant with p-value 0.0012 and threshold 0.0060
# Subject 13 Session 01 - Channel S10_D11 hbo is not significant with p-value 0.0145 and threshold 0.0080
# Subject 13 Session 01 - Channel S12_D1 hbo is not significant with p-value 0.0207 and threshold 0.0100
# Subject 13 Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0410 and threshold 0.0020
# Subject 13
#   Session 01 significant channels (5): ['S10_D11 hbo', 'S10_D9 hbo', 'S12_D1 hbo', 'S6_D6 hbo', 'S6_D8 hbo']
#   Session 02 significant channels (1): ['S11_D11 hbo']
#   Overlapping channels (0): []
#   R_overlap: 0.000
#   R_quantity: 0.333
#
# Subject 16  Session 01 - Channel S2_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 16  Session 01 - Channel S5_D3 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 16  Session 01 - Channel S5_D4 hbo is significant with p-value 0.0001 and threshold 0.0060
# Subject 16  Session 01 - Channel S5_D5 hbo is significant with p-value 0.0023 and threshold 0.0080
# Subject 16  Session 01 - Channel S6_D8 hbo is significant with p-value 0.0041 and threshold 0.0100
# Subject 16  Session 01 - Channel S10_D9 hbo is significant with p-value 0.0064 and threshold 0.0120
# Subject 16  Session 01 - Channel S10_D10 hbo is significant with p-value 0.0137 and threshold 0.0140
# Subject 16  Session 01 - Channel S10_D12 hbo is significant with p-value 0.0157 and threshold 0.0160
# Subject 16 Session 01 - Channel S12_D1 hbo is not significant with p-value 0.0496 and threshold 0.0180
# Subject 16  Session 02 - Channel S12_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 16
#   Session 01 significant channels (9): ['S10_D10 hbo', 'S10_D12 hbo', 'S10_D9 hbo', 'S12_D1 hbo', 'S2_D1 hbo', 'S5_D3 hbo', 'S5_D4 hbo', 'S5_D5 hbo', 'S6_D8 hbo']
#   Session 02 significant channels (1): ['S12_D1 hbo']
#   Overlapping channels (1): ['S12_D1 hbo']
#   R_overlap: 0.200
#   R_quantity: 0.200
#
# Subject 17  Session 01 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 17  Session 01 - Channel S2_D1 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 17  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 17  Session 01 - Channel S7_D8 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 17  Session 01 - Channel S8_D7 hbo is significant with p-value 0.0005 and threshold 0.0100
# Subject 17  Session 01 - Channel S10_D12 hbo is significant with p-value 0.0010 and threshold 0.0120
# Subject 17  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0089 and threshold 0.0140
# Subject 17 Session 01 - Channel S12_D1 hbo is not significant with p-value 0.0195 and threshold 0.0160
# Subject 17  Session 02 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 17  Session 02 - Channel S7_D6 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 17  Session 02 - Channel S10_D9 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 17  Session 02 - Channel S10_D10 hbo is significant with p-value 0.0002 and threshold 0.0080
# Subject 17  Session 02 - Channel S11_D11 hbo is significant with p-value 0.0086 and threshold 0.0100
# Subject 17
#   Session 01 significant channels (8): ['S10_D12 hbo', 'S11_D11 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S2_D1 hbo', 'S4_D2 hbo', 'S7_D8 hbo', 'S8_D7 hbo']
#   Session 02 significant channels (5): ['S10_D10 hbo', 'S10_D9 hbo', 'S11_D11 hbo', 'S1_D1 hbo', 'S7_D6 hbo']
#   Overlapping channels (2): ['S11_D11 hbo', 'S1_D1 hbo']
#   R_overlap: 0.308
#   R_quantity: 0.769
#
# Subject 19  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 19  Session 01 - Channel S11_D12 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 19  Session 02 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 19  Session 02 - Channel S2_D1 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 19  Session 02 - Channel S5_D3 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 19  Session 02 - Channel S5_D4 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 19  Session 02 - Channel S5_D5 hbo is significant with p-value 0.0000 and threshold 0.0100
# Subject 19  Session 02 - Channel S7_D8 hbo is significant with p-value 0.0000 and threshold 0.0120
# Subject 19  Session 02 - Channel S8_D7 hbo is significant with p-value 0.0000 and threshold 0.0140
# Subject 19  Session 02 - Channel S10_D9 hbo is significant with p-value 0.0002 and threshold 0.0160
# Subject 19  Session 02 - Channel S10_D12 hbo is significant with p-value 0.0002 and threshold 0.0180
# Subject 19  Session 02 - Channel S11_D11 hbo is significant with p-value 0.0009 and threshold 0.0200
# Subject 19  Session 02 - Channel S11_D12 hbo is significant with p-value 0.0082 and threshold 0.0220
# Subject 19 Session 02 - Channel S12_D1 hbo is not significant with p-value 0.0332 and threshold 0.0240
# Subject 19
#   Session 01 significant channels (2): ['S11_D11 hbo', 'S11_D12 hbo']
#   Session 02 significant channels (12): ['S10_D12 hbo', 'S10_D9 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S2_D1 hbo', 'S5_D3 hbo', 'S5_D4 hbo', 'S5_D5 hbo', 'S7_D8 hbo', 'S8_D7 hbo']
#   Overlapping channels (2): ['S11_D11 hbo', 'S11_D12 hbo']
#   R_overlap: 0.286
#   R_quantity: 0.286
#
# Subject 21 Session 01 - Channel S2_D1 hbo is not significant with p-value 0.0023 and threshold 0.0020
# Subject 21  Session 01 - Channel S3_D2 hbo is significant with p-value 0.0031 and threshold 0.0040
# Subject 21  Session 01 - Channel S5_D3 hbo is significant with p-value 0.0035 and threshold 0.0060
# Subject 21 Session 01 - Channel S11_D12 hbo is not significant with p-value 0.0265 and threshold 0.0080
# Subject 21  Session 02 - Channel S5_D3 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 21  Session 02 - Channel S5_D5 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 21  Session 02 - Channel S6_D6 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 21  Session 02 - Channel S9_D8 hbo is significant with p-value 0.0011 and threshold 0.0080
# Subject 21 Session 02 - Channel S10_D11 hbo is not significant with p-value 0.0225 and threshold 0.0100
# Subject 21
#   Session 01 significant channels (4): ['S11_D12 hbo', 'S2_D1 hbo', 'S3_D2 hbo', 'S5_D3 hbo']
#   Session 02 significant channels (5): ['S10_D11 hbo', 'S5_D3 hbo', 'S5_D5 hbo', 'S6_D6 hbo', 'S9_D8 hbo']
#   Overlapping channels (1): ['S5_D3 hbo']
#   R_overlap: 0.222
#   R_quantity: 0.889
#
# Subject 24  Session 01 - Channel S6_D8 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 24  Session 01 - Channel S7_D6 hbo is significant with p-value 0.0013 and threshold 0.0040
# Subject 24 Session 01 - Channel S11_D12 hbo is not significant with p-value 0.0227 and threshold 0.0060
# Subject 24  Session 02 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 24  Session 02 - Channel S6_D6 hbo is significant with p-value 0.0007 and threshold 0.0040
# Subject 24  Session 02 - Channel S8_D8 hbo is significant with p-value 0.0017 and threshold 0.0060
# Subject 24  Session 02 - Channel S10_D11 hbo is significant with p-value 0.0030 and threshold 0.0080
# Subject 24 Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0251 and threshold 0.0100
# Subject 24
#   Session 01 significant channels (3): ['S11_D12 hbo', 'S6_D8 hbo', 'S7_D6 hbo']
#   Session 02 significant channels (5): ['S10_D11 hbo', 'S11_D11 hbo', 'S4_D2 hbo', 'S6_D6 hbo', 'S8_D8 hbo']
#   Overlapping channels (0): []
#   R_overlap: 0.000
#   R_quantity: 0.750

# %% [markdown]
# ### Control vs Speech

# %%
# Filter for significant optodes only
df_sig = df_con_speech[df_con_speech["Significant"] == True]

# Get unique subjects
subjects = df_sig["Subject"].unique()

# For each subject, calculate R_overlap
for subj in sorted(subjects):
    # Filter data for the subject
    subj_data = df_sig[df_sig["Subject"] == subj]
    
    
    # FDR
    q = 0.05
    m = 25 # Total number of unique channels
    # run on each session separately

    for session in ["01", "02"]:
        df_ses = subj_data[(subj_data["session"] == session)]
        p_values = df_ses["p_value"].values
        sorted_p_values = np.sort(p_values)
        
        for i in range(len(sorted_p_values)):
            p_val = sorted_p_values[i]
            threshold = (q * (i + 1)) / m
            
            if p_val <= threshold:
                print(f"Subject {subj}  Session {session} - Channel {df_ses.iloc[i]['ch_name']} is significant with p-value {p_val:.4f} and threshold {threshold:.4f}")
            else:
                print(f"Subject {subj} Session {session} - Channel {df_ses.iloc[i]['ch_name']} is not significant with p-value {p_val:.4f} and threshold {threshold:.4f}")
        

    # Get channels for each session
    ses1_channels = set(subj_data[subj_data["session"] == "01"]["ch_name"])
    ses2_channels = set(subj_data[subj_data["session"] == "02"]["ch_name"])
    
    

    # Calculate activation quantities
    A1 = len(ses1_channels)
    A2 = len(ses2_channels)
    A_overlap = len(ses1_channels.intersection(ses2_channels))

    # Compute R_overlap safely (avoid division by zero)
    if (A1 + A2) > 0:
        R_quantity= 1- ((abs(A1 - A2) )/ (A1 + A2))
        R_overlap = (2 * A_overlap) / (A1 + A2)
    else:
        R_quantity = float('nan') 
        R_overlap = float('nan')

    print(f"Subject {subj}")
    print(f"  Session 01 significant channels ({A1}): {sorted(ses1_channels)}")
    print(f"  Session 02 significant channels ({A2}): {sorted(ses2_channels)}")
    print(f"  Overlapping channels ({A_overlap}): {sorted(ses1_channels.intersection(ses2_channels))}")
    print(f"  R_overlap: {R_overlap:.3f}")
    print(f"  R_quantity: {R_quantity:.3f}")
    print()
# Out:
# Subject 01  Session 01 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 01 Session 01 - Channel S8_D7 hbo is not significant with p-value 0.0103 and threshold 0.0040
# Subject 01  Session 02 - Channel S10_D11 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 01  Session 02 - Channel S11_D11 hbo is significant with p-value 0.0013 and threshold 0.0040
# Subject 01
#   Session 01 significant channels (2): ['S1_D1 hbo', 'S8_D7 hbo']
#   Session 02 significant channels (2): ['S10_D11 hbo', 'S11_D11 hbo']
#   Overlapping channels (0): []
#   R_overlap: 0.000
#   R_quantity: 1.000
#
# Subject 02  Session 01 - Channel S2_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 02  Session 01 - Channel S3_D1 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 02  Session 01 - Channel S4_D3 hbo is significant with p-value 0.0044 and threshold 0.0060
# Subject 02 Session 01 - Channel S11_D11 hbo is not significant with p-value 0.0134 and threshold 0.0080
# Subject 02 Session 01 - Channel S11_D12 hbo is not significant with p-value 0.0147 and threshold 0.0100
# Subject 02  Session 02 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 02  Session 02 - Channel S11_D11 hbo is significant with p-value 0.0029 and threshold 0.0040
# Subject 02
#   Session 01 significant channels (5): ['S11_D11 hbo', 'S11_D12 hbo', 'S2_D1 hbo', 'S3_D1 hbo', 'S4_D3 hbo']
#   Session 02 significant channels (2): ['S11_D11 hbo', 'S4_D3 hbo']
#   Overlapping channels (2): ['S11_D11 hbo', 'S4_D3 hbo']
#   R_overlap: 0.571
#   R_quantity: 0.571
#
# Subject 03  Session 01 - Channel S5_D2 hbo is significant with p-value 0.0006 and threshold 0.0020
# Subject 03 Session 01 - Channel S11_D11 hbo is not significant with p-value 0.0049 and threshold 0.0040
# Subject 03
#   Session 01 significant channels (2): ['S11_D11 hbo', 'S5_D2 hbo']
#   Session 02 significant channels (0): []
#   Overlapping channels (0): []
#   R_overlap: 0.000
#   R_quantity: 0.000
#
# Subject 04  Session 01 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 04  Session 01 - Channel S5_D2 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 04  Session 01 - Channel S5_D3 hbo is significant with p-value 0.0001 and threshold 0.0060
# Subject 04  Session 01 - Channel S6_D6 hbo is significant with p-value 0.0079 and threshold 0.0080
# Subject 04 Session 01 - Channel S10_D12 hbo is not significant with p-value 0.0185 and threshold 0.0100
# Subject 04  Session 02 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 04  Session 02 - Channel S5_D3 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 04  Session 02 - Channel S6_D6 hbo is significant with p-value 0.0021 and threshold 0.0060
# Subject 04
#   Session 01 significant channels (5): ['S10_D12 hbo', 'S4_D3 hbo', 'S5_D2 hbo', 'S5_D3 hbo', 'S6_D6 hbo']
#   Session 02 significant channels (3): ['S4_D2 hbo', 'S5_D3 hbo', 'S6_D6 hbo']
#   Overlapping channels (2): ['S5_D3 hbo', 'S6_D6 hbo']
#   R_overlap: 0.500
#   R_quantity: 0.750
#
# Subject 05  Session 01 - Channel S3_D2 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 05  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 05  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 05  Session 01 - Channel S12_D1 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 05  Session 02 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 05  Session 02 - Channel S3_D1 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 05  Session 02 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 05  Session 02 - Channel S4_D3 hbo is significant with p-value 0.0001 and threshold 0.0080
# Subject 05  Session 02 - Channel S5_D3 hbo is significant with p-value 0.0006 and threshold 0.0100
# Subject 05  Session 02 - Channel S8_D7 hbo is significant with p-value 0.0007 and threshold 0.0120
# Subject 05  Session 02 - Channel S8_D8 hbo is significant with p-value 0.0024 and threshold 0.0140
# Subject 05  Session 02 - Channel S10_D9 hbo is significant with p-value 0.0025 and threshold 0.0160
# Subject 05  Session 02 - Channel S10_D10 hbo is significant with p-value 0.0072 and threshold 0.0180
# Subject 05  Session 02 - Channel S10_D11 hbo is significant with p-value 0.0172 and threshold 0.0200
# Subject 05 Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0318 and threshold 0.0220
# Subject 05 Session 02 - Channel S12_D1 hbo is not significant with p-value 0.0333 and threshold 0.0240
# Subject 05
#   Session 01 significant channels (4): ['S11_D11 hbo', 'S12_D1 hbo', 'S3_D2 hbo', 'S4_D2 hbo']
#   Session 02 significant channels (12): ['S10_D10 hbo', 'S10_D11 hbo', 'S10_D9 hbo', 'S11_D11 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S3_D1 hbo', 'S4_D2 hbo', 'S4_D3 hbo', 'S5_D3 hbo', 'S8_D7 hbo', 'S8_D8 hbo']
#   Overlapping channels (3): ['S11_D11 hbo', 'S12_D1 hbo', 'S4_D2 hbo']
#   R_overlap: 0.375
#   R_quantity: 0.500
#
# Subject 07  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 07  Session 01 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 07  Session 01 - Channel S10_D9 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 07  Session 01 - Channel S10_D11 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 07  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0051 and threshold 0.0100
# Subject 07 Session 01 - Channel S11_D12 hbo is not significant with p-value 0.0246 and threshold 0.0120
# Subject 07  Session 02 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 07  Session 02 - Channel S3_D2 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 07  Session 02 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 07  Session 02 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 07  Session 02 - Channel S5_D2 hbo is significant with p-value 0.0002 and threshold 0.0100
# Subject 07  Session 02 - Channel S5_D3 hbo is significant with p-value 0.0003 and threshold 0.0120
# Subject 07  Session 02 - Channel S9_D8 hbo is significant with p-value 0.0045 and threshold 0.0140
# Subject 07  Session 02 - Channel S10_D10 hbo is significant with p-value 0.0084 and threshold 0.0160
# Subject 07 Session 02 - Channel S10_D11 hbo is not significant with p-value 0.0212 and threshold 0.0180
# Subject 07 Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0472 and threshold 0.0200
# Subject 07 Session 02 - Channel S11_D12 hbo is not significant with p-value 0.0500 and threshold 0.0220
# Subject 07
#   Session 01 significant channels (6): ['S10_D11 hbo', 'S10_D9 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S4_D2 hbo', 'S4_D3 hbo']
#   Session 02 significant channels (11): ['S10_D10 hbo', 'S10_D11 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S1_D1 hbo', 'S3_D2 hbo', 'S4_D2 hbo', 'S4_D3 hbo', 'S5_D2 hbo', 'S5_D3 hbo', 'S9_D8 hbo']
#   Overlapping channels (5): ['S10_D11 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S4_D2 hbo', 'S4_D3 hbo']
#   R_overlap: 0.588
#   R_quantity: 0.706
#
# Subject 08  Session 01 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 08  Session 01 - Channel S3_D1 hbo is significant with p-value 0.0001 and threshold 0.0040
# Subject 08  Session 01 - Channel S3_D2 hbo is significant with p-value 0.0002 and threshold 0.0060
# Subject 08  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0009 and threshold 0.0080
# Subject 08 Session 01 - Channel S5_D3 hbo is not significant with p-value 0.0122 and threshold 0.0100
# Subject 08 Session 01 - Channel S5_D5 hbo is not significant with p-value 0.0165 and threshold 0.0120
# Subject 08 Session 01 - Channel S6_D6 hbo is not significant with p-value 0.0267 and threshold 0.0140
# Subject 08 Session 01 - Channel S7_D8 hbo is not significant with p-value 0.0277 and threshold 0.0160
# Subject 08 Session 01 - Channel S10_D11 hbo is not significant with p-value 0.0320 and threshold 0.0180
# Subject 08 Session 01 - Channel S10_D12 hbo is not significant with p-value 0.0322 and threshold 0.0200
# Subject 08 Session 01 - Channel S11_D12 hbo is not significant with p-value 0.0347 and threshold 0.0220
# Subject 08  Session 02 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 08  Session 02 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 08  Session 02 - Channel S5_D5 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 08  Session 02 - Channel S6_D6 hbo is significant with p-value 0.0006 and threshold 0.0080
# Subject 08  Session 02 - Channel S8_D8 hbo is significant with p-value 0.0007 and threshold 0.0100
# Subject 08  Session 02 - Channel S10_D10 hbo is significant with p-value 0.0080 and threshold 0.0120
# Subject 08  Session 02 - Channel S10_D11 hbo is significant with p-value 0.0095 and threshold 0.0140
# Subject 08  Session 02 - Channel S10_D12 hbo is significant with p-value 0.0141 and threshold 0.0160
# Subject 08 Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0246 and threshold 0.0180
# Subject 08
#   Session 01 significant channels (11): ['S10_D11 hbo', 'S10_D12 hbo', 'S11_D12 hbo', 'S1_D1 hbo', 'S3_D1 hbo', 'S3_D2 hbo', 'S4_D2 hbo', 'S5_D3 hbo', 'S5_D5 hbo', 'S6_D6 hbo', 'S7_D8 hbo']
#   Session 02 significant channels (9): ['S10_D10 hbo', 'S10_D11 hbo', 'S10_D12 hbo', 'S11_D11 hbo', 'S4_D2 hbo', 'S4_D3 hbo', 'S5_D5 hbo', 'S6_D6 hbo', 'S8_D8 hbo']
#   Overlapping channels (5): ['S10_D11 hbo', 'S10_D12 hbo', 'S4_D2 hbo', 'S5_D5 hbo', 'S6_D6 hbo']
#   R_overlap: 0.500
#   R_quantity: 0.900
#
# Subject 10  Session 01 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 10  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 10  Session 01 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 10  Session 01 - Channel S5_D2 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 10  Session 01 - Channel S5_D3 hbo is significant with p-value 0.0000 and threshold 0.0100
# Subject 10  Session 01 - Channel S7_D7 hbo is significant with p-value 0.0000 and threshold 0.0120
# Subject 10  Session 01 - Channel S10_D10 hbo is significant with p-value 0.0000 and threshold 0.0140
# Subject 10  Session 01 - Channel S10_D11 hbo is significant with p-value 0.0000 and threshold 0.0160
# Subject 10  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0051 and threshold 0.0180
# Subject 10  Session 01 - Channel S11_D12 hbo is significant with p-value 0.0116 and threshold 0.0200
# Subject 10 Session 01 - Channel S12_D1 hbo is not significant with p-value 0.0489 and threshold 0.0220
# Subject 10  Session 02 - Channel S6_D8 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 10  Session 02 - Channel S10_D11 hbo is significant with p-value 0.0002 and threshold 0.0040
# Subject 10 Session 02 - Channel S11_D12 hbo is not significant with p-value 0.0166 and threshold 0.0060
# Subject 10
#   Session 01 significant channels (11): ['S10_D10 hbo', 'S10_D11 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S4_D2 hbo', 'S4_D3 hbo', 'S5_D2 hbo', 'S5_D3 hbo', 'S7_D7 hbo']
#   Session 02 significant channels (3): ['S10_D11 hbo', 'S11_D12 hbo', 'S6_D8 hbo']
#   Overlapping channels (2): ['S10_D11 hbo', 'S11_D12 hbo']
#   R_overlap: 0.286
#   R_quantity: 0.429
#
# Subject 11  Session 01 - Channel S3_D2 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 11  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 11  Session 01 - Channel S7_D8 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 11  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 11 Session 01 - Channel S11_D12 hbo is not significant with p-value 0.0167 and threshold 0.0100
# Subject 11  Session 02 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 11  Session 02 - Channel S3_D1 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 11  Session 02 - Channel S3_D2 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 11  Session 02 - Channel S5_D4 hbo is significant with p-value 0.0080 and threshold 0.0080
# Subject 11 Session 02 - Channel S6_D8 hbo is not significant with p-value 0.0116 and threshold 0.0100
# Subject 11 Session 02 - Channel S9_D8 hbo is not significant with p-value 0.0237 and threshold 0.0120
# Subject 11 Session 02 - Channel S10_D12 hbo is not significant with p-value 0.0240 and threshold 0.0140
# Subject 11 Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0375 and threshold 0.0160
# Subject 11 Session 02 - Channel S11_D12 hbo is not significant with p-value 0.0400 and threshold 0.0180
# Subject 11
#   Session 01 significant channels (5): ['S11_D11 hbo', 'S11_D12 hbo', 'S3_D2 hbo', 'S4_D2 hbo', 'S7_D8 hbo']
#   Session 02 significant channels (9): ['S10_D12 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S1_D1 hbo', 'S3_D1 hbo', 'S3_D2 hbo', 'S5_D4 hbo', 'S6_D8 hbo', 'S9_D8 hbo']
#   Overlapping channels (3): ['S11_D11 hbo', 'S11_D12 hbo', 'S3_D2 hbo']
#   R_overlap: 0.429
#   R_quantity: 0.714
#
# Subject 12  Session 01 - Channel S3_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 12  Session 01 - Channel S3_D2 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 12  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 12  Session 01 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 12  Session 01 - Channel S5_D3 hbo is significant with p-value 0.0000 and threshold 0.0100
# Subject 12  Session 01 - Channel S5_D4 hbo is significant with p-value 0.0000 and threshold 0.0120
# Subject 12  Session 01 - Channel S7_D7 hbo is significant with p-value 0.0001 and threshold 0.0140
# Subject 12  Session 01 - Channel S8_D7 hbo is significant with p-value 0.0013 and threshold 0.0160
# Subject 12  Session 01 - Channel S8_D8 hbo is significant with p-value 0.0033 and threshold 0.0180
# Subject 12  Session 01 - Channel S9_D8 hbo is significant with p-value 0.0074 and threshold 0.0200
# Subject 12  Session 01 - Channel S10_D9 hbo is significant with p-value 0.0124 and threshold 0.0220
# Subject 12  Session 01 - Channel S10_D10 hbo is significant with p-value 0.0180 and threshold 0.0240
# Subject 12 Session 01 - Channel S10_D12 hbo is not significant with p-value 0.0311 and threshold 0.0260
# Subject 12 Session 01 - Channel S11_D11 hbo is not significant with p-value 0.0334 and threshold 0.0280
# Subject 12 Session 01 - Channel S11_D12 hbo is not significant with p-value 0.0480 and threshold 0.0300
# Subject 12  Session 02 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 12  Session 02 - Channel S3_D1 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 12  Session 02 - Channel S3_D2 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 12  Session 02 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 12  Session 02 - Channel S4_D3 hbo is significant with p-value 0.0004 and threshold 0.0100
# Subject 12  Session 02 - Channel S5_D2 hbo is significant with p-value 0.0009 and threshold 0.0120
# Subject 12  Session 02 - Channel S5_D4 hbo is significant with p-value 0.0010 and threshold 0.0140
# Subject 12  Session 02 - Channel S6_D6 hbo is significant with p-value 0.0020 and threshold 0.0160
# Subject 12  Session 02 - Channel S10_D11 hbo is significant with p-value 0.0022 and threshold 0.0180
# Subject 12  Session 02 - Channel S10_D12 hbo is significant with p-value 0.0022 and threshold 0.0200
# Subject 12  Session 02 - Channel S11_D11 hbo is significant with p-value 0.0052 and threshold 0.0220
# Subject 12  Session 02 - Channel S11_D12 hbo is significant with p-value 0.0162 and threshold 0.0240
# Subject 12 Session 02 - Channel S12_D1 hbo is not significant with p-value 0.0311 and threshold 0.0260
# Subject 12
#   Session 01 significant channels (15): ['S10_D10 hbo', 'S10_D12 hbo', 'S10_D9 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S3_D1 hbo', 'S3_D2 hbo', 'S4_D2 hbo', 'S4_D3 hbo', 'S5_D3 hbo', 'S5_D4 hbo', 'S7_D7 hbo', 'S8_D7 hbo', 'S8_D8 hbo', 'S9_D8 hbo']
#   Session 02 significant channels (13): ['S10_D11 hbo', 'S10_D12 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S3_D1 hbo', 'S3_D2 hbo', 'S4_D2 hbo', 'S4_D3 hbo', 'S5_D2 hbo', 'S5_D4 hbo', 'S6_D6 hbo']
#   Overlapping channels (8): ['S10_D12 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S3_D1 hbo', 'S3_D2 hbo', 'S4_D2 hbo', 'S4_D3 hbo', 'S5_D4 hbo']
#   R_overlap: 0.571
#   R_quantity: 0.929
#
# Subject 13  Session 01 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 13  Session 01 - Channel S2_D1 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 13  Session 01 - Channel S3_D1 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 13  Session 01 - Channel S3_D2 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 13  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0100
# Subject 13  Session 01 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0120
# Subject 13  Session 01 - Channel S5_D2 hbo is significant with p-value 0.0001 and threshold 0.0140
# Subject 13  Session 01 - Channel S5_D3 hbo is significant with p-value 0.0001 and threshold 0.0160
# Subject 13  Session 01 - Channel S5_D4 hbo is significant with p-value 0.0001 and threshold 0.0180
# Subject 13  Session 01 - Channel S5_D5 hbo is significant with p-value 0.0004 and threshold 0.0200
# Subject 13  Session 01 - Channel S6_D8 hbo is significant with p-value 0.0014 and threshold 0.0220
# Subject 13  Session 01 - Channel S7_D7 hbo is significant with p-value 0.0023 and threshold 0.0240
# Subject 13  Session 01 - Channel S7_D8 hbo is significant with p-value 0.0028 and threshold 0.0260
# Subject 13  Session 01 - Channel S8_D7 hbo is significant with p-value 0.0053 and threshold 0.0280
# Subject 13  Session 01 - Channel S8_D8 hbo is significant with p-value 0.0063 and threshold 0.0300
# Subject 13  Session 01 - Channel S10_D10 hbo is significant with p-value 0.0068 and threshold 0.0320
# Subject 13  Session 01 - Channel S10_D12 hbo is significant with p-value 0.0114 and threshold 0.0340
# Subject 13  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0142 and threshold 0.0360
# Subject 13  Session 01 - Channel S11_D12 hbo is significant with p-value 0.0173 and threshold 0.0380
# Subject 13  Session 01 - Channel S12_D1 hbo is significant with p-value 0.0334 and threshold 0.0400
# Subject 13  Session 02 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 13  Session 02 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 13  Session 02 - Channel S7_D7 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 13  Session 02 - Channel S11_D11 hbo is significant with p-value 0.0046 and threshold 0.0080
# Subject 13
#   Session 01 significant channels (20): ['S10_D10 hbo', 'S10_D12 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S2_D1 hbo', 'S3_D1 hbo', 'S3_D2 hbo', 'S4_D2 hbo', 'S4_D3 hbo', 'S5_D2 hbo', 'S5_D3 hbo', 'S5_D4 hbo', 'S5_D5 hbo', 'S6_D8 hbo', 'S7_D7 hbo', 'S7_D8 hbo', 'S8_D7 hbo', 'S8_D8 hbo']
#   Session 02 significant channels (4): ['S11_D11 hbo', 'S4_D2 hbo', 'S4_D3 hbo', 'S7_D7 hbo']
#   Overlapping channels (4): ['S11_D11 hbo', 'S4_D2 hbo', 'S4_D3 hbo', 'S7_D7 hbo']
#   R_overlap: 0.333
#   R_quantity: 0.333
#
# Subject 16 Session 01 - Channel S1_D1 hbo is not significant with p-value 0.0047 and threshold 0.0020
# Subject 16  Session 02 - Channel S12_D1 hbo is significant with p-value 0.0003 and threshold 0.0020
# Subject 16
#   Session 01 significant channels (1): ['S1_D1 hbo']
#   Session 02 significant channels (1): ['S12_D1 hbo']
#   Overlapping channels (0): []
#   R_overlap: 0.000
#   R_quantity: 1.000
#
# Subject 17  Session 01 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 17  Session 01 - Channel S2_D1 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 17  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 17  Session 01 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 17  Session 01 - Channel S10_D12 hbo is significant with p-value 0.0001 and threshold 0.0100
# Subject 17  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0047 and threshold 0.0120
# Subject 17  Session 01 - Channel S12_D1 hbo is significant with p-value 0.0056 and threshold 0.0140
# Subject 17  Session 02 - Channel S1_D1 hbo is significant with p-value 0.0007 and threshold 0.0020
# Subject 17
#   Session 01 significant channels (7): ['S10_D12 hbo', 'S11_D11 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S2_D1 hbo', 'S4_D2 hbo', 'S4_D3 hbo']
#   Session 02 significant channels (1): ['S1_D1 hbo']
#   Overlapping channels (1): ['S1_D1 hbo']
#   R_overlap: 0.250
#   R_quantity: 0.250
#
# Subject 19  Session 01 - Channel S4_D3 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 19  Session 01 - Channel S11_D12 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 19  Session 02 - Channel S2_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 19  Session 02 - Channel S5_D3 hbo is significant with p-value 0.0001 and threshold 0.0040
# Subject 19  Session 02 - Channel S5_D5 hbo is significant with p-value 0.0001 and threshold 0.0060
# Subject 19 Session 02 - Channel S10_D12 hbo is not significant with p-value 0.0173 and threshold 0.0080
# Subject 19 Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0259 and threshold 0.0100
# Subject 19 Session 02 - Channel S11_D12 hbo is not significant with p-value 0.0317 and threshold 0.0120
# Subject 19
#   Session 01 significant channels (2): ['S11_D12 hbo', 'S4_D3 hbo']
#   Session 02 significant channels (6): ['S10_D12 hbo', 'S11_D11 hbo', 'S11_D12 hbo', 'S2_D1 hbo', 'S5_D3 hbo', 'S5_D5 hbo']
#   Overlapping channels (1): ['S11_D12 hbo']
#   R_overlap: 0.250
#   R_quantity: 0.500
#
# Subject 21  Session 01 - Channel S2_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 21  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0006 and threshold 0.0040
# Subject 21 Session 01 - Channel S5_D3 hbo is not significant with p-value 0.0225 and threshold 0.0060
# Subject 21  Session 02 - Channel S5_D3 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 21  Session 02 - Channel S5_D5 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 21  Session 02 - Channel S6_D6 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 21  Session 02 - Channel S7_D8 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 21  Session 02 - Channel S9_D8 hbo is significant with p-value 0.0000 and threshold 0.0100
# Subject 21  Session 02 - Channel S10_D11 hbo is significant with p-value 0.0002 and threshold 0.0120
# Subject 21  Session 02 - Channel S10_D12 hbo is significant with p-value 0.0005 and threshold 0.0140
# Subject 21  Session 02 - Channel S11_D11 hbo is significant with p-value 0.0022 and threshold 0.0160
# Subject 21
#   Session 01 significant channels (3): ['S2_D1 hbo', 'S4_D2 hbo', 'S5_D3 hbo']
#   Session 02 significant channels (8): ['S10_D11 hbo', 'S10_D12 hbo', 'S11_D11 hbo', 'S5_D3 hbo', 'S5_D5 hbo', 'S6_D6 hbo', 'S7_D8 hbo', 'S9_D8 hbo']
#   Overlapping channels (1): ['S5_D3 hbo']
#   R_overlap: 0.182
#   R_quantity: 0.545
#
# Subject 24  Session 01 - Channel S2_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 24  Session 01 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 24  Session 01 - Channel S6_D8 hbo is significant with p-value 0.0001 and threshold 0.0060
# Subject 24  Session 01 - Channel S11_D11 hbo is significant with p-value 0.0050 and threshold 0.0080
# Subject 24 Session 01 - Channel S11_D12 hbo is not significant with p-value 0.0327 and threshold 0.0100
# Subject 24  Session 02 - Channel S1_D1 hbo is significant with p-value 0.0000 and threshold 0.0020
# Subject 24  Session 02 - Channel S2_D1 hbo is significant with p-value 0.0000 and threshold 0.0040
# Subject 24  Session 02 - Channel S4_D2 hbo is significant with p-value 0.0000 and threshold 0.0060
# Subject 24  Session 02 - Channel S5_D2 hbo is significant with p-value 0.0000 and threshold 0.0080
# Subject 24  Session 02 - Channel S5_D3 hbo is significant with p-value 0.0001 and threshold 0.0100
# Subject 24  Session 02 - Channel S8_D8 hbo is significant with p-value 0.0005 and threshold 0.0120
# Subject 24  Session 02 - Channel S10_D9 hbo is significant with p-value 0.0027 and threshold 0.0140
# Subject 24  Session 02 - Channel S10_D10 hbo is significant with p-value 0.0048 and threshold 0.0160
# Subject 24  Session 02 - Channel S10_D11 hbo is significant with p-value 0.0061 and threshold 0.0180
# Subject 24 Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0282 and threshold 0.0200
# Subject 24 Session 02 - Channel S12_D1 hbo is not significant with p-value 0.0353 and threshold 0.0220
# Subject 24
#   Session 01 significant channels (5): ['S11_D11 hbo', 'S11_D12 hbo', 'S2_D1 hbo', 'S4_D2 hbo', 'S6_D8 hbo']
#   Session 02 significant channels (11): ['S10_D10 hbo', 'S10_D11 hbo', 'S10_D9 hbo', 'S11_D11 hbo', 'S12_D1 hbo', 'S1_D1 hbo', 'S2_D1 hbo', 'S4_D2 hbo', 'S5_D2 hbo', 'S5_D3 hbo', 'S8_D8 hbo']
#   Overlapping channels (3): ['S11_D11 hbo', 'S2_D1 hbo', 'S4_D2 hbo']
#   R_overlap: 0.375
#   R_quantity: 0.625

# %% [markdown]
# # GLM Group Level Analysis (pre-defined vs data-driven ROIs)

# %%
grp_results = df_roi.query("Condition in ['Control','Noise', 'Speech']")

results_dict = {}

model_summary_df = pd.DataFrame(columns=["ROI", "Effect", "Coef", "StdErr", "z", "Pval", "CI_lower", "CI_upper"])


for roi in ["Left", "Right", "Back", "Front", "Noise_glm", "Speech_glm", "Noise_waa", "Speech_waa", "Speech_glm_fdr", "Noise_glm_fdr", "Speech_waa_fdr", "Noise_waa_fdr"]:
    print(f"Running mixed model for {roi}...")
    subset = grp_results[(grp_results["Chroma"] == "hbo") & (grp_results["ROI"] == roi)].copy()

    # Ensure categorical variables
    subset["Condition"] = subset["Condition"].astype("category")
    subset["session"] = subset["session"].astype("category")
    
    subset["Condition"] = subset["Condition"].cat.reorder_categories(["Control", "Noise", "Speech"], ordered=True)


    # Fit mixed model: Condition + Session as fixed, ID as random intercept
    model = smf.mixedlm("theta ~  Condition+session", subset, groups=subset["Subject"])
    result = model.fit( method="nm")
    print(result.summary())
    
    results_dict[roi] = result
    
    # Extract desired coefficients
    for term in ["Condition[T.Noise]", "Condition[T.Speech]"]:
        if term in result.params:
            coef = result.params[term]
            stderr = result.bse[term]
            z_val = coef / stderr
            pval = result.pvalues[term]
            ci_low, ci_up = result.conf_int().loc[term]

            model_summary_df = pd.concat(
                [model_summary_df,
                    pd.DataFrame({
                        "ROI": [roi],
                        "Effect": [term],
                        "Coef": [coef],
                        "StdErr": [stderr],
                        "z": [z_val],
                        "Pval": [pval],
                        "CI_lower": [ci_low],
                        "CI_upper": [ci_up]
                    })],
                ignore_index=True
            )

# Show collected results
print("\n=== Summary Table ===")
print(model_summary_df)
# Out:
# Running mixed model for Left...
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   theta
# No. Observations:    96        Method:               REML
# No. Groups:          16        Scale:                1.3797
# Min. group size:     6         Log-Likelihood:       -160.6538
# Max. group size:     6         Converged:            Yes
# Mean group size:     6.0
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           -0.168    0.296 -0.568 0.570 -0.749  0.412
# Condition[T.Noise]  -0.130    0.294 -0.444 0.657 -0.706  0.445
# Condition[T.Speech]  0.553    0.294  1.884 0.060 -0.022  1.129
# session[T.02]        0.432    0.240  1.800 0.072 -0.038  0.901
# Group Var            0.486    0.243
# ==============================================================
#
# Running mixed model for Right...
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   theta
# No. Observations:    96        Method:               REML
# No. Groups:          16        Scale:                0.9247
# Min. group size:     6         Log-Likelihood:       -147.4345
# Max. group size:     6         Converged:            Yes
# Mean group size:     6.0
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           -0.023    0.298 -0.078 0.938 -0.607  0.561
# Condition[T.Noise]   0.807    0.240  3.357 0.001  0.336  1.278
# Condition[T.Speech]  0.659    0.240  2.740 0.006  0.187  1.130
# session[T.02]        0.224    0.196  1.140 0.254 -0.161  0.608
# Group Var            0.804    0.398
# ==============================================================
#
# Running mixed model for Back...
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   theta
# No. Observations:    96        Method:               REML
# No. Groups:          16        Scale:                0.9843
# Min. group size:     6         Log-Likelihood:       -140.1841
# Max. group size:     6         Converged:            Yes
# Mean group size:     6.0
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           -0.097    0.217 -0.446 0.656 -0.523  0.329
# Condition[T.Noise]  -0.284    0.248 -1.144 0.253 -0.770  0.202
# Condition[T.Speech] -1.045    0.248 -4.215 0.000 -1.532 -0.559
# session[T.02]        0.333    0.203  1.642 0.101 -0.064  0.729
# Group Var            0.100    0.106
# ==============================================================
#
# Running mixed model for Front...
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   theta
# No. Observations:    96        Method:               REML
# No. Groups:          16        Scale:                1.0597
# Min. group size:     6         Log-Likelihood:       -145.3912
# Max. group size:     6         Converged:            Yes
# Mean group size:     6.0
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           -0.036    0.236 -0.151 0.880 -0.499  0.427
# Condition[T.Noise]  -0.236    0.257 -0.918 0.359 -0.741  0.268
# Condition[T.Speech] -0.323    0.257 -1.255 0.209 -0.827  0.181
# session[T.02]        0.292    0.210  1.390 0.164 -0.120  0.704
# Group Var            0.186    0.141
# ==============================================================
#
# Running mixed model for Noise_glm...
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   theta
# No. Observations:    96        Method:               REML
# No. Groups:          16        Scale:                1.3555
# Min. group size:     6         Log-Likelihood:       -164.6356
# Max. group size:     6         Converged:            Yes
# Mean group size:     6.0
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           -0.193    0.355 -0.543 0.587 -0.887  0.502
# Condition[T.Noise]   1.005    0.291  3.452 0.001  0.434  1.575
# Condition[T.Speech]  1.546    0.291  5.311 0.000  0.975  2.116
# session[T.02]        0.535    0.238  2.253 0.024  0.070  1.001
# Group Var            1.107    0.457
# ==============================================================
#
# Running mixed model for Speech_glm...
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   theta
# No. Observations:    96        Method:               REML
# No. Groups:          16        Scale:                0.9805
# Min. group size:     6         Log-Likelihood:       -146.2710
# Max. group size:     6         Converged:            Yes
# Mean group size:     6.0
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           -0.190    0.262 -0.724 0.469 -0.703  0.324
# Condition[T.Noise]   0.172    0.248  0.694 0.488 -0.313  0.657
# Condition[T.Speech]  0.750    0.248  3.029 0.002  0.265  1.235
# session[T.02]        0.431    0.202  2.133 0.033  0.035  0.827
# Group Var            0.444    0.245
# ==============================================================
#
# Running mixed model for Noise_waa...
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   theta
# No. Observations:    96        Method:               REML
# No. Groups:          16        Scale:                3.0637
# Min. group size:     6         Log-Likelihood:       -205.1535
# Max. group size:     6         Converged:            Yes
# Mean group size:     6.0
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           -0.233    0.614 -0.379 0.704 -1.436  0.970
# Condition[T.Noise]   1.417    0.438  3.237 0.001  0.559  2.274
# Condition[T.Speech]  2.431    0.438  5.555 0.000  1.573  3.288
# session[T.02]        0.964    0.357  2.697 0.007  0.263  1.664
# Group Var            3.989    1.026
# ==============================================================
#
# Running mixed model for Speech_waa...
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   theta
# No. Observations:    96        Method:               REML
# No. Groups:          16        Scale:                0.9737
# Min. group size:     6         Log-Likelihood:       -149.3172
# Max. group size:     6         Converged:            Yes
# Mean group size:     6.0
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           -0.052    0.299 -0.175 0.861 -0.639  0.534
# Condition[T.Noise]   0.665    0.247  2.694 0.007  0.181  1.148
# Condition[T.Speech]  0.570    0.247  2.310 0.021  0.086  1.053
# session[T.02]        0.327    0.201  1.624 0.104 -0.068  0.722
# Group Var            0.783    0.382
# ==============================================================
#
# Running mixed model for Speech_glm_fdr...
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   theta
# No. Observations:    96        Method:               REML
# No. Groups:          16        Scale:                0.8543
# Min. group size:     6         Log-Likelihood:       -136.1153
# Max. group size:     6         Converged:            Yes
# Mean group size:     6.0
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept            0.012    0.216  0.056 0.955 -0.411  0.435
# Condition[T.Noise]  -0.125    0.231 -0.540 0.589 -0.578  0.328
# Condition[T.Speech]  0.172    0.231  0.745 0.456 -0.281  0.625
# session[T.02]        0.102    0.189  0.543 0.587 -0.267  0.472
# Group Var            0.176    0.137
# ==============================================================
#
# Running mixed model for Noise_glm_fdr...
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   theta
# No. Observations:    96        Method:               REML
# No. Groups:          16        Scale:                0.9040
# Min. group size:     6         Log-Likelihood:       -148.0323
# Max. group size:     6         Converged:            Yes
# Mean group size:     6.0
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           -0.096    0.318 -0.302 0.763 -0.719  0.527
# Condition[T.Noise]   1.005    0.238  4.229 0.000  0.539  1.471
# Condition[T.Speech]  1.171    0.238  4.928 0.000  0.705  1.637
# session[T.02]        0.495    0.194  2.552 0.011  0.115  0.876
# Group Var            1.015    0.489
# ==============================================================
#
# Running mixed model for Speech_waa_fdr...
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  theta
# No. Observations:    96       Method:              REML
# No. Groups:          16       Scale:               1.1118
# Min. group size:     6        Log-Likelihood:      -156.1229
# Max. group size:     6        Converged:           Yes
# Mean group size:     6.0
# ------------------------------------------------------------
#                     Coef. Std.Err.   z   P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept           0.033    0.330 0.100 0.920 -0.613  0.680
# Condition[T.Noise]  0.599    0.264 2.271 0.023  0.082  1.115
# Condition[T.Speech] 0.341    0.264 1.293 0.196 -0.176  0.858
# session[T.02]       0.262    0.215 1.218 0.223 -0.160  0.684
# Group Var           1.000    0.449
# ============================================================
#
# Running mixed model for Noise_waa_fdr...
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  theta
# No. Observations:    96       Method:              REML
# No. Groups:          16       Scale:               1.2550
# Min. group size:     6        Log-Likelihood:      -159.8472
# Max. group size:     6        Converged:           Yes
# Mean group size:     6.0
# ------------------------------------------------------------
#                     Coef. Std.Err.   z   P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept           0.038    0.323 0.118 0.906 -0.596  0.672
# Condition[T.Noise]  0.422    0.280 1.505 0.132 -0.127  0.970
# Condition[T.Speech] 0.422    0.280 1.508 0.132 -0.127  0.971
# session[T.02]       0.175    0.229 0.766 0.444 -0.273  0.623
# Group Var           0.836    0.373
# ============================================================
#
#
# === Summary Table ===
#                ROI               Effect      Coef    StdErr         z  \
# 0             Left   Condition[T.Noise] -0.130388  0.293654 -0.444018
# 1             Left  Condition[T.Speech]  0.553214  0.293654  1.883900
# 2            Right   Condition[T.Noise]  0.807106  0.240397  3.357384
# 3            Right  Condition[T.Speech]  0.658631  0.240397  2.739759
# 4             Back   Condition[T.Noise] -0.283795  0.248025 -1.144221
# 5             Back  Condition[T.Speech] -1.045455  0.248025 -4.215124
# 6            Front   Condition[T.Noise] -0.236151  0.257351 -0.917624
# 7            Front  Condition[T.Speech] -0.323042  0.257351 -1.255260
# 8        Noise_glm   Condition[T.Noise]  1.004666  0.291069  3.451635
# 9        Noise_glm  Condition[T.Speech]  1.545763  0.291069  5.310633
# 10      Speech_glm   Condition[T.Noise]  0.171719  0.247545  0.693686
# 11      Speech_glm  Condition[T.Speech]  0.749760  0.247545  3.028778
# 12       Noise_waa   Condition[T.Noise]  1.416545  0.437588  3.237168
# 13       Noise_waa  Condition[T.Speech]  2.430582  0.437588  5.554503
# 14      Speech_waa   Condition[T.Noise]  0.664639  0.246685  2.694275
# 15      Speech_waa  Condition[T.Speech]  0.569874  0.246685  2.310123
# 16  Speech_glm_fdr   Condition[T.Noise] -0.124838  0.231068 -0.540265
# 17  Speech_glm_fdr  Condition[T.Speech]  0.172147  0.231068  0.745009
# 18   Noise_glm_fdr   Condition[T.Noise]  1.005299  0.237693  4.229403
# 19   Noise_glm_fdr  Condition[T.Speech]  1.171262  0.237693  4.927627
# 20  Speech_waa_fdr   Condition[T.Noise]  0.598735  0.263609  2.271298
# 21  Speech_waa_fdr  Condition[T.Speech]  0.340974  0.263609  1.293485
# 22   Noise_waa_fdr   Condition[T.Noise]  0.421558  0.280065  1.505212
# 23   Noise_waa_fdr  Condition[T.Speech]  0.422262  0.280065  1.507727
#
#             Pval  CI_lower  CI_upper
# 0   6.570293e-01 -0.705938  0.445163
# 1   5.957849e-02 -0.022336  1.128765
# 2   7.868378e-04  0.335936  1.278277
# 3   6.148419e-03  0.187461  1.129801
# 4   2.525319e-01 -0.769915  0.202324
# 5   2.496411e-05 -1.531575 -0.559335
# 6   3.588159e-01 -0.740550  0.268247
# 7   2.093846e-01 -0.827440  0.181356
# 8   5.572017e-04  0.434180  1.575151
# 9   1.092448e-07  0.975278  2.116249
# 10  4.878791e-01 -0.313461  0.656899
# 11  2.455447e-03  0.264580  1.234940
# 12  1.207224e-03  0.558889  2.274201
# 13  2.784027e-08  1.572926  3.288238
# 14  7.054190e-03  0.181144  1.148133
# 15  2.088133e-02  0.086379  1.053369
# 16  5.890141e-01 -0.577722  0.328046
# 17  4.562662e-01 -0.280737  0.625031
# 18  2.343127e-05  0.539429  1.471168
# 19  8.323412e-07  0.705392  1.637131
# 20  2.312895e-02  0.082070  1.115399
# 21  1.958433e-01 -0.175690  0.857639
# 22  1.322696e-01 -0.127360  0.970476
# 23  1.316244e-01 -0.126656  0.971180

# %% [markdown]
# ## FDR

# %%
m= 16 # number of independent tests (number of rois x 2 conditions- control vs noise, control vs speech)
q= 0.05

effects= model_summary_df["Effect"].unique()
roi_names = model_summary_df["ROI"].unique()

for effect in effects:
    print(f"\n=== Analyzing Effect: {effect} ===")
    df_effect= model_summary_df[model_summary_df["Effect"] == effect]
    p_values = df_effect["Pval"].values
    p_values = np.sort(p_values)
    p_values_significant = p_values[p_values < 0.05]
    if len(p_values_significant) == 0:
        print("No significant p-values found.")
        continue
    for i in range(0, len(p_values_significant)):
        p_val = p_values_significant[i]
        threshold = (q * (i + 1)) / m
        # pass if p-value <= threshold
        if p_val <= threshold:
            print(f"ROI {df_effect.iloc[i]['ROI']} is significant with p-value {p_val:.4f} and threshold {threshold:.4f}")
        else:
            print(f"ROI {df_effect.iloc[i]['ROI']} is not significant with p-value {p_val:.4f} and threshold {threshold:.4f}")
# Out:
# === Analyzing Effect: Condition[T.Noise] ===
# ROI Left is significant with p-value 0.0000 and threshold 0.0031
# ROI Right is significant with p-value 0.0006 and threshold 0.0063
# ROI Back is significant with p-value 0.0008 and threshold 0.0094
# ROI Front is significant with p-value 0.0012 and threshold 0.0125
# ROI Noise_glm is significant with p-value 0.0071 and threshold 0.0156
# ROI Speech_glm is not significant with p-value 0.0231 and threshold 0.0188
#
# === Analyzing Effect: Condition[T.Speech] ===
# ROI Left is significant with p-value 0.0000 and threshold 0.0031
# ROI Right is significant with p-value 0.0000 and threshold 0.0063
# ROI Back is significant with p-value 0.0000 and threshold 0.0094
# ROI Front is significant with p-value 0.0000 and threshold 0.0125
# ROI Noise_glm is significant with p-value 0.0025 and threshold 0.0156
# ROI Speech_glm is significant with p-value 0.0061 and threshold 0.0188
# ROI Noise_waa is significant with p-value 0.0209 and threshold 0.0219

# %% [markdown]
# ## Group-Level Contrasts

# %% [markdown]
# ### Control vs Noise

# %%
import pandas as pd
from scipy.stats import ttest_1samp

# Optional: Filter by Chroma if needed
df_filtered = df_con_noise[df_con_noise["Chroma"] == "hbo"].copy()

# Initialize list to collect group-level results
all_group_results = []

# Step 1: Group-level stats for each session
for session in df_filtered["session"].unique():
    df_ses = df_filtered[df_filtered["session"] == session]

    for ch_name, group in df_ses.groupby("ch_name"):
        effects = group["effect"].dropna().values
        if len(effects) < 2:
            continue  # Not enough data for a t-test

        t_stat, p_val = ttest_1samp(effects, popmean=0)

        all_group_results.append({
            "session": session,
            "ch_name": ch_name,
            "n_subjects": len(effects),
            "mean_effect": effects.mean(),
            "std_effect": effects.std(ddof=1),
            "t_stat": t_stat,
            "p_value": p_val,
        })

# Step 2: Create group-level DataFrame
group_df = pd.DataFrame(all_group_results)

# create a new column for significant channels based on p-value
group_df["significant"] = group_df["p_value"] < 0.05


# Step 4: Compute R_quantity and R_overlap
sig_ses1 = set(group_df[(group_df["session"] == "01") & (group_df["significant"])]["ch_name"])
sig_ses2 = set(group_df[(group_df["session"] == "02") & (group_df["significant"])]["ch_name"])

A1 = len(sig_ses1)
A2 = len(sig_ses2)
A_overlap = len(sig_ses1 & sig_ses2)


R_quantity= 1- ((abs(A1 - A2) )/ (A1 + A2))

R_overlap = (2 * A_overlap) / (A1 + A2) if (A1 + A2) > 0 else float('nan')

# Step 5: Print results
print(f"Session 01: {A1} significant channels")
print(f"Session 02: {A2} significant channels")
print(f"Overlap   : {A_overlap} channels")
print(f"R_quantity: {R_quantity:.2f}")
print(f"R_overlap : {R_overlap:.2f}")

# Optional: Show group-level significant channels
print("\nGroup-level significant channels by session:")
for session in ["01", "02"]:
    sig_chs = group_df[(group_df["session"] == session) & (group_df["significant"])]["ch_name"].tolist()
    print(f"Session {session}:")
    for ch in sig_chs:
        print(f"  - {ch}")
    print()
# Out:
# Session 01: 3 significant channels
# Session 02: 3 significant channels
# Overlap   : 2 channels
# R_quantity: 1.00
# R_overlap : 0.67
#
# Group-level significant channels by session:
# Session 01:
#   - S10_D12 hbo
#   - S11_D11 hbo
#   - S11_D12 hbo
#
# Session 02:
#   - S10_D11 hbo
#   - S11_D11 hbo
#   - S11_D12 hbo

# %% [markdown]
# #### Apply FDR?

# %%
import pandas as pd
from scipy.stats import ttest_1samp

# Optional: Filter by Chroma if needed
df_filtered = df_con_noise[df_con_noise["Chroma"] == "hbo"].copy()

# Initialize list to collect group-level results
all_group_results = []

# Step 1: Group-level stats for each session
for session in df_filtered["session"].unique():
    df_ses = df_filtered[df_filtered["session"] == session]

    for ch_name, group in df_ses.groupby("ch_name"):
        effects = group["effect"].dropna().values
        if len(effects) < 2:
            continue  # Not enough data for a t-test

        t_stat, p_val = ttest_1samp(effects, popmean=0)

        all_group_results.append({
            "session": session,
            "ch_name": ch_name,
            "n_subjects": len(effects),
            "mean_effect": effects.mean(),
            "std_effect": effects.std(ddof=1),
            "t_stat": t_stat,
            "p_value": p_val,
        })

# Step 2: Create group-level DataFrame
group_df = pd.DataFrame(all_group_results)

# create a new column for significant channels based on p-value
group_df["significant"] = group_df["p_value"] < 0.05


# Step 4: Compute R_quantity and R_overlap
sig_ses1 = set(group_df[(group_df["session"] == "01") & (group_df["significant"])]["ch_name"])
sig_ses2 = set(group_df[(group_df["session"] == "02") & (group_df["significant"])]["ch_name"])

# %%
sig_ses1
# Out:
# {'S10_D12 hbo', 'S11_D11 hbo', 'S11_D12 hbo'}

# %%
# FDR
q = 0.2
m = 25 # Total number of unique channels
# run on each session separately

for session in ["01", "02"]:
    df_ses = group_df[(group_df["session"] == session) & (group_df["significant"])]
    p_values = df_ses["p_value"].values
    sorted_p_values = np.sort(p_values)
    
    for i in range(len(sorted_p_values)):
        p_val = sorted_p_values[i]
        threshold = (q * (i + 1)) / m
        
        if p_val <= threshold:
            print(f"Session {session} - Channel {df_ses.iloc[i]['ch_name']} is significant with p-value {p_val:.4f} and threshold {threshold:.4f}")
        else:
            print(f"Session {session} - Channel {df_ses.iloc[i]['ch_name']} is not significant with p-value {p_val:.4f} and threshold {threshold:.4f}")
# Out:
# Session 01 - Channel S10_D12 hbo is not significant with p-value 0.0090 and threshold 0.0080
# Session 01 - Channel S11_D11 hbo is not significant with p-value 0.0172 and threshold 0.0160
# Session 01 - Channel S11_D12 hbo is not significant with p-value 0.0328 and threshold 0.0240
# Session 02 - Channel S10_D11 hbo is significant with p-value 0.0008 and threshold 0.0080
# Session 02 - Channel S11_D11 hbo is significant with p-value 0.0044 and threshold 0.0160
# Session 02 - Channel S11_D12 hbo is significant with p-value 0.0220 and threshold 0.0240

# %%
A1 = len(sig_ses1)
A2 = len(sig_ses2)
A_overlap = len(sig_ses1 & sig_ses2)


R_quantity= 1- ((abs(A1 - A2) )/ (A1 + A2))

R_overlap = (2 * A_overlap) / (A1 + A2) if (A1 + A2) > 0 else float('nan')

# Step 5: Print results
print(f"Session 01: {A1} significant channels")
print(f"Session 02: {A2} significant channels")
print(f"Overlap   : {A_overlap} channels")
print(f"R_quantity: {R_quantity:.2f}")
print(f"R_overlap : {R_overlap:.2f}")

# Optional: Show group-level significant channels
print("\nGroup-level significant channels by session:")
for session in ["01", "02"]:
    sig_chs = group_df[(group_df["session"] == session) & (group_df["significant"])]["ch_name"].tolist()
    print(f"Session {session}:")
    for ch in sig_chs:
        print(f"  - {ch}")
    print()

# %% [markdown]
# ### Control vs Speech

# %%
import pandas as pd
from scipy.stats import ttest_1samp
from statsmodels.stats.multitest import multipletests

# Optional: Filter by Chroma if needed
df_filtered = df_con_speech[df_con_speech["Chroma"] == "hbo"].copy()

# Initialize list to collect group-level results
all_group_results = []

# Step 1: Group-level stats for each session
for session in df_filtered["session"].unique():
    df_ses = df_filtered[df_filtered["session"] == session]

    for ch_name, group in df_ses.groupby("ch_name"):
        effects = group["effect"].dropna().values
        if len(effects) < 2:
            continue  # Not enough data for a t-test

        t_stat, p_val = ttest_1samp(effects, popmean=0)

        all_group_results.append({
            "session": session,
            "ch_name": ch_name,
            "n_subjects": len(effects),
            "mean_effect": effects.mean(),
            "std_effect": effects.std(ddof=1),
            "t_stat": t_stat,
            "p_value": p_val,
        })

# Step 2: Create group-level DataFrame
group_df = pd.DataFrame(all_group_results)

# create a new column for significant channels based on p-value
group_df["significant"] = group_df["p_value"] < 0.05


# Step 4: Compute R_quantity and R_overlap
sig_ses1 = set(group_df[(group_df["session"] == "01") & (group_df["significant"])]["ch_name"])
sig_ses2 = set(group_df[(group_df["session"] == "02") & (group_df["significant"])]["ch_name"])

A1 = len(sig_ses1)
A2 = len(sig_ses2)
A_overlap = len(sig_ses1 & sig_ses2)

R_quantity= 1- ((abs(A1 - A2) )/ (A1 + A2))
R_overlap = (2 * A_overlap) / (A1 + A2) if (A1 + A2) > 0 else float('nan')

# Step 5: Print results
print(f"Session 01: {A1} significant channels")
print(f"Session 02: {A2} significant channels")
print(f"Overlap   : {A_overlap} channels")
print(f"R_quantity: {R_quantity:.2f}")
print(f"R_overlap : {R_overlap:.2f}")

# Optional: Show group-level significant channels
print("\nGroup-level significant channels by session:")
for session in ["01", "02"]:
    sig_chs = group_df[(group_df["session"] == session) & (group_df["significant"])]["ch_name"].tolist()
    print(f"Session {session}:")
    for ch in sig_chs:
        print(f"  - {ch}")
    print()
# Out:
# Session 01: 4 significant channels
# Session 02: 6 significant channels
# Overlap   : 4 channels
# R_quantity: 0.80
# R_overlap : 0.80
#
# Group-level significant channels by session:
# Session 01:
#   - S11_D11 hbo
#   - S11_D12 hbo
#   - S4_D2 hbo
#   - S7_D7 hbo
#
# Session 02:
#   - S10_D11 hbo
#   - S11_D11 hbo
#   - S11_D12 hbo
#   - S4_D2 hbo
#   - S7_D6 hbo
#   - S7_D7 hbo

# %%
# FDR
q = 0.05
m = 25 # Total number of unique channels
# run on each session separately

for session in ["01", "02"]:
    df_ses = group_df[(group_df["session"] == session) & (group_df["significant"])]
    p_values = df_ses["p_value"].values
    sorted_p_values = np.sort(p_values)
    
    for i in range(len(sorted_p_values)):
        p_val = sorted_p_values[i]
        threshold = (q * (i + 1)) / m
        
        if p_val <= threshold:
            print(f"Session {session} - Channel {df_ses.iloc[i]['ch_name']} is significant with p-value {p_val:.4f} and threshold {threshold:.4f}")
        else:
            print(f"Session {session} - Channel {df_ses.iloc[i]['ch_name']} is not significant with p-value {p_val:.4f} and threshold {threshold:.4f}")
# Out:
# Session 01 - Channel S11_D11 hbo is not significant with p-value 0.0034 and threshold 0.0020
# Session 01 - Channel S11_D12 hbo is not significant with p-value 0.0070 and threshold 0.0040
# Session 01 - Channel S4_D2 hbo is not significant with p-value 0.0079 and threshold 0.0060
# Session 01 - Channel S7_D7 hbo is not significant with p-value 0.0206 and threshold 0.0080
# Session 02 - Channel S10_D11 hbo is significant with p-value 0.0002 and threshold 0.0020
# Session 02 - Channel S11_D11 hbo is not significant with p-value 0.0070 and threshold 0.0040
# Session 02 - Channel S11_D12 hbo is not significant with p-value 0.0099 and threshold 0.0060
# Session 02 - Channel S4_D2 hbo is not significant with p-value 0.0114 and threshold 0.0080
# Session 02 - Channel S7_D6 hbo is not significant with p-value 0.0176 and threshold 0.0100
# Session 02 - Channel S7_D7 hbo is not significant with p-value 0.0286 and threshold 0.0120

# %% [markdown]
# # ICC

# %%
import pandas as pd
from pingouin import intraclass_corr

# --- Define ROIs (without ' hbo') ---
rois = {
    "Noise_WAA_FDR": [ "S4_D2 hbo", "S5_D2 hbo", "S5_D3 hbo", "S10_D9 hbo", "S10_D10 hbo", "S10_D11 hbo", "S10_D12 hbo"],
    "Speech_WAA_FDR": ["S5_D2 hbo", "S5_D4 hbo","S10_D9 hbo","S10_D10 hbo", "S10_D11 hbo",  "S10_D12 hbo",  "S11_D11 hbo"],
    
    
    "Noise_WAA": ["S11_D11 hbo" ],
    "Speech_WAA": [ "S5_D4 hbo","S10_D9 hbo","S10_D10 hbo", "S10_D11 hbo",  "S11_D11 hbo",  "S11_D12 hbo"],
    
    
    "Noise_GLM_FDR": ["S10_D11 hbo", "S11_D12 hbo"],
    "Speech_GLM_FDR": [ "S4_D2 hbo", "S4_D3 hbo", "S5_D3 hbo", "S6_D8 hbo","S7_D7 hbo", "S8_D7 hbo"],
    
    "Noise_GLM": ["S11_D11 hbo", "S11_D12 hbo"],
    "Speech_GLM": ["S4_D2 hbo", "S4_D3 hbo","S5_D3 hbo",  "S7_D7 hbo", "S9_D8 hbo","S11_D11 hbo", "S11_D12 hbo"],
    
    "Left_Auditory": ["S4_D2 hbo", "S4_D3 hbo", "S5_D2 hbo", "S5_D3 hbo", "S5_D4 hbo", "S5_D5 hbo"],
    "Right_Auditory": ["S10_D9 hbo", "S10_D10 hbo", "S10_D11 hbo", "S10_D12 hbo", "S11_D11 hbo", "S11_D12 hbo"],
    "Visual": ["S6_D6 hbo", "S6_D8 hbo", "S7_D6 hbo", "S7_D7 hbo","S8_D7 hbo", "S8_D8 hbo", "S9_D8 hbo", "S7_D8 hbo"],
    "Front": ["S1_D1 hbo", "S2_D1 hbo", "S3_D1 hbo", "S3_D2 hbo","S12_D1 hbo"] 
}
# --- Remove ' hbo' from optode names in ROIs ---
rois = {roi: [opt.replace(" hbo", "") for opt in optodes] for roi, optodes in rois.items()}



df_combined = pd.read_csv("all_subjects_evoked_values_optodes.csv")

# Filter for HbO only
df_combined = df_combined[df_combined["Chroma"] == "hbo"].copy()

# --- ICC computation ---
results_list = []

for roi_name, optodes in rois.items():
    print(f"Processing ROI: {roi_name}")
    
    # Filter for relevant optodes only
    subset = df_combined[df_combined["Optode"].isin(optodes)]

    # Mean over optodes per subject/session/condition (but do NOT average across conditions)
    mean_values = subset.groupby(["Subject", "session", "Condition"])["theta"].mean().reset_index()

    # Replicates for each Subject-Session (Condition = replicate)
    # ICC expects: targets (subjects), raters (sessions), ratings (values)
    icc_input = mean_values.rename(columns={
        "Subject": "targets",
        "session": "raters",
        "theta": "scores"
    })
    
    #print(icc_input.head())

    # ICC(3,1): Two-way mixed, single measurement, consistency
    icc = intraclass_corr(data=icc_input, targets="targets", raters="raters", ratings="scores")

    icc_3_1 = icc[icc["Type"] == "ICC3"].iloc[0]  # ICC(3,1)

    results_list.append({
        "ROI": roi_name,
        "ICC": icc_3_1["ICC"],
        "CI95_low": icc_3_1["CI95%"][0],
        "CI95_high": icc_3_1["CI95%"][1],
        "F": icc_3_1["F"],
        "pval": icc_3_1["pval"]
    })

# Save to CSV
results_df = pd.DataFrame(results_list)
results_df.to_csv("icc_results_combined_conditions.csv", index=False)
print("✅ ICC results saved to 'icc_results_combined_conditions.csv'")
# Out:
# Processing ROI: Noise_WAA_FDR
# Processing ROI: Speech_WAA_FDR
# Processing ROI: Noise_WAA
# Processing ROI: Speech_WAA
# Processing ROI: Noise_GLM_FDR
# Processing ROI: Speech_GLM_FDR
# Processing ROI: Noise_GLM
# Processing ROI: Speech_GLM
# Processing ROI: Left_Auditory
# Processing ROI: Right_Auditory
# Processing ROI: Visual
# Processing ROI: Front
# ✅ ICC results saved to 'icc_results_combined_conditions.csv'

# %% [markdown]
# ## Bland-Altmann Plots

# %%
# Get unique experimental conditions
conditions = df_combined["Condition"].unique()
df_combined["session"] = df_combined["session"].astype(str).str.zfill(2)

# --- Bland-Altman plots per ROI and condition ---
for roi_name, optodes in rois.items():
    fig, axes = plt.subplots(1, len(conditions), figsize=(6 * len(conditions), 5), sharey=True)
    if len(conditions) == 1:
        axes = [axes]  # Ensure iterable if only one condition

    for ax, condition in zip(axes, conditions):
        # Filter data for current ROI and condition
        subset = df_combined[
            (df_combined["Optode"].isin(optodes)) & 
            (df_combined["Condition"] == condition)
        ]

        # Average over optodes for each subject and session
        mean_vals = subset.groupby(["Subject", "session"])["theta"].mean().reset_index()

        # Pivot so each subject has session 01 and 02 as columns
        pivot = mean_vals.pivot(index="Subject", columns="session", values="theta").dropna()

        if pivot.shape[0] < 2:
            ax.set_title(f'{condition}\nNot enough data')
            ax.axis('off')
            continue

        # Bland-Altman calculations
        session1 = pivot["01"]
        session2 = pivot["02"]
        avg = (session1 + session2) / 2
        diff = session1 - session2
        mean_diff = diff.mean()
        std_diff = diff.std()

        # Plot
        sns.scatterplot(x=avg, y=diff, ax=ax)
        ax.axhline(mean_diff, color='red', linestyle='--', label=f'Mean diff = {mean_diff:.3f}')
        ax.axhline(mean_diff + 1.96 * std_diff, color='gray', linestyle='--', label='+1.96 SD')
        ax.axhline(mean_diff - 1.96 * std_diff, color='gray', linestyle='--', label='-1.96 SD')
        ax.set_title(f'{condition}')
        ax.set_xlabel('Mean of Session 1 and 2')
        if ax == axes[0]:
            ax.set_ylabel('Difference (Session 1 - Session 2)')
            ax.set_ylim(-8, 8)
        else:
            ax.set_ylabel('')
        ax.legend()

    plt.suptitle(f'Bland-Altman Plot per Condition\nROI: {roi_name}', fontsize=14)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()
