# %%
# sphinx_gallery_thumbnail_number = 2

# Authors: Robert Luke <mail@robertluke.net>
#
# License: BSD (3-clause)

# Import common libraries
from collections import defaultdict
from copy import deepcopy
from itertools import compress
from pprint import pprint

# Import Plotting Library
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import os
import pywt


# Import StatsModels
import statsmodels.formula.api as smf
from mne import Epochs, events_from_annotations, set_log_level
from mne.preprocessing.nirs import (
    beer_lambert_law,
    optical_density,
    scalp_coupling_index,
    temporal_derivative_distribution_repair,
    
)

# Import MNE processing
from mne.viz import plot_compare_evokeds

# Import MNE-BIDS processing
from mne_bids import BIDSPath, read_raw_bids


# Import MNE-NIRS processing
from mne_nirs.channels import get_long_channels, picks_pair_to_idx
from mne_nirs.datasets import fnirs_motor_group
from mne_nirs.signal_enhancement import (enhance_negative_correlation, short_channel_regression)
from mne_nirs.channels import (get_long_channels,
                               get_short_channels,
                               picks_pair_to_idx)

from collections import defaultdict
import numpy as np
from itertools import compress
from sklearn.decomposition import PCA
import mne


# Set general parameters
set_log_level("WARNING")  # Don't show info, as it is repetitive for many subjects

tmin=-3
tmax=14

# %%
# cropping the signal before sci calculation
def individual_analysis(bids_path):
    # Read data with annotations in BIDS format
    raw_intensity = read_raw_bids(bids_path=bids_path, verbose=False)
    # check if coordinates of the channels
    
    
    #print(raw_intensity.ch_names)

    
    # Get event timings
    #print("Extracting event timings...")
    Breaks, _ = mne.events_from_annotations(raw_intensity, {'Xstart': 4, 'Xend': 5})
    AllEvents, _ = mne.events_from_annotations(raw_intensity)
    Breaks = Breaks[:, 0] / raw_intensity.info['sfreq']
    LastEvent = AllEvents[-1, 0] / raw_intensity.info['sfreq']
    
    if len(Breaks) % 2 == 0:
        raise ValueError("Breaks array should have an odd number of elements.")
    
    original_duration = raw_intensity.times[-1] - raw_intensity.times[0]
    #print(f"Original duration: {original_duration:.2f} seconds")
    
    # Cropping dataset
    #print("Cropping the dataset...")
    cropped_intensity = raw_intensity.copy().crop(Breaks[0], Breaks[1])
    for j in range(2, len(Breaks) - 1, 2):
        block = raw_intensity.copy().crop(Breaks[j], Breaks[j + 1])
        cropped_intensity.append(block)
    cropped_intensity.append(raw_intensity.copy().crop(Breaks[-1], LastEvent + 15.25))
    
    cropped_duration = cropped_intensity.times[-1] - cropped_intensity.times[0]
    #print(f"Cropped duration: {cropped_duration:.2f} seconds")
    
    if cropped_duration >= original_duration:
        print(f"WARNING: Cropping did not reduce duration!")
    
    raw_intensity_cropped = cropped_intensity.copy()

    

    
    # Remove break annotations
    #print("Removing break annotations for the orginal raw...")
    raw_intensity.annotations.delete(np.where(
        (raw_intensity.annotations.description == 'Xstart') | 
        (raw_intensity.annotations.description == 'Xend') | 
        (raw_intensity.annotations.description == 'BAD boundary') | 
        (raw_intensity.annotations.description == 'EDGE boundary')
    )[0])
    
    #print("Removing break annotations for the cropped raw...")
    raw_intensity_cropped.annotations.delete(np.where(
        (raw_intensity_cropped.annotations.description == 'Xstart') | 
        (raw_intensity_cropped.annotations.description == 'Xend') | 
        (raw_intensity_cropped.annotations.description == 'BAD boundary') | 
        (raw_intensity_cropped.annotations.description == 'EDGE boundary')
    )[0]) 
    
    
    
    # Convert signal to optical density and determine bad channels
    raw_od = optical_density(raw_intensity)
    raw_od_cropped = optical_density(raw_intensity_cropped)
    
    # get the total number of short channels
    short_chs = get_short_channels(raw_od)
    tot_number_of_short_channels = len(short_chs.ch_names)
    

    # sci calculated
    sci = scalp_coupling_index(raw_od_cropped, l_freq=0.7, h_freq=1.45)
    #sci = scalp_coupling_index(raw_od_cropped, h_freq=1.35)
    bad_channels= list(compress(raw_od.ch_names, sci < 0.8))
    
    if len(bad_channels) > 55:
        print(f"❌ Too many bad channels ({len(bad_channels)}). Excluding subject from analysis.")
        return None, None, None, None, None
    
    raw_od.info["bads"] = bad_channels
    raw_intensity_cropped.info["bads"] = bad_channels
    
    #print(f"Bad channels: {raw_od.info['bads']}")
    # print the number of bad channels
    #print(f"Number of bad channels: {len(raw_od.info['bads'])}")
    
    # Remove bad channels
   
    """ raw_od.drop_channels(bad_channels)
    raw_intensity_cropped.drop_channels(bad_channels) """
    
    raw_od = temporal_derivative_distribution_repair(raw_od)
    raw_od_cropped = temporal_derivative_distribution_repair(raw_od_cropped)

    
     # Get long channels
    long_chs = get_long_channels(raw_od)
    bad_long_chs = long_chs.info["bads"]
    
    """ print(f"Number of all (good and bad) short channels: {tot_number_of_short_channels}")
    print(f"Number of bad long channels: {len(bad_long_chs)}")
    print(f"Number of long and short bad channels: {len(bad_channels)}") """
    # print the number of short bad channels
    len_bad_short_chs = len(bad_channels) - len(bad_long_chs)
    num_good_short_channels = tot_number_of_short_channels - len_bad_short_chs
    # Print diagnostics
    """ print(f"Number of all (good and bad) short channels: {tot_number_of_short_channels}")
    print(f"Number of bad long channels: {len(bad_long_chs)}")
    print(f"Number of bad short channels: {len_bad_short_chs}")
    print(f"✅ Number of good short channels: {num_good_short_channels}") """
    #print(f"Number of bad short channels: {len_bad_short_chs}")
    
    # Determine if there are short channels
    if num_good_short_channels < 4:
        print("❌ No short channels found. Skipping the subject.")
        return None, None, None, None, None # Keep the data unchanged
    else:
        #print("Applying short-channel regression.")
        raw_od_corrected = short_channel_regression(raw_od)
        #raw_od_corrected=raw_od.copy()
        # drop the bad channels
        #raw_od_corrected.drop_channels(bad_channels)
        
        # interpolate the bad channels
        #raw_od_corrected.interpolate_bads()
        
    # short-channel regression subtracts a scaled version of the signal obtained from the nearest short channel from the signal obtained from the long channel. 

    raw_haemo = beer_lambert_law(raw_od_corrected, ppf=0.1)
    
    #raw_haemo = get_long_channels(raw_haemo, min_dist=0.02, max_dist=0.04) # max_dist 40mm
    raw_haemo = get_long_channels(raw_haemo, min_dist=0.02) 
    
    
   
    

    # Convert to haemoglobin and filter
    
    # check the ppf
    
    #raw_haemo.plot_psd(average=True, show=True)
    
    """ raw_haemo = raw_haemo.filter(
    l_freq=0.01, h_freq=0.7, method="fir", fir_design="firwin", verbose=False,
    h_trans_bandwidth=0.3, l_trans_bandwidth=0.005) """
    
    # improved filter
    """ raw_haemo = raw_haemo.filter(
    l_freq=0.05, h_freq=0.2, method="fir", fir_design="firwin", verbose=False,
    h_trans_bandwidth=0.01, l_trans_bandwidth=0.01) """
    
    #raw_haemo.plot_psd(average=True, show=True)

    raw_haemo = raw_haemo.filter(l_freq = None, h_freq = 0.2,  
                                 method="iir", iir_params =dict(order=5, ftype='butter'))
     #high-pass
    raw_haemo= raw_haemo.filter(l_freq =  0.05, h_freq = None, method="iir", iir_params =dict(order=5, ftype='butter')) #t0.05 was cutoff in andreas analysis
      
    """ # drop the bad channels
    raw_heamo_good = raw_haemo.copy()
    
    raw_heamo_good.drop_channels(raw_haemo.info['bads']) """
    
    
    #raw_haemo.plot(n_channels=len(raw_haemo.ch_names), duration=5000,show_scrollbars=True )

    # Extract events but ignore those with
    # the word Ends (i.e. drop ExperimentEnds events)
    events, event_dict = events_from_annotations(
        raw_haemo, verbose=False, regexp="^(?![Ends]).*$"
    )
    epochs = Epochs(
        raw_haemo,
        events,
        event_id=event_dict,
        tmin=-3,
        tmax=14,
        reject=dict(hbo=100e-6),
        reject_by_annotation=True,
        proj=True,
        baseline=(None, 0),
        detrend=1,
        preload=True,
        verbose=None,
    )
    """ epochs['Control'].plot()
    epochs['Noise'].plot()
    epochs['Speech'].plot()
     """


    return raw_haemo, epochs, event_dict, raw_od, events

# %% [markdown]
# # Individual participant's mean+std dev

# %%
import os
import numpy as np
import pandas as pd
from collections import defaultdict
from mne_bids import BIDSPath

# === Paths ===
bids_root = r"C:\Datasets\Test-retest study\bids_dataset"
output_root = "individual_analysis_outputs"
os.makedirs(output_root, exist_ok=True)

# === List subjects ===
subject_list = sorted([d for d in os.listdir(bids_root) if d.startswith("sub-")])
subject_list = [s.replace("sub-", "") for s in subject_list]
print("Detected subjects:", subject_list)

# === Storage ===
summary_stats = []

# === Loop over subjects and sessions ===
for sub in subject_list:
    for ses in range(1, 3):
        bids_path = BIDSPath(
            subject=f"{sub}",
            session=f"{ses:02d}",
            task="auditory",
            datatype="nirs",
            root=bids_root,
            suffix="nirs",
            extension=".snirf",
        )

        raw_haemo, epochs, event_dict, raw_od, events = individual_analysis(bids_path)

        if raw_haemo is None or len(epochs) < 10:
            print(f"⚠️ Skipping sub-{sub} ses-{ses:02d} (not enough channels or epochs)")
            continue

        # Output directory
        output_dir = os.path.join(output_root, f"sub-{sub}", f"ses-{ses:02d}")
        os.makedirs(output_dir, exist_ok=True)

        # Drop bad channels
        epochs.drop_channels(epochs.info['bads'])

        # Pick only HbO
        hbo_epochs = epochs.copy().pick("hbo")
        #hbo_epochs.crop(tmin=0.0, tmax=10.0)

        for condition in hbo_epochs.event_id:
            condition_epochs = hbo_epochs[condition]

            if len(condition_epochs) < 3:
                print(f"⚠️ Skipping {condition} for sub-{sub} ses-{ses:02d} (too few epochs)")
                continue

            data = condition_epochs.get_data()  # shape: (n_epochs, n_channels, n_times)

            # Compute average amplitude across all channels and time points, per epoch
            epoch_means = np.mean(data, axis=(1, 2))  # shape: (n_epochs,)

            # Compute mean and std dev across epochs
            mean_all = np.mean(epoch_means)
            std_all = np.std(epoch_means, ddof=1)

            summary_stats.append({
                "Subject": f"sub-{sub}",
                "Session": f"ses-{ses:02d}",
                "Condition": condition,
                "Mean_Amplitude": mean_all,
                "SD_Amplitude": std_all,
                "Num_Epochs": len(condition_epochs)
            })

        print(f"✅ Finished sub-{sub} ses-{ses:02d}")

# === Save summary stats ===
stats_df = pd.DataFrame(summary_stats)

# save to csv
stats_df.to_csv(os.path.join(output_root, "individual_mean_stddev_zscore.csv"), index=False)
# Out:
# Detected subjects: ['01', '02', '03', '04', '05', '07', '08', '10', '11', '12', '13', '16', '17', '19', '21', '24']
# ✅ Finished sub-01 ses-01
# ✅ Finished sub-01 ses-02
# ✅ Finished sub-02 ses-01
# ✅ Finished sub-02 ses-02
# ✅ Finished sub-03 ses-01
# ✅ Finished sub-03 ses-02
# ✅ Finished sub-04 ses-01
# ✅ Finished sub-04 ses-02
# ✅ Finished sub-05 ses-01
# ✅ Finished sub-05 ses-02
# ✅ Finished sub-07 ses-01
# ✅ Finished sub-07 ses-02
# ✅ Finished sub-08 ses-01
# ✅ Finished sub-08 ses-02
# ✅ Finished sub-10 ses-01
# ✅ Finished sub-10 ses-02
# ✅ Finished sub-11 ses-01
# ✅ Finished sub-11 ses-02
# ✅ Finished sub-12 ses-01
# ✅ Finished sub-12 ses-02
# ✅ Finished sub-13 ses-01
# ✅ Finished sub-13 ses-02
# ✅ Finished sub-16 ses-01
# ✅ Finished sub-16 ses-02
# ✅ Finished sub-17 ses-01
# ✅ Finished sub-17 ses-02
# ✅ Finished sub-19 ses-01
# ✅ Finished sub-19 ses-02
# ✅ Finished sub-21 ses-01
# ✅ Finished sub-21 ses-02
# ✅ Finished sub-24 ses-01
# ✅ Finished sub-24 ses-02

# %% [markdown]
# # Individual mean + std dev rejection

# %%
def reject_epochs_zscore_individual(data, subject, session, condition_name, stats_df, z_thresh=3.0, max_reject_ratio=1.0):
    """
    Rejects epochs based on z-score threshold using subject/session/condition-specific stats from stats_df.

    Parameters:
        data (ndarray): (n_epochs, n_times) or (n_epochs,) averaged data per epoch
        subject (str): e.g., "sub-01"
        session (str): e.g., "ses-01"
        condition_name (str): "Control", "Noise", or "Speech"
        stats_df (pd.DataFrame): DataFrame with per-participant mean and std
        z_thresh (float): Z-score threshold
        max_reject_ratio (float): Max proportion of epochs to reject

    Returns:
        cleaned_data (ndarray), rejected_indices (list)
    """
    row = stats_df[
        (stats_df["Subject"] == f"sub-{subject}") &
        (stats_df["Session"] == f"ses-{session}") &
        (stats_df["Condition"] == condition_name)
    ]

    if row.empty:
        raise ValueError(f"No stats found for {subject}, {session}, {condition_name}")

    mean = row["Mean_Amplitude"].values[0]
    std = row["SD_Amplitude"].values[0]

    z_scores = (data - mean) / std
    reject_mask = np.abs(z_scores) > z_thresh
    rejected_indices = np.where(reject_mask)[0].tolist()

    # Limit rejections
    max_reject = int(max_reject_ratio * data.shape[0])
    if len(rejected_indices) > max_reject:
        rejected_indices = rejected_indices[:max_reject]

    cleaned_data = np.delete(data, rejected_indices, axis=0)
    return cleaned_data, rejected_indices

# %%
from scipy.stats import ttest_ind
# === Setup ===
output_root = "individual_analysis_outputs"
os.makedirs(output_root, exist_ok=True)

bids_root = r"C:\\Datasets\\Test-retest study\\bids_dataset"
subject_list = sorted([d for d in os.listdir(bids_root) if d.startswith("sub-")])
subject_list = [s.replace("sub-", "") for s in subject_list]

print("Detected subjects:", subject_list)

ttest_results = []


for sub in subject_list:
    for ses in range(1, 3):
        bids_path = BIDSPath(
            subject=f"{sub}",
            session=f"{ses:02d}",
            task="auditory",
            datatype="nirs",
            root=bids_root,
            suffix="nirs",
            extension=".snirf",
        )
        print(f"Processing Subject {sub}, Session {ses:02d}")

        raw_haemo, epochs, event_dict, raw_od, events = individual_analysis(bids_path)

        if raw_haemo is None or len(epochs) < 10:
            print(f"⚠️ Skipping Subject {sub}, Session {ses:02d} (insufficient data)")
            continue

        epochs.drop_channels(epochs.info['bads'])
        epochs_cleaned = epochs.copy().pick("hbo")
        #epochs_cleaned.crop(tmin=0.0, tmax=10.0)

        # Get data and labels
        data = epochs_cleaned.get_data().mean(axis=1)  # (n_epochs, n_channels, n_times)
        data_mean = data.mean(axis=1)
        ev = epochs_cleaned.events[:, 2]
        index_column = np.arange(0, len(ev)).reshape(-1, 1)
        labels = np.hstack((index_column, ev.reshape(-1, 1)))

        # Reject epochs per condition
        conditions = {1: "Control", 2: "Noise", 3: "Speech"}
        all_rejected = []
        for cond_code, cond_name in conditions.items():
            cond_idx = labels[labels[:, 1] == cond_code][:, 0].astype(int)
            cond_data = data_mean[cond_idx]

            try:
                cleaned, rejected = reject_epochs_zscore_individual(
                    cond_data,
                    subject=sub,
                    session=f"{ses:02d}",
                    condition_name=cond_name,
                    stats_df=stats_df,
                    z_thresh=2
                )
            except ValueError as e:
                print(f"⚠️ {e}")
                continue

            rejected_indices = [cond_idx[i] for i in rejected]
            all_rejected.extend(rejected_indices)
            print(f"Subject {sub}, Session {ses:02d} - Rejected {len(rejected)} epochs in {cond_name}")

        # Drop all rejected epochs
        epochs_cleaned.drop(all_rejected)

        # === ROI definitions ===
        roi_definitions = {
            "Noise_ROI": ["S10_D11 hbo", "S5_D3 hbo", "S11_D11 hbo", "S10_D9 hbo", "S10_D12 hbo", "S10_D10 hbo"],
            "Speech_ROI": ["S10_D11 hbo", "S10_D10 hbo", "S10_D12 hbo", "S11_D12 hbo", "S1_D1 hbo", "S10_D9 hbo", "S8_D7 hbo", "S7_D7 hbo", "S8_D8 hbo"],
            "Common_ROI": ["S10_D11 hbo", "S10_D9 hbo", "S10_D12 hbo", "S10_D10 hbo"],
            "Only_Noise_ROI": ["S5_D3 hbo", "S11_D11 hbo"],
            "Only_Speech_ROI": ["S11_D12 hbo", "S1_D1 hbo", "S8_D7 hbo", "S7_D7 hbo", "S8_D8 hbo"],
            "Left_Auditory": ["S4_D2 hbo", "S4_D3 hbo", "S5_D2 hbo", "S5_D3 hbo", "S5_D4 hbo", "S5_D5 hbo"],
            "Right_Auditory": ["S10_D9 hbo", "S10_D10 hbo", "S10_D11 hbo", "S10_D12 hbo", "S11_D11 hbo", "S11_D12 hbo"],
            "Visual": ["S6_D6 hbo", "S6_D8 hbo", "S7_D6 hbo", "S7_D7 hbo", "S8_D7 hbo", "S8_D8 hbo", "S9_D8 hbo", "S7_D8 hbo"],
            "Front": ["S1_D1 hbo", "S2_D1 hbo", "S3_D1 hbo", "S3_D2 hbo", "S12_D1 hbo"]
        }

        tmin, tmax = 4, 6
        for roi_name, optode_list in roi_definitions.items():
            available_optodes = [opt for opt in optode_list if opt in epochs_cleaned.info["ch_names"]]
            if len(available_optodes) < 2:
                continue

            try:
                cond_data = {}
                for cond in ["Control", "Noise", "Speech"]:
                    cond_epochs = epochs_cleaned[cond].copy().pick(available_optodes).crop(tmin=tmin, tmax=tmax)
                    data = cond_epochs.get_data()
                    cond_data[cond] = data.mean(axis=1).mean(axis=1) * 1e6

                if len(cond_data["Control"]) > 1 and len(cond_data["Noise"]) > 1:
                    t_stat, p_val = ttest_ind(cond_data["Control"], cond_data["Noise"], equal_var=False, alternative='less')
                    effect = np.mean(cond_data["Noise"]) - np.mean(cond_data["Control"])
                    ttest_results.append({"Subject": sub, "Session": f"{ses:02d}", "ROI": roi_name, "Comparison": "Control vs Noise", "t_stat": t_stat, "p_value": p_val, "Effect": effect})

                if len(cond_data["Control"]) > 1 and len(cond_data["Speech"]) > 1:
                    t_stat, p_val = ttest_ind(cond_data["Control"], cond_data["Speech"], equal_var=False, alternative='less')
                    effect = np.mean(cond_data["Speech"]) - np.mean(cond_data["Control"])
                    ttest_results.append({"Subject": sub, "Session": f"{ses:02d}", "ROI": roi_name, "Comparison": "Control vs Speech", "t_stat": t_stat, "p_value": p_val, "Effect": effect})

            except Exception as e:
                print(f"Error testing {roi_name} for Subject {sub}, Session {ses:02d}: {e}")

# === Save results ===
df_ttest = pd.DataFrame(ttest_results)

# === Summary per participant ===
print("\n=== Significant ROI Summary per Participant ===")
df_significant = df_ttest[df_ttest["p_value"] < 0.05]
if df_significant.empty:
    print("No significant ROIs found.")
else:
    grouped = df_significant.groupby(["Subject", "Session"])
    for (sub, ses), group in grouped:
        print(f"\nSubject: {sub}, Session: {ses}")
        for _, row in group.iterrows():
            sign = "↑" if row["Effect"] > 0 else "↓"
            print(f"  - {row['ROI']} ({row['Comparison']}): p = {row['p_value']:.4f}, effect = {row['Effect']:.4f} ({sign})")

print("\n✅ Done with ROI t-tests!")
# Out:
# Detected subjects: ['01', '02', '03', '04', '05', '07', '08', '10', '11', '12', '13', '16', '17', '19', '21', '24']
# Processing Subject 01, Session 01
# Subject 01, Session 01 - Rejected 2 epochs in Control
# Subject 01, Session 01 - Rejected 1 epochs in Noise
# Subject 01, Session 01 - Rejected 1 epochs in Speech
# Processing Subject 01, Session 02
# Subject 01, Session 02 - Rejected 2 epochs in Control
# Subject 01, Session 02 - Rejected 1 epochs in Noise
# Subject 01, Session 02 - Rejected 1 epochs in Speech
# Processing Subject 02, Session 01
# Subject 02, Session 01 - Rejected 1 epochs in Control
# Subject 02, Session 01 - Rejected 1 epochs in Noise
# Subject 02, Session 01 - Rejected 0 epochs in Speech
# Processing Subject 02, Session 02
# Subject 02, Session 02 - Rejected 1 epochs in Control
# Subject 02, Session 02 - Rejected 1 epochs in Noise
# Subject 02, Session 02 - Rejected 0 epochs in Speech
# Processing Subject 03, Session 01
# Subject 03, Session 01 - Rejected 0 epochs in Control
# Subject 03, Session 01 - Rejected 2 epochs in Noise
# Subject 03, Session 01 - Rejected 0 epochs in Speech
# Processing Subject 03, Session 02
# Subject 03, Session 02 - Rejected 0 epochs in Control
# Subject 03, Session 02 - Rejected 0 epochs in Noise
# Subject 03, Session 02 - Rejected 0 epochs in Speech
# Processing Subject 04, Session 01
# Subject 04, Session 01 - Rejected 1 epochs in Control
# Subject 04, Session 01 - Rejected 2 epochs in Noise
# Subject 04, Session 01 - Rejected 2 epochs in Speech
# Processing Subject 04, Session 02
# Subject 04, Session 02 - Rejected 0 epochs in Control
# Subject 04, Session 02 - Rejected 1 epochs in Noise
# Subject 04, Session 02 - Rejected 1 epochs in Speech
# Processing Subject 05, Session 01
# Subject 05, Session 01 - Rejected 1 epochs in Control
# Subject 05, Session 01 - Rejected 1 epochs in Noise
# Subject 05, Session 01 - Rejected 0 epochs in Speech
# Processing Subject 05, Session 02
# Subject 05, Session 02 - Rejected 0 epochs in Control
# Subject 05, Session 02 - Rejected 0 epochs in Noise
# Subject 05, Session 02 - Rejected 1 epochs in Speech
# Processing Subject 07, Session 01
# Subject 07, Session 01 - Rejected 0 epochs in Control
# Subject 07, Session 01 - Rejected 1 epochs in Noise
# Subject 07, Session 01 - Rejected 2 epochs in Speech
# Processing Subject 07, Session 02
# Subject 07, Session 02 - Rejected 2 epochs in Control
# Subject 07, Session 02 - Rejected 0 epochs in Noise
# Subject 07, Session 02 - Rejected 0 epochs in Speech
# Processing Subject 08, Session 01
# Subject 08, Session 01 - Rejected 1 epochs in Control
# Subject 08, Session 01 - Rejected 1 epochs in Noise
# Subject 08, Session 01 - Rejected 1 epochs in Speech
# Processing Subject 08, Session 02
# Subject 08, Session 02 - Rejected 1 epochs in Control
# Subject 08, Session 02 - Rejected 1 epochs in Noise
# Subject 08, Session 02 - Rejected 0 epochs in Speech
# Processing Subject 10, Session 01
# Subject 10, Session 01 - Rejected 1 epochs in Control
# Subject 10, Session 01 - Rejected 1 epochs in Noise
# Subject 10, Session 01 - Rejected 1 epochs in Speech
# Processing Subject 10, Session 02
# Subject 10, Session 02 - Rejected 1 epochs in Control
# Subject 10, Session 02 - Rejected 0 epochs in Noise
# Subject 10, Session 02 - Rejected 2 epochs in Speech
# Processing Subject 11, Session 01
# Subject 11, Session 01 - Rejected 0 epochs in Control
# Subject 11, Session 01 - Rejected 1 epochs in Noise
# Subject 11, Session 01 - Rejected 2 epochs in Speech
# Processing Subject 11, Session 02
# Subject 11, Session 02 - Rejected 0 epochs in Control
# Subject 11, Session 02 - Rejected 0 epochs in Noise
# Subject 11, Session 02 - Rejected 1 epochs in Speech
# Processing Subject 12, Session 01
# Subject 12, Session 01 - Rejected 0 epochs in Control
# Subject 12, Session 01 - Rejected 0 epochs in Noise
# Subject 12, Session 01 - Rejected 0 epochs in Speech
# Processing Subject 12, Session 02
# Subject 12, Session 02 - Rejected 1 epochs in Control
# Subject 12, Session 02 - Rejected 1 epochs in Noise
# Subject 12, Session 02 - Rejected 1 epochs in Speech
# Processing Subject 13, Session 01
# Subject 13, Session 01 - Rejected 0 epochs in Control
# Subject 13, Session 01 - Rejected 0 epochs in Noise
# Subject 13, Session 01 - Rejected 0 epochs in Speech
# Processing Subject 13, Session 02
# Subject 13, Session 02 - Rejected 0 epochs in Control
# Subject 13, Session 02 - Rejected 0 epochs in Noise
# Subject 13, Session 02 - Rejected 0 epochs in Speech
# Processing Subject 16, Session 01
# Subject 16, Session 01 - Rejected 2 epochs in Control
# Subject 16, Session 01 - Rejected 1 epochs in Noise
# Subject 16, Session 01 - Rejected 1 epochs in Speech
# Processing Subject 16, Session 02
# Subject 16, Session 02 - Rejected 1 epochs in Control
# Subject 16, Session 02 - Rejected 1 epochs in Noise
# Subject 16, Session 02 - Rejected 1 epochs in Speech
# Processing Subject 17, Session 01
# Subject 17, Session 01 - Rejected 0 epochs in Control
# Subject 17, Session 01 - Rejected 0 epochs in Noise
# Subject 17, Session 01 - Rejected 1 epochs in Speech
# Processing Subject 17, Session 02
# Subject 17, Session 02 - Rejected 0 epochs in Control
# Subject 17, Session 02 - Rejected 0 epochs in Noise
# Subject 17, Session 02 - Rejected 0 epochs in Speech
# Processing Subject 19, Session 01
# Subject 19, Session 01 - Rejected 1 epochs in Control
# Subject 19, Session 01 - Rejected 1 epochs in Noise
# Subject 19, Session 01 - Rejected 0 epochs in Speech
# Processing Subject 19, Session 02
# Subject 19, Session 02 - Rejected 0 epochs in Control
# Subject 19, Session 02 - Rejected 0 epochs in Noise
# Subject 19, Session 02 - Rejected 0 epochs in Speech
# Processing Subject 21, Session 01
# Subject 21, Session 01 - Rejected 2 epochs in Control
# Subject 21, Session 01 - Rejected 1 epochs in Noise
# Subject 21, Session 01 - Rejected 0 epochs in Speech
# Processing Subject 21, Session 02
# Subject 21, Session 02 - Rejected 1 epochs in Control
# Subject 21, Session 02 - Rejected 1 epochs in Noise
# Subject 21, Session 02 - Rejected 1 epochs in Speech
# Processing Subject 24, Session 01
# Subject 24, Session 01 - Rejected 0 epochs in Control
# Subject 24, Session 01 - Rejected 0 epochs in Noise
# Subject 24, Session 01 - Rejected 0 epochs in Speech
# Processing Subject 24, Session 02
# Subject 24, Session 02 - Rejected 1 epochs in Control
# Subject 24, Session 02 - Rejected 1 epochs in Noise
# Subject 24, Session 02 - Rejected 0 epochs in Speech
#
# === Significant ROI Summary per Participant ===
#
# Subject: 01, Session: 01
#   - Noise_ROI (Control vs Noise): p = 0.0000, effect = 9.1309 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0001, effect = 8.3252 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0000, effect = 7.7600 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0001, effect = 6.8516 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0000, effect = 10.7723 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0004, effect = 9.0649 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0000, effect = 5.8481 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0000, effect = 6.8459 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0000, effect = 5.3502 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0001, effect = 5.0810 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0000, effect = 5.8756 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0006, effect = 5.7777 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0000, effect = 8.4201 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0001, effect = 7.7635 (↑)
#   - Visual (Control vs Noise): p = 0.0000, effect = 6.5401 (↑)
#   - Visual (Control vs Speech): p = 0.0001, effect = 5.7725 (↑)
#
# Subject: 01, Session: 02
#   - Noise_ROI (Control vs Speech): p = 0.0121, effect = 4.4455 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0087, effect = 5.7455 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0047, effect = 4.7525 (↑)
#
# Subject: 02, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0029, effect = 7.4435 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0199, effect = 6.4393 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0038, effect = 6.4386 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0247, effect = 5.4897 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0032, effect = 9.4998 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0169, effect = 8.3981 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0082, effect = 3.3308 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0306, effect = 2.3571 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0014, effect = 5.4773 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0465, effect = 4.0696 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0022, effect = 7.5695 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0146, effect = 6.6523 (↑)
#   - Front (Control vs Noise): p = 0.0473, effect = 1.7054 (↑)
#
# Subject: 03, Session: 01
#   - Left_Auditory (Control vs Noise): p = 0.0351, effect = 4.8058 (↑)
#
# Subject: 03, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0394, effect = 5.9469 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0202, effect = 7.5796 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0393, effect = 6.7750 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0225, effect = 7.3338 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0423, effect = 6.5564 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0196, effect = 7.8253 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0388, effect = 6.9937 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0370, effect = 5.5340 (↑)
#   - Visual (Control vs Noise): p = 0.0186, effect = 8.9282 (↑)
#   - Visual (Control vs Speech): p = 0.0396, effect = 7.5790 (↑)
#
# Subject: 04, Session: 01
#   - Noise_ROI (Control vs Noise): p = 0.0268, effect = 4.2333 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0314, effect = 4.1926 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0397, effect = 3.0091 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0412, effect = 4.2125 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0280, effect = 4.6501 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0299, effect = 4.2750 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0257, effect = 3.9325 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0397, effect = 3.4676 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0325, effect = 3.5975 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0317, effect = 3.5830 (↑)
#   - Visual (Control vs Speech): p = 0.0495, effect = 3.9738 (↑)
#
# Subject: 05, Session: 01
#   - Right_Auditory (Control vs Speech): p = 0.0456, effect = 2.4377 (↑)
#   - Front (Control vs Speech): p = 0.0021, effect = 4.7700 (↑)
#
# Subject: 05, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0278, effect = 7.1009 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0244, effect = 9.7049 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0258, effect = 6.5660 (↑)
#
# Subject: 08, Session: 02
#   - Speech_ROI (Control vs Noise): p = 0.0472, effect = 2.3391 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0227, effect = 2.7347 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0458, effect = 2.4329 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0317, effect = 2.6397 (↑)
#
# Subject: 11, Session: 01
#   - Noise_ROI (Control vs Noise): p = 0.0333, effect = 7.1330 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0386, effect = 5.7832 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0371, effect = 8.4968 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0415, effect = 4.4055 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0295, effect = 5.3967 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0369, effect = 5.6135 (↑)
#   - Visual (Control vs Noise): p = 0.0159, effect = 9.6138 (↑)
#
# Subject: 12, Session: 02
#   - Left_Auditory (Control vs Noise): p = 0.0326, effect = 4.2913 (↑)
#
# Subject: 13, Session: 01
#   - Common_ROI (Control vs Speech): p = 0.0327, effect = 3.0249 (↑)
#
# Subject: 13, Session: 02
#   - Noise_ROI (Control vs Speech): p = 0.0153, effect = 9.2874 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0084, effect = 10.2913 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0129, effect = 9.6811 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0319, effect = 8.4998 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0077, effect = 10.7794 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0340, effect = 10.6714 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0061, effect = 9.0673 (↑)
#   - Visual (Control vs Speech): p = 0.0068, effect = 9.8916 (↑)
#   - Front (Control vs Speech): p = 0.0030, effect = 6.8717 (↑)
#
# Subject: 16, Session: 01
#   - Common_ROI (Control vs Speech): p = 0.0478, effect = 4.2986 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0420, effect = 3.1189 (↑)
#
# Subject: 16, Session: 02
#   - Only_Speech_ROI (Control vs Speech): p = 0.0368, effect = 3.3145 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0333, effect = 3.3361 (↑)
#   - Front (Control vs Noise): p = 0.0322, effect = 2.8521 (↑)
#   - Front (Control vs Speech): p = 0.0003, effect = 5.1215 (↑)
#
# Subject: 17, Session: 01
#   - Only_Noise_ROI (Control vs Noise): p = 0.0453, effect = 1.7210 (↑)
#
# Subject: 17, Session: 02
#   - Noise_ROI (Control vs Speech): p = 0.0162, effect = 6.4477 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0043, effect = 8.3897 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0087, effect = 8.7323 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0024, effect = 8.1157 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0323, effect = 4.6050 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0103, effect = 7.0071 (↑)
#   - Visual (Control vs Speech): p = 0.0034, effect = 6.7395 (↑)
#
# Subject: 21, Session: 02
#   - Only_Speech_ROI (Control vs Speech): p = 0.0407, effect = 2.0810 (↑)
#
# Subject: 24, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0108, effect = 7.2414 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0021, effect = 10.3151 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0240, effect = 6.0221 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0038, effect = 9.1783 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0311, effect = 6.3642 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0021, effect = 11.0149 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0015, effect = 8.9958 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0053, effect = 8.9156 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0225, effect = 5.5660 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0175, effect = 6.7295 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0302, effect = 5.6558 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0269, effect = 6.4288 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0087, effect = 7.3705 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0014, effect = 10.5770 (↑)
#   - Visual (Control vs Speech): p = 0.0466, effect = 5.3195 (↑)
#   - Front (Control vs Noise): p = 0.0219, effect = 3.8736 (↑)
#   - Front (Control vs Speech): p = 0.0172, effect = 4.9993 (↑)
#
# ✅ Done with ROI t-tests!

# %%
from scipy.stats import ttest_ind
# === Setup ===
output_root = "individual_analysis_outputs"
os.makedirs(output_root, exist_ok=True)

bids_root = r"C:\\Datasets\\Test-retest study\\bids_dataset"
subject_list = sorted([d for d in os.listdir(bids_root) if d.startswith("sub-")])
subject_list = [s.replace("sub-", "") for s in subject_list]

print("Detected subjects:", subject_list)

ttest_results = []


for sub in subject_list:
    for ses in range(1, 3):
        bids_path = BIDSPath(
            subject=f"{sub}",
            session=f"{ses:02d}",
            task="auditory",
            datatype="nirs",
            root=bids_root,
            suffix="nirs",
            extension=".snirf",
        )
        print(f"Processing Subject {sub}, Session {ses:02d}")

        raw_haemo, epochs, event_dict, raw_od, events = individual_analysis(bids_path)

        if raw_haemo is None or len(epochs) < 10:
            print(f"⚠️ Skipping Subject {sub}, Session {ses:02d} (insufficient data)")
            continue

        epochs.drop_channels(epochs.info['bads'])
        epochs_cleaned = epochs.copy().pick("hbo")
        #epochs_cleaned.crop(tmin=0.0, tmax=10.0)

        # Get data and labels
        data = epochs_cleaned.get_data().mean(axis=2)  # (n_epochs, n_channels)
        ev = epochs_cleaned.events[:, 2]
        index_column = np.arange(0, len(ev)).reshape(-1, 1)
        labels = np.hstack((index_column, ev.reshape(-1, 1)))

        # Reject epochs per condition
        conditions = {1: "Control", 2: "Noise", 3: "Speech"}
        all_rejected = []

        for cond_code, cond_name in conditions.items():
            cond_idx = labels[labels[:, 1] == cond_code][:, 0].astype(int)
            cond_epochs = epochs_cleaned[cond_idx]  # Filter epochs for this condition

            if len(cond_epochs) == 0:
                continue

            available_channels = cond_epochs.info["ch_names"]
            rejected_epoch_indices = set()

            for ch_idx, ch_name in enumerate(available_channels):
                try:
                    # Get mean time-series for each epoch for this channel
                    ch_data = cond_epochs.get_data()[:, ch_idx, :].mean(axis=1)  # (n_epochs,)
                    _, rejected = reject_epochs_zscore_individual(
                        ch_data,
                        subject=sub,
                        session=f"{ses:02d}",
                        condition_name=cond_name,
                        stats_df=stats_df,
                        z_thresh=3.0
                    )

                    # Map local indices to global indices
                    global_rejected = [cond_idx[i] for i in rejected]
                    rejected_epoch_indices.update(global_rejected)

                except Exception as e:
                    print(f"⚠️ Channel {ch_name} skipped for Subject {sub}, Session {ses:02d}, Condition {cond_name}: {e}")
                    continue

            all_rejected.extend(rejected_epoch_indices)
            print(f"Subject {sub}, Session {ses:02d} - Rejected {len(rejected_epoch_indices)} epochs in {cond_name}")


        # Drop all rejected epochs
        epochs_cleaned.drop(all_rejected)

        # === ROI definitions ===
        roi_definitions = {
            "Noise_ROI": ["S10_D11 hbo", "S5_D3 hbo", "S11_D11 hbo", "S10_D9 hbo", "S10_D12 hbo", "S10_D10 hbo"],
            "Speech_ROI": ["S10_D11 hbo", "S10_D10 hbo", "S10_D12 hbo", "S11_D12 hbo", "S1_D1 hbo", "S10_D9 hbo", "S8_D7 hbo", "S7_D7 hbo", "S8_D8 hbo"],
            "Common_ROI": ["S10_D11 hbo", "S10_D9 hbo", "S10_D12 hbo", "S10_D10 hbo"],
            "Only_Noise_ROI": ["S5_D3 hbo", "S11_D11 hbo"],
            "Only_Speech_ROI": ["S11_D12 hbo", "S1_D1 hbo", "S8_D7 hbo", "S7_D7 hbo", "S8_D8 hbo"],
            "Left_Auditory": ["S4_D2 hbo", "S4_D3 hbo", "S5_D2 hbo", "S5_D3 hbo", "S5_D4 hbo", "S5_D5 hbo"],
            "Right_Auditory": ["S10_D9 hbo", "S10_D10 hbo", "S10_D11 hbo", "S10_D12 hbo", "S11_D11 hbo", "S11_D12 hbo"],
            "Visual": ["S6_D6 hbo", "S6_D8 hbo", "S7_D6 hbo", "S7_D7 hbo", "S8_D7 hbo", "S8_D8 hbo", "S9_D8 hbo", "S7_D8 hbo"],
            "Front": ["S1_D1 hbo", "S2_D1 hbo", "S3_D1 hbo", "S3_D2 hbo", "S12_D1 hbo"]
        }

        tmin, tmax = 4, 6
        for roi_name, optode_list in roi_definitions.items():
            available_optodes = [opt for opt in optode_list if opt in epochs_cleaned.info["ch_names"]]
            if len(available_optodes) < 2:
                continue

            try:
                cond_data = {}
                for cond in ["Control", "Noise", "Speech"]:
                    cond_epochs = epochs_cleaned[cond].copy().pick(available_optodes).crop(tmin=tmin, tmax=tmax)
                    data = cond_epochs.get_data()
                    cond_data[cond] = data.mean(axis=1).mean(axis=1) * 1e6

                if len(cond_data["Control"]) > 1 and len(cond_data["Noise"]) > 1:
                    t_stat, p_val = ttest_ind(cond_data["Control"], cond_data["Noise"], equal_var=False, alternative='less')
                    effect = np.mean(cond_data["Noise"]) - np.mean(cond_data["Control"])
                    ttest_results.append({"Subject": sub, "Session": f"{ses:02d}", "ROI": roi_name, "Comparison": "Control vs Noise", "t_stat": t_stat, "p_value": p_val, "Effect": effect})

                if len(cond_data["Control"]) > 1 and len(cond_data["Speech"]) > 1:
                    t_stat, p_val = ttest_ind(cond_data["Control"], cond_data["Speech"], equal_var=False, alternative='less')
                    effect = np.mean(cond_data["Speech"]) - np.mean(cond_data["Control"])
                    ttest_results.append({"Subject": sub, "Session": f"{ses:02d}", "ROI": roi_name, "Comparison": "Control vs Speech", "t_stat": t_stat, "p_value": p_val, "Effect": effect})

            except Exception as e:
                print(f"Error testing {roi_name} for Subject {sub}, Session {ses:02d}: {e}")

# === Save results ===
df_ttest = pd.DataFrame(ttest_results)

# === Summary per participant ===
print("\n=== Significant ROI Summary per Participant ===")
df_significant = df_ttest[df_ttest["p_value"] < 0.05]
if df_significant.empty:
    print("No significant ROIs found.")
else:
    grouped = df_significant.groupby(["Subject", "Session"])
    for (sub, ses), group in grouped:
        print(f"\nSubject: {sub}, Session: {ses}")
        for _, row in group.iterrows():
            sign = "↑" if row["Effect"] > 0 else "↓"
            print(f"  - {row['ROI']} ({row['Comparison']}): p = {row['p_value']:.4f}, effect = {row['Effect']:.4f} ({sign})")

print("\n✅ Done with ROI t-tests!")
# Out:
# Detected subjects: ['01', '02', '03', '04', '05', '07', '08', '10', '11', '12', '13', '16', '17', '19', '21', '24']
# Processing Subject 01, Session 01
# Subject 01, Session 01 - Rejected 9 epochs in Control
# Subject 01, Session 01 - Rejected 15 epochs in Noise
# Subject 01, Session 01 - Rejected 8 epochs in Speech
# Processing Subject 01, Session 02
# Subject 01, Session 02 - Rejected 7 epochs in Control
# Subject 01, Session 02 - Rejected 7 epochs in Noise
# Subject 01, Session 02 - Rejected 10 epochs in Speech
# Processing Subject 02, Session 01
# Subject 02, Session 01 - Rejected 4 epochs in Control
# Subject 02, Session 01 - Rejected 4 epochs in Noise
# Subject 02, Session 01 - Rejected 4 epochs in Speech
# Processing Subject 02, Session 02
# Subject 02, Session 02 - Rejected 10 epochs in Control
# Subject 02, Session 02 - Rejected 6 epochs in Noise
# Subject 02, Session 02 - Rejected 3 epochs in Speech
# Processing Subject 03, Session 01
# Subject 03, Session 01 - Rejected 7 epochs in Control
# Subject 03, Session 01 - Rejected 9 epochs in Noise
# Subject 03, Session 01 - Rejected 9 epochs in Speech
# Processing Subject 03, Session 02
# Subject 03, Session 02 - Rejected 3 epochs in Control
# Subject 03, Session 02 - Rejected 3 epochs in Noise
# Subject 03, Session 02 - Rejected 1 epochs in Speech
# Processing Subject 04, Session 01
# Subject 04, Session 01 - Rejected 5 epochs in Control
# Subject 04, Session 01 - Rejected 5 epochs in Noise
# Subject 04, Session 01 - Rejected 6 epochs in Speech
# Processing Subject 04, Session 02
# Subject 04, Session 02 - Rejected 12 epochs in Control
# Subject 04, Session 02 - Rejected 15 epochs in Noise
# Subject 04, Session 02 - Rejected 9 epochs in Speech
# Processing Subject 05, Session 01
# Subject 05, Session 01 - Rejected 10 epochs in Control
# Subject 05, Session 01 - Rejected 10 epochs in Noise
# Subject 05, Session 01 - Rejected 9 epochs in Speech
# Processing Subject 05, Session 02
# Subject 05, Session 02 - Rejected 9 epochs in Control
# Subject 05, Session 02 - Rejected 10 epochs in Noise
# Subject 05, Session 02 - Rejected 8 epochs in Speech
# Processing Subject 07, Session 01
# Subject 07, Session 01 - Rejected 9 epochs in Control
# Subject 07, Session 01 - Rejected 13 epochs in Noise
# Subject 07, Session 01 - Rejected 14 epochs in Speech
# Processing Subject 07, Session 02
# Subject 07, Session 02 - Rejected 4 epochs in Control
# Subject 07, Session 02 - Rejected 12 epochs in Noise
# Subject 07, Session 02 - Rejected 9 epochs in Speech
# Processing Subject 08, Session 01
# Subject 08, Session 01 - Rejected 11 epochs in Control
# Subject 08, Session 01 - Rejected 14 epochs in Noise
# Subject 08, Session 01 - Rejected 4 epochs in Speech
# Processing Subject 08, Session 02
# Subject 08, Session 02 - Rejected 16 epochs in Control
# Subject 08, Session 02 - Rejected 10 epochs in Noise
# Subject 08, Session 02 - Rejected 11 epochs in Speech
# Processing Subject 10, Session 01
# Subject 10, Session 01 - Rejected 5 epochs in Control
# Subject 10, Session 01 - Rejected 3 epochs in Noise
# Subject 10, Session 01 - Rejected 2 epochs in Speech
# Processing Subject 10, Session 02
# Subject 10, Session 02 - Rejected 4 epochs in Control
# Subject 10, Session 02 - Rejected 5 epochs in Noise
# Subject 10, Session 02 - Rejected 3 epochs in Speech
# Processing Subject 11, Session 01
# Subject 11, Session 01 - Rejected 9 epochs in Control
# Subject 11, Session 01 - Rejected 7 epochs in Noise
# Subject 11, Session 01 - Rejected 5 epochs in Speech
# Processing Subject 11, Session 02
# Subject 11, Session 02 - Rejected 10 epochs in Control
# Subject 11, Session 02 - Rejected 11 epochs in Noise
# Subject 11, Session 02 - Rejected 6 epochs in Speech
# Processing Subject 12, Session 01
# Subject 12, Session 01 - Rejected 6 epochs in Control
# Subject 12, Session 01 - Rejected 6 epochs in Noise
# Subject 12, Session 01 - Rejected 11 epochs in Speech
# Processing Subject 12, Session 02
# Subject 12, Session 02 - Rejected 11 epochs in Control
# Subject 12, Session 02 - Rejected 7 epochs in Noise
# Subject 12, Session 02 - Rejected 12 epochs in Speech
# Processing Subject 13, Session 01
# Subject 13, Session 01 - Rejected 10 epochs in Control
# Subject 13, Session 01 - Rejected 10 epochs in Noise
# Subject 13, Session 01 - Rejected 6 epochs in Speech
# Processing Subject 13, Session 02
# Subject 13, Session 02 - Rejected 5 epochs in Control
# Subject 13, Session 02 - Rejected 8 epochs in Noise
# Subject 13, Session 02 - Rejected 6 epochs in Speech
# Processing Subject 16, Session 01
# Subject 16, Session 01 - Rejected 5 epochs in Control
# Subject 16, Session 01 - Rejected 3 epochs in Noise
# Subject 16, Session 01 - Rejected 6 epochs in Speech
# Processing Subject 16, Session 02
# Subject 16, Session 02 - Rejected 13 epochs in Control
# Subject 16, Session 02 - Rejected 6 epochs in Noise
# Subject 16, Session 02 - Rejected 8 epochs in Speech
# Processing Subject 17, Session 01
# Subject 17, Session 01 - Rejected 11 epochs in Control
# Subject 17, Session 01 - Rejected 10 epochs in Noise
# Subject 17, Session 01 - Rejected 11 epochs in Speech
# Processing Subject 17, Session 02
# Subject 17, Session 02 - Rejected 8 epochs in Control
# Subject 17, Session 02 - Rejected 8 epochs in Noise
# Subject 17, Session 02 - Rejected 7 epochs in Speech
# Processing Subject 19, Session 01
# Subject 19, Session 01 - Rejected 7 epochs in Control
# Subject 19, Session 01 - Rejected 9 epochs in Noise
# Subject 19, Session 01 - Rejected 6 epochs in Speech
# Processing Subject 19, Session 02
# Subject 19, Session 02 - Rejected 6 epochs in Control
# Subject 19, Session 02 - Rejected 5 epochs in Noise
# Subject 19, Session 02 - Rejected 6 epochs in Speech
# Processing Subject 21, Session 01
# Subject 21, Session 01 - Rejected 10 epochs in Control
# Subject 21, Session 01 - Rejected 7 epochs in Noise
# Subject 21, Session 01 - Rejected 7 epochs in Speech
# Processing Subject 21, Session 02
# Subject 21, Session 02 - Rejected 15 epochs in Control
# Subject 21, Session 02 - Rejected 11 epochs in Noise
# Subject 21, Session 02 - Rejected 13 epochs in Speech
# Processing Subject 24, Session 01
# Subject 24, Session 01 - Rejected 4 epochs in Control
# Subject 24, Session 01 - Rejected 6 epochs in Noise
# Subject 24, Session 01 - Rejected 3 epochs in Speech
# Processing Subject 24, Session 02
# Subject 24, Session 02 - Rejected 1 epochs in Control
# Subject 24, Session 02 - Rejected 2 epochs in Noise
# Subject 24, Session 02 - Rejected 3 epochs in Speech
#
# === Significant ROI Summary per Participant ===
#
# Subject: 01, Session: 01
#   - Noise_ROI (Control vs Noise): p = 0.0232, effect = 5.1219 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0002, effect = 6.5791 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0379, effect = 4.3837 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0000, effect = 6.1511 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0272, effect = 6.1543 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0004, effect = 7.1509 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0021, effect = 5.4356 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0000, effect = 5.3512 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0202, effect = 3.9554 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0221, effect = 4.6903 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0002, effect = 6.1559 (↑)
#   - Visual (Control vs Speech): p = 0.0000, effect = 6.4468 (↑)
#
# Subject: 01, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0174, effect = 4.2768 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0484, effect = 3.1663 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0076, effect = 4.8336 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0146, effect = 5.3045 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0304, effect = 4.3025 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0132, effect = 4.3628 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0208, effect = 3.0756 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0286, effect = 3.5925 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0351, effect = 3.3093 (↑)
#   - Visual (Control vs Noise): p = 0.0155, effect = 4.6150 (↑)
#   - Front (Control vs Noise): p = 0.0185, effect = 2.8832 (↑)
#
# Subject: 03, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0388, effect = 6.0164 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0153, effect = 7.9272 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0185, effect = 7.4389 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0140, effect = 8.4155 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0430, effect = 6.8644 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0414, effect = 5.5527 (↑)
#   - Visual (Control vs Noise): p = 0.0097, effect = 9.9444 (↑)
#
# Subject: 04, Session: 01
#   - Noise_ROI (Control vs Noise): p = 0.0102, effect = 5.0643 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0122, effect = 4.9924 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0405, effect = 3.1785 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0075, effect = 3.8638 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0104, effect = 5.6367 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0073, effect = 6.1424 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0434, effect = 3.9194 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0459, effect = 2.0408 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0036, effect = 5.3046 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0130, effect = 4.0279 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0139, effect = 4.2993 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0111, effect = 4.3810 (↑)
#   - Visual (Control vs Speech): p = 0.0179, effect = 3.8643 (↑)
#
# Subject: 04, Session: 02
#   - Only_Noise_ROI (Control vs Speech): p = 0.0481, effect = 3.0134 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0199, effect = 3.9219 (↑)
#
# Subject: 05, Session: 01
#   - Speech_ROI (Control vs Speech): p = 0.0339, effect = 3.8547 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0430, effect = 2.4318 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0304, effect = 4.9286 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0264, effect = 2.4003 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0238, effect = 3.0817 (↑)
#   - Front (Control vs Speech): p = 0.0128, effect = 5.1603 (↑)
#
# Subject: 05, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0015, effect = 11.4405 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0358, effect = 6.0166 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0086, effect = 9.2561 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0030, effect = 12.2709 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0343, effect = 6.8442 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0022, effect = 10.3508 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0311, effect = 5.9869 (↑)
#
# Subject: 08, Session: 01
#   - Only_Speech_ROI (Control vs Noise): p = 0.0323, effect = 3.1786 (↑)
#
# Subject: 10, Session: 02
#   - Common_ROI (Control vs Noise): p = 0.0460, effect = 4.9833 (↑)
#
# Subject: 12, Session: 02
#   - Left_Auditory (Control vs Noise): p = 0.0444, effect = 4.1058 (↑)
#
# Subject: 13, Session: 01
#   - Noise_ROI (Control vs Noise): p = 0.0228, effect = 3.3006 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0406, effect = 3.3173 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0164, effect = 9.2082 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0392, effect = 8.1698 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0375, effect = 3.4167 (↑)
#
# Subject: 13, Session: 02
#   - Noise_ROI (Control vs Speech): p = 0.0024, effect = 10.8191 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0366, effect = 5.4388 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0005, effect = 11.4906 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0020, effect = 10.6408 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0091, effect = 11.1756 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0283, effect = 6.1012 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0005, effect = 12.1705 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0064, effect = 13.3737 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0013, effect = 10.1551 (↑)
#   - Visual (Control vs Noise): p = 0.0328, effect = 5.5417 (↑)
#   - Visual (Control vs Speech): p = 0.0005, effect = 11.0023 (↑)
#   - Front (Control vs Noise): p = 0.0477, effect = 4.4834 (↑)
#   - Front (Control vs Speech): p = 0.0002, effect = 8.0381 (↑)
#
# Subject: 16, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0102, effect = 5.4113 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0035, effect = 6.7989 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0189, effect = 4.2583 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0013, effect = 6.6906 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0160, effect = 5.5977 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0052, effect = 7.1361 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0457, effect = 2.9190 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0005, effect = 6.2451 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0071, effect = 5.1652 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0021, effect = 6.6607 (↑)
#   - Visual (Control vs Speech): p = 0.0353, effect = 3.4171 (↑)
#   - Front (Control vs Noise): p = 0.0016, effect = 4.6311 (↑)
#   - Front (Control vs Speech): p = 0.0000, effect = 7.5024 (↑)
#
# Subject: 17, Session: 02
#   - Noise_ROI (Control vs Speech): p = 0.0055, effect = 5.4958 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0009, effect = 7.2345 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0020, effect = 7.5730 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0009, effect = 6.9637 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0224, effect = 4.0414 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0028, effect = 5.9950 (↑)
#   - Visual (Control vs Speech): p = 0.0036, effect = 5.3838 (↑)
#   - Front (Control vs Speech): p = 0.0219, effect = 2.4184 (↑)
#
# Subject: 19, Session: 01
#   - Left_Auditory (Control vs Noise): p = 0.0470, effect = 2.1473 (↑)
#
# Subject: 21, Session: 02
#   - Noise_ROI (Control vs Speech): p = 0.0215, effect = 5.8076 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0326, effect = 4.9366 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0407, effect = 6.0916 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0381, effect = 5.3816 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0310, effect = 3.7817 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0395, effect = 6.0976 (↑)
#
# Subject: 24, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0179, effect = 6.7109 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0158, effect = 7.1717 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0387, effect = 5.4218 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0267, effect = 6.0613 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0494, effect = 5.6874 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0160, effect = 7.4684 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0023, effect = 8.7580 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0274, effect = 6.5782 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0353, effect = 5.0676 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0459, effect = 5.1396 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0146, effect = 6.8598 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0112, effect = 7.4800 (↑)
#   - Front (Control vs Noise): p = 0.0291, effect = 3.7122 (↑)
#
# ✅ Done with ROI t-tests!

# %% [markdown]
# # Global Mean + Std dev

# %%
import os
import numpy as np
import pandas as pd
from collections import defaultdict
from mne_bids import BIDSPath

# === Paths ===
bids_root = r"C:\Datasets\Test-retest study\bids_dataset"
output_root = "individual_analysis_outputs"
os.makedirs(output_root, exist_ok=True)

# === List subjects ===
subject_list = sorted([d for d in os.listdir(bids_root) if d.startswith("sub-")])
subject_list = [s.replace("sub-", "") for s in subject_list]
print("Detected subjects:", subject_list)

# === Storage ===
condition_timecourses = defaultdict(list)
n_times_map = {}

# === Loop over subjects and sessions ===
for sub in subject_list:
    for ses in range(1, 3):
        bids_path = BIDSPath(
            subject=f"{sub}",
            session=f"{ses:02d}",
            task="auditory",
            datatype="nirs",
            root=bids_root,
            suffix="nirs",
            extension=".snirf",
        )

        raw_haemo, epochs, event_dict, raw_od, events = individual_analysis(bids_path)

        if raw_haemo is None or len(epochs) < 10:
            print(f"⚠️ Skipping sub-{sub} ses-{ses:02d} (not enough channels or epochs)")
            continue

        # Drop bad channels
        epochs.drop_channels(epochs.info['bads'])

        # Pick only HbO
        hbo_epochs = epochs.copy().pick("hbo")
        #hbo_epochs.crop(tmin=0.0, tmax=10.0)

        for condition in hbo_epochs.event_id:
            condition_epochs = hbo_epochs[condition]

            if len(condition_epochs) < 3:
                print(f"⚠️ Skipping {condition} for sub-{sub} ses-{ses:02d} (too few epochs)")
                continue

            data = condition_epochs.get_data()  # (n_epochs, n_channels, n_times)
            avg_timecourse = np.mean(data, axis=(0, 1))  # (n_times,) — avg over epochs and channels

            condition_timecourses[condition].append(avg_timecourse)
            n_times_map[condition] = avg_timecourse.shape[0]

        print(f"✅ Finished sub-{sub} ses-{ses:02d}")

# === Compute mean and std per condition ===
group_level_results = []

for condition, vectors in condition_timecourses.items():
    stacked = np.vstack(vectors)  # shape: (n_participants, n_times)
    flat_data = stacked.flatten()  # Combine all timepoints and participants
    mean_signal = np.mean(flat_data)
    std_signal = np.std(flat_data, ddof=1)

    # Save individual timecourses just in case
    condition_df = pd.DataFrame(stacked)
    

    group_level_results.append({
        "Condition": condition,
        "N_Participants": len(vectors),
        "Global_Mean": mean_signal,
        "Global_Std": std_signal
        
    })

# === Summary Table ===
summary_df = pd.DataFrame(group_level_results)

# save to csv
summary_df.to_csv(os.path.join(output_root, "global_mean_stddev_zscore.csv"), index=False)
# Out:
# Detected subjects: ['01', '02', '03', '04', '05', '07', '08', '10', '11', '12', '13', '16', '17', '19', '21', '24']
# ✅ Finished sub-01 ses-01
# ✅ Finished sub-01 ses-02
# ✅ Finished sub-02 ses-01
# ✅ Finished sub-02 ses-02
# ✅ Finished sub-03 ses-01
# ✅ Finished sub-03 ses-02
# ✅ Finished sub-04 ses-01
# ✅ Finished sub-04 ses-02
# ✅ Finished sub-05 ses-01
# ✅ Finished sub-05 ses-02
# ✅ Finished sub-07 ses-01
# ✅ Finished sub-07 ses-02
# ✅ Finished sub-08 ses-01
# ✅ Finished sub-08 ses-02
# ✅ Finished sub-10 ses-01
# ✅ Finished sub-10 ses-02
# ✅ Finished sub-11 ses-01
# ✅ Finished sub-11 ses-02
# ✅ Finished sub-12 ses-01
# ✅ Finished sub-12 ses-02
# ✅ Finished sub-13 ses-01
# ✅ Finished sub-13 ses-02
# ✅ Finished sub-16 ses-01
# ✅ Finished sub-16 ses-02
# ✅ Finished sub-17 ses-01
# ✅ Finished sub-17 ses-02
# ✅ Finished sub-19 ses-01
# ✅ Finished sub-19 ses-02
# ✅ Finished sub-21 ses-01
# ✅ Finished sub-21 ses-02
# ✅ Finished sub-24 ses-01
# ✅ Finished sub-24 ses-02

# %%
print(summary_df)
# Out:
#   Condition  N_Participants   Global_Mean  Global_Std
# 0   Control              32 -1.467584e-07    0.000001
# 1     Noise              32  6.891795e-07    0.000001
# 2    Speech              32  9.625289e-07    0.000002

# %% [markdown]
# # Epoch rejection function (global mean std dev)

# %%
import os
import numpy as np
import pandas as pd
from scipy.stats import ttest_ind, zscore
from mne_bids import BIDSPath
from collections import defaultdict

def reject_epochs_zscore_global(data, condition_name, df= summary_df, z_thresh=3.0, max_reject_ratio=1.0):
    """
    Rejects epochs based on z-score threshold using global mean and std from summary_df.

    Parameters:
        data (ndarray): (n_epochs, n_channels) — max or min per channel per epoch
        condition_name (str): "Control", "Noise", or "Speech"
        summary_df (pd.DataFrame): Contains global mean/std per condition
        z_thresh (float): Z-score threshold for rejection
        max_reject_ratio (float): Max proportion of epochs to reject

    Returns:
        cleaned_data (ndarray), rejected_indices (list)
    """
    row = summary_df[summary_df["Condition"] == condition_name]
    if row.empty:
        raise ValueError(f"No global stats found for condition: {condition_name}")
    
    global_mean = row["Global_Mean"].values[0]
    global_std = row["Global_Std"].values[0]

    z_scores = (data - global_mean) / global_std
    reject_mask = np.abs(z_scores) > z_thresh
    #epoch_reject_flags = np.any(reject_mask)
    rejected_indices = np.where(reject_mask)[0].tolist()

    # Limit number of rejected epochs
    max_reject = int(max_reject_ratio * data.shape[0])
    if len(rejected_indices) > max_reject:
        rejected_indices = rejected_indices[:max_reject]

    cleaned_data = np.delete(data, rejected_indices, axis=0)
    return cleaned_data, rejected_indices

# %%
import os
import numpy as np
import pandas as pd
from scipy.stats import ttest_ind, zscore
from mne_bids import BIDSPath
from collections import defaultdict

# === Setup ===
output_root = "individual_analysis_outputs"
os.makedirs(output_root, exist_ok=True)

bids_root = r"C:\\Datasets\\Test-retest study\\bids_dataset"
subject_list = sorted([d for d in os.listdir(bids_root) if d.startswith("sub-")])
subject_list = [s.replace("sub-", "") for s in subject_list]

print("Detected subjects:", subject_list)

ttest_results = []


for sub in subject_list:
    for ses in range(1, 3):
        bids_path = BIDSPath(
            subject=f"{sub}",
            session=f"{ses:02d}",
            task="auditory",
            datatype="nirs",
            root=bids_root,
            suffix="nirs",
            extension=".snirf",
        )
        print(f"Processing Subject {sub}, Session {ses:02d}")

        raw_haemo, epochs, event_dict, raw_od, events = individual_analysis(bids_path)

        if raw_haemo is None or len(epochs) < 10:
            print(f"⚠️ Skipping Subject {sub}, Session {ses:02d} (insufficient data)")
            continue

        epochs.drop_channels(epochs.info['bads'])
        epochs_cleaned = epochs.copy().pick("hbo")
        #epochs_cleaned.crop(tmin=0.0, tmax=10.0)

        # Get data and labels
        data = epochs_cleaned.get_data().mean(axis=1) # average over channels (n_epochs, n_times)
        data_mean = data.mean(axis=1) # average over time
        ev = epochs_cleaned.events[:, 2]
        index_column = np.arange(0, len(ev)).reshape(-1, 1)
        labels = np.hstack((index_column, ev.reshape(-1, 1)))

        # Reject epochs per condition
        conditions = {1: "Control", 2: "Noise", 3: "Speech"}
        all_rejected = []
        for cond_code, cond_name in conditions.items():
            cond_idx = labels[labels[:, 1] == cond_code][:, 0].astype(int)
            cond_data = data_mean[cond_idx]
            a, rejected = reject_epochs_zscore_global(cond_data, cond_name )
            rejected_global = [cond_idx[i] for i in rejected]
            all_rejected.extend(rejected_global)
            print(f"Subject {sub}, Session {ses:02d} - Rejected {len(rejected)} epochs in {cond_name}")

        # Drop all rejected
        epochs_cleaned.drop(all_rejected)

        # === ROI definitions ===
        roi_definitions = {
            "Noise_ROI": ["S10_D11 hbo", "S5_D3 hbo", "S11_D11 hbo", "S10_D9 hbo", "S10_D12 hbo", "S10_D10 hbo"],
            "Speech_ROI": ["S10_D11 hbo", "S10_D10 hbo", "S10_D12 hbo", "S11_D12 hbo", "S1_D1 hbo", "S10_D9 hbo", "S8_D7 hbo", "S7_D7 hbo", "S8_D8 hbo"],
            "Common_ROI": ["S10_D11 hbo", "S10_D9 hbo", "S10_D12 hbo", "S10_D10 hbo"],
            "Only_Noise_ROI": ["S5_D3 hbo", "S11_D11 hbo"],
            "Only_Speech_ROI": ["S11_D12 hbo", "S1_D1 hbo", "S8_D7 hbo", "S7_D7 hbo", "S8_D8 hbo"],
            "Left_Auditory": ["S4_D2 hbo", "S4_D3 hbo", "S5_D2 hbo", "S5_D3 hbo", "S5_D4 hbo", "S5_D5 hbo"],
            "Right_Auditory": ["S10_D9 hbo", "S10_D10 hbo", "S10_D11 hbo", "S10_D12 hbo", "S11_D11 hbo", "S11_D12 hbo"],
            "Visual": ["S6_D6 hbo", "S6_D8 hbo", "S7_D6 hbo", "S7_D7 hbo", "S8_D7 hbo", "S8_D8 hbo", "S9_D8 hbo", "S7_D8 hbo"],
            "Front": ["S1_D1 hbo", "S2_D1 hbo", "S3_D1 hbo", "S3_D2 hbo", "S12_D1 hbo"]
        }

        tmin, tmax = 4, 6
        for roi_name, optode_list in roi_definitions.items():
            available_optodes = [opt for opt in optode_list if opt in epochs_cleaned.info["ch_names"]]
            if len(available_optodes) < 2:
                continue

            try:
                cond_data = {}
                for cond in ["Control", "Noise", "Speech"]:
                    cond_epochs = epochs_cleaned[cond].copy().pick(available_optodes).crop(tmin=tmin, tmax=tmax)
                    data = cond_epochs.get_data()
                    cond_data[cond] = data.mean(axis=1).mean(axis=1) * 1e6

                if len(cond_data["Control"]) > 1 and len(cond_data["Noise"]) > 1:
                    t_stat, p_val = ttest_ind(cond_data["Control"], cond_data["Noise"], equal_var=False, alternative='less')
                    effect = np.mean(cond_data["Noise"]) - np.mean(cond_data["Control"])
                    ttest_results.append({"Subject": sub, "Session": f"{ses:02d}", "ROI": roi_name, "Comparison": "Control vs Noise", "t_stat": t_stat, "p_value": p_val, "Effect": effect})

                if len(cond_data["Control"]) > 1 and len(cond_data["Speech"]) > 1:
                    t_stat, p_val = ttest_ind(cond_data["Control"], cond_data["Speech"], equal_var=False, alternative='less')
                    effect = np.mean(cond_data["Speech"]) - np.mean(cond_data["Control"])
                    ttest_results.append({"Subject": sub, "Session": f"{ses:02d}", "ROI": roi_name, "Comparison": "Control vs Speech", "t_stat": t_stat, "p_value": p_val, "Effect": effect})

            except Exception as e:
                print(f"Error testing {roi_name} for Subject {sub}, Session {ses:02d}: {e}")

# === Save results ===
df_ttest = pd.DataFrame(ttest_results)

# === Summary per participant ===
print("\n=== Significant ROI Summary per Participant ===")
df_significant = df_ttest[df_ttest["p_value"] < 0.05]
if df_significant.empty:
    print("No significant ROIs found.")
else:
    grouped = df_significant.groupby(["Subject", "Session"])
    for (sub, ses), group in grouped:
        print(f"\nSubject: {sub}, Session: {ses}")
        for _, row in group.iterrows():
            sign = "↑" if row["Effect"] > 0 else "↓"
            print(f"  - {row['ROI']} ({row['Comparison']}): p = {row['p_value']:.4f}, effect = {row['Effect']:.4f} ({sign})")

print("\n✅ Done with ROI t-tests!")
# Out:
# Detected subjects: ['01', '02', '03', '04', '05', '07', '08', '10', '11', '12', '13', '16', '17', '19', '21', '24']
# Processing Subject 01, Session 01
# Subject 01, Session 01 - Rejected 2 epochs in Control
# Subject 01, Session 01 - Rejected 1 epochs in Noise
# Subject 01, Session 01 - Rejected 1 epochs in Speech
# Processing Subject 01, Session 02
# Subject 01, Session 02 - Rejected 2 epochs in Control
# Subject 01, Session 02 - Rejected 1 epochs in Noise
# Subject 01, Session 02 - Rejected 0 epochs in Speech
# Processing Subject 02, Session 01
# Subject 02, Session 01 - Rejected 5 epochs in Control
# Subject 02, Session 01 - Rejected 7 epochs in Noise
# Subject 02, Session 01 - Rejected 4 epochs in Speech
# Processing Subject 02, Session 02
# Subject 02, Session 02 - Rejected 2 epochs in Control
# Subject 02, Session 02 - Rejected 3 epochs in Noise
# Subject 02, Session 02 - Rejected 5 epochs in Speech
# Processing Subject 03, Session 01
# Subject 03, Session 01 - Rejected 6 epochs in Control
# Subject 03, Session 01 - Rejected 4 epochs in Noise
# Subject 03, Session 01 - Rejected 4 epochs in Speech
# Processing Subject 03, Session 02
# Subject 03, Session 02 - Rejected 9 epochs in Control
# Subject 03, Session 02 - Rejected 10 epochs in Noise
# Subject 03, Session 02 - Rejected 8 epochs in Speech
# Processing Subject 04, Session 01
# Subject 04, Session 01 - Rejected 7 epochs in Control
# Subject 04, Session 01 - Rejected 4 epochs in Noise
# Subject 04, Session 01 - Rejected 2 epochs in Speech
# Processing Subject 04, Session 02
# Subject 04, Session 02 - Rejected 1 epochs in Control
# Subject 04, Session 02 - Rejected 1 epochs in Noise
# Subject 04, Session 02 - Rejected 1 epochs in Speech
# Processing Subject 05, Session 01
# Subject 05, Session 01 - Rejected 2 epochs in Control
# Subject 05, Session 01 - Rejected 4 epochs in Noise
# Subject 05, Session 01 - Rejected 3 epochs in Speech
# Processing Subject 05, Session 02
# Subject 05, Session 02 - Rejected 9 epochs in Control
# Subject 05, Session 02 - Rejected 7 epochs in Noise
# Subject 05, Session 02 - Rejected 7 epochs in Speech
# Processing Subject 07, Session 01
# Subject 07, Session 01 - Rejected 0 epochs in Control
# Subject 07, Session 01 - Rejected 0 epochs in Noise
# Subject 07, Session 01 - Rejected 0 epochs in Speech
# Processing Subject 07, Session 02
# Subject 07, Session 02 - Rejected 3 epochs in Control
# Subject 07, Session 02 - Rejected 0 epochs in Noise
# Subject 07, Session 02 - Rejected 0 epochs in Speech
# Processing Subject 08, Session 01
# Subject 08, Session 01 - Rejected 1 epochs in Control
# Subject 08, Session 01 - Rejected 0 epochs in Noise
# Subject 08, Session 01 - Rejected 1 epochs in Speech
# Processing Subject 08, Session 02
# Subject 08, Session 02 - Rejected 0 epochs in Control
# Subject 08, Session 02 - Rejected 1 epochs in Noise
# Subject 08, Session 02 - Rejected 0 epochs in Speech
# Processing Subject 10, Session 01
# Subject 10, Session 01 - Rejected 7 epochs in Control
# Subject 10, Session 01 - Rejected 10 epochs in Noise
# Subject 10, Session 01 - Rejected 9 epochs in Speech
# Processing Subject 10, Session 02
# Subject 10, Session 02 - Rejected 6 epochs in Control
# Subject 10, Session 02 - Rejected 12 epochs in Noise
# Subject 10, Session 02 - Rejected 6 epochs in Speech
# Processing Subject 11, Session 01
# Subject 11, Session 01 - Rejected 7 epochs in Control
# Subject 11, Session 01 - Rejected 6 epochs in Noise
# Subject 11, Session 01 - Rejected 7 epochs in Speech
# Processing Subject 11, Session 02
# Subject 11, Session 02 - Rejected 3 epochs in Control
# Subject 11, Session 02 - Rejected 3 epochs in Noise
# Subject 11, Session 02 - Rejected 1 epochs in Speech
# Processing Subject 12, Session 01
# Subject 12, Session 01 - Rejected 8 epochs in Control
# Subject 12, Session 01 - Rejected 5 epochs in Noise
# Subject 12, Session 01 - Rejected 4 epochs in Speech
# Processing Subject 12, Session 02
# Subject 12, Session 02 - Rejected 6 epochs in Control
# Subject 12, Session 02 - Rejected 4 epochs in Noise
# Subject 12, Session 02 - Rejected 4 epochs in Speech
# Processing Subject 13, Session 01
# Subject 13, Session 01 - Rejected 6 epochs in Control
# Subject 13, Session 01 - Rejected 4 epochs in Noise
# Subject 13, Session 01 - Rejected 2 epochs in Speech
# Processing Subject 13, Session 02
# Subject 13, Session 02 - Rejected 10 epochs in Control
# Subject 13, Session 02 - Rejected 10 epochs in Noise
# Subject 13, Session 02 - Rejected 9 epochs in Speech
# Processing Subject 16, Session 01
# Subject 16, Session 01 - Rejected 4 epochs in Control
# Subject 16, Session 01 - Rejected 7 epochs in Noise
# Subject 16, Session 01 - Rejected 4 epochs in Speech
# Processing Subject 16, Session 02
# Subject 16, Session 02 - Rejected 1 epochs in Control
# Subject 16, Session 02 - Rejected 2 epochs in Noise
# Subject 16, Session 02 - Rejected 0 epochs in Speech
# Processing Subject 17, Session 01
# Subject 17, Session 01 - Rejected 0 epochs in Control
# Subject 17, Session 01 - Rejected 1 epochs in Noise
# Subject 17, Session 01 - Rejected 0 epochs in Speech
# Processing Subject 17, Session 02
# Subject 17, Session 02 - Rejected 4 epochs in Control
# Subject 17, Session 02 - Rejected 5 epochs in Noise
# Subject 17, Session 02 - Rejected 3 epochs in Speech
# Processing Subject 19, Session 01
# Subject 19, Session 01 - Rejected 1 epochs in Control
# Subject 19, Session 01 - Rejected 1 epochs in Noise
# Subject 19, Session 01 - Rejected 3 epochs in Speech
# Processing Subject 19, Session 02
# Subject 19, Session 02 - Rejected 5 epochs in Control
# Subject 19, Session 02 - Rejected 8 epochs in Noise
# Subject 19, Session 02 - Rejected 4 epochs in Speech
# Processing Subject 21, Session 01
# Subject 21, Session 01 - Rejected 0 epochs in Control
# Subject 21, Session 01 - Rejected 1 epochs in Noise
# Subject 21, Session 01 - Rejected 0 epochs in Speech
# Processing Subject 21, Session 02
# Subject 21, Session 02 - Rejected 1 epochs in Control
# Subject 21, Session 02 - Rejected 1 epochs in Noise
# Subject 21, Session 02 - Rejected 0 epochs in Speech
# Processing Subject 24, Session 01
# Subject 24, Session 01 - Rejected 7 epochs in Control
# Subject 24, Session 01 - Rejected 2 epochs in Noise
# Subject 24, Session 01 - Rejected 6 epochs in Speech
# Processing Subject 24, Session 02
# Subject 24, Session 02 - Rejected 5 epochs in Control
# Subject 24, Session 02 - Rejected 7 epochs in Noise
# Subject 24, Session 02 - Rejected 5 epochs in Speech
#
# === Significant ROI Summary per Participant ===
#
# Subject: 01, Session: 01
#   - Noise_ROI (Control vs Noise): p = 0.0000, effect = 9.1309 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0001, effect = 8.3252 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0000, effect = 7.7600 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0001, effect = 6.8516 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0000, effect = 10.7723 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0004, effect = 9.0649 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0000, effect = 5.8481 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0000, effect = 6.8459 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0000, effect = 5.3502 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0001, effect = 5.0810 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0000, effect = 5.8756 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0006, effect = 5.7777 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0000, effect = 8.4201 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0001, effect = 7.7635 (↑)
#   - Visual (Control vs Noise): p = 0.0000, effect = 6.5401 (↑)
#   - Visual (Control vs Speech): p = 0.0001, effect = 5.7725 (↑)
#
# Subject: 01, Session: 02
#   - Noise_ROI (Control vs Speech): p = 0.0209, effect = 4.0018 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0154, effect = 5.1959 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0072, effect = 4.4117 (↑)
#
# Subject: 02, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0171, effect = 4.9042 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0220, effect = 4.0340 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0175, effect = 6.2767 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0447, effect = 2.1593 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0087, effect = 3.6880 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0122, effect = 5.1208 (↑)
#
# Subject: 03, Session: 01
#   - Noise_ROI (Control vs Noise): p = 0.0106, effect = 4.5560 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0225, effect = 3.9410 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0048, effect = 6.4153 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0121, effect = 5.8349 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0156, effect = 5.1301 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0256, effect = 4.5836 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0164, effect = 3.4078 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0474, effect = 2.6558 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0034, effect = 7.4435 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0094, effect = 6.8360 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0080, effect = 6.2709 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0164, effect = 5.0855 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0206, effect = 3.5549 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0457, effect = 2.9867 (↑)
#   - Visual (Control vs Noise): p = 0.0024, effect = 8.7657 (↑)
#   - Visual (Control vs Speech): p = 0.0049, effect = 8.8898 (↑)
#   - Front (Control vs Noise): p = 0.0376, effect = 2.8290 (↑)
#   - Front (Control vs Speech): p = 0.0237, effect = 2.3927 (↑)
#
# Subject: 04, Session: 01
#   - Noise_ROI (Control vs Speech): p = 0.0317, effect = 4.0442 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0298, effect = 3.0673 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0205, effect = 4.9377 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0333, effect = 3.6309 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0224, effect = 3.7360 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0305, effect = 3.4882 (↑)
#
# Subject: 05, Session: 01
#   - Front (Control vs Speech): p = 0.0043, effect = 4.7582 (↑)
#
# Subject: 05, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0293, effect = 5.5152 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0217, effect = 6.4327 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0352, effect = 4.8523 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0185, effect = 6.1083 (↑)
#
# Subject: 08, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0329, effect = 2.7299 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0312, effect = 2.5967 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0137, effect = 3.0052 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0396, effect = 2.7259 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0338, effect = 2.6004 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0196, effect = 2.9130 (↑)
#
# Subject: 12, Session: 02
#   - Left_Auditory (Control vs Noise): p = 0.0272, effect = 4.0534 (↑)
#
# Subject: 13, Session: 01
#   - Noise_ROI (Control vs Speech): p = 0.0474, effect = 2.9189 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0185, effect = 3.6151 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0443, effect = 3.1311 (↑)
#
# Subject: 13, Session: 02
#   - Noise_ROI (Control vs Speech): p = 0.0014, effect = 9.8079 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0004, effect = 8.3970 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0005, effect = 9.6084 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0188, effect = 10.2068 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0026, effect = 7.4278 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0205, effect = 10.3904 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0005, effect = 9.6210 (↑)
#   - Visual (Control vs Speech): p = 0.0031, effect = 7.2815 (↑)
#   - Front (Control vs Speech): p = 0.0013, effect = 6.1976 (↑)
#
# Subject: 16, Session: 02
#   - Noise_ROI (Control vs Speech): p = 0.0313, effect = 3.7801 (↑)
#   - Speech_ROI (Control vs Speech): p = 0.0292, effect = 3.8697 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0443, effect = 3.9544 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0215, effect = 3.7850 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0463, effect = 2.7764 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0185, effect = 3.9001 (↑)
#   - Front (Control vs Noise): p = 0.0185, effect = 3.2359 (↑)
#   - Front (Control vs Speech): p = 0.0001, effect = 5.5523 (↑)
#
# Subject: 17, Session: 01
#   - Only_Noise_ROI (Control vs Noise): p = 0.0415, effect = 1.8181 (↑)
#
# Subject: 17, Session: 02
#   - Only_Speech_ROI (Control vs Speech): p = 0.0343, effect = 4.4668 (↑)
#   - Visual (Control vs Speech): p = 0.0475, effect = 3.4517 (↑)
#
# Subject: 19, Session: 01
#   - Only_Speech_ROI (Control vs Speech): p = 0.0380, effect = 3.4659 (↑)
#   - Visual (Control vs Speech): p = 0.0477, effect = 2.4718 (↑)
#
# Subject: 21, Session: 01
#   - Only_Noise_ROI (Control vs Noise): p = 0.0183, effect = 2.8168 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0446, effect = 2.8809 (↑)
#   - Left_Auditory (Control vs Speech): p = 0.0414, effect = 2.9368 (↑)
#
# Subject: 21, Session: 02
#   - Speech_ROI (Control vs Speech): p = 0.0448, effect = 2.2528 (↑)
#   - Only_Speech_ROI (Control vs Speech): p = 0.0259, effect = 2.3173 (↑)
#
# Subject: 24, Session: 01
#   - Noise_ROI (Control vs Speech): p = 0.0474, effect = 4.8245 (↑)
#
# Subject: 24, Session: 02
#   - Noise_ROI (Control vs Noise): p = 0.0017, effect = 8.2478 (↑)
#   - Noise_ROI (Control vs Speech): p = 0.0281, effect = 6.6883 (↑)
#   - Speech_ROI (Control vs Noise): p = 0.0078, effect = 6.7877 (↑)
#   - Common_ROI (Control vs Noise): p = 0.0070, effect = 7.7735 (↑)
#   - Common_ROI (Control vs Speech): p = 0.0290, effect = 7.2111 (↑)
#   - Only_Noise_ROI (Control vs Noise): p = 0.0005, effect = 9.1965 (↑)
#   - Only_Noise_ROI (Control vs Speech): p = 0.0461, effect = 5.6426 (↑)
#   - Only_Speech_ROI (Control vs Noise): p = 0.0205, effect = 5.4734 (↑)
#   - Left_Auditory (Control vs Noise): p = 0.0235, effect = 5.4908 (↑)
#   - Right_Auditory (Control vs Noise): p = 0.0012, effect = 8.5176 (↑)
#   - Right_Auditory (Control vs Speech): p = 0.0235, effect = 6.9179 (↑)
#   - Front (Control vs Noise): p = 0.0240, effect = 3.7058 (↑)
#
# ✅ Done with ROI t-tests!
